# %% [markdown]
# # 6. Dependency parsing
#
# In this class we will have a look at *parsing*, which means annotating the syntactic structure of the sentence. Currently the most popular way to see the problem is *dependency parsing*, in which we assume that each word in the sentence *depends* on some other word. For example the adjective can depend on the noun that it describes, while a verb's subject depends on the verb.
#
# We will start by reading in the text of "Anna Karenina" exactly as in the previous class:

# %%
from collections import Counter, defaultdict
from operator import itemgetter
import spacy
import spacy.displacy

# %%
def load_paragraphs(filename):
    '''Reads a text divided into paragraphs.'''
    pars = []
    with open(filename) as fp:
        text = fp.read()
        pars = [p.replace('\n', ' ') for p in text.split('\n\n') if p.strip()]
    return pars

# %%
text = load_paragraphs('anna_karenina.txt')
nlp = spacy.load('en_core_web_sm')
docs = [nlp(par) for par in text]  # Run the NLP pipeline paragraph by paragraph

# %% [markdown]
# From the annotations produced by spaCy, today we'll be interested in `head` and `dep_`:

# %%
for tok in docs[30][0].sent:
    print(tok.i, tok.orth_, tok.pos_, tok.head.i, tok.dep_, sep='\t')
    # dep_ = dependency type
    # head = where the arrow is coming from
    # head shows the word, head.i shows the index
    # ROOT = there's no arrow
# Out:
# 0	“	PUNCT	15	punct
# 1	It	PRON	2	nsubj
# 2	’s	VERB	15	ccomp
# 3	that	DET	5	det
# 4	idiotic	ADJ	5	amod
# 5	smile	NOUN	2	attr
# 6	that	DET	7	nsubj
# 7	’s	VERB	5	relcl
# 8	to	PART	9	aux
# 9	blame	VERB	2	xcomp
# 10	for	ADP	9	prep
# 11	it	PRON	10	pobj
# 12	all	DET	11	appos
# 13	,	PUNCT	15	punct
# 14	”	PUNCT	15	punct
# 15	thought	VERB	15	ROOT
# 16	Stepan	PROPN	17	compound
# 17	Arkadyevitch	PROPN	15	nsubj
# 18	.	PUNCT	15	punct

# %%
docs[30][4].head
# Out:
# smile

# %% [markdown]
# The `head` annotation encodes the word that the given word depends on. For example token number 3 is "that" and it refers to token number 5: "smile". `tok.head` is again a Token object, so we can ask directly about its properties: e.g. `tok.head.pos_` is the POS-tag of the *head* of `tok` (cf. `tok.pos_`, which is the POS-tag of `tok` itself):

# %%
docs[30][3].head.pos_
# Out:
# 'NOUN'

# %%
docs[30][3].pos_
# Out:
# 'DET'

# %% [markdown]
# The annotation `dep_` gives us the *type* of the dependency. For example `nsubj` means that the word is subject of a verb.
#
# In every sentence there is one word that doesn't depend on any other (typically the main verb): it's called the *root* of the sentence. It has the head set to itself and dependency type `ROOT`.
#
# The dependency relationships in a sentence can be visualized by the function `render()` from the module `spacy.displacy`:

# %%
spacy.displacy.render(docs[30][0].sent, style='dep', options={'distance': 100, 'compact':True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a491f4ed7fad4e7ca2ff9eba294c4d72-0" class="displacy" width="1650" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">“</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">idiotic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">smile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">blame</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">all,”</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">thought</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Stepan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">Arkadyevitch.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-0" stroke-width="2px" d="M62,302.0 62,202.0 1350.0,202.0 1350.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-1" stroke-width="2px" d="M162,302.0 162,285.3333333333333 235.0,285.3333333333333 235.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,304.0 L158,296.0 166,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-2" stroke-width="2px" d="M262,302.0 262,218.66666666666669 1347.0,218.66666666666669 1347.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,304.0 L258,296.0 266,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-3" stroke-width="2px" d="M362,302.0 362,268.6666666666667 538.0,268.6666666666667 538.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,304.0 L358,296.0 366,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-4" stroke-width="2px" d="M462,302.0 462,285.3333333333333 535.0,285.3333333333333 535.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,304.0 L458,296.0 466,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-5" stroke-width="2px" d="M262,302.0 262,252.0 541.0,252.0 541.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M541.0,304.0 L545.0,296.0 537.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a491f4ed7fad4e7ca2ff9eba294c4d72-0-6" stroke-width="2px" d="M662,302.0 66

# %%
spacy.displacy.render(docs[30][0].sent, style='dep', options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="64151aaf163546d59923586dd0c25f23-0" class="displacy" width="1650" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">“</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">idiotic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">smile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">blame</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">all,”</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">thought</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Stepan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">Arkadyevitch.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64151aaf163546d59923586dd0c25f23-0-0" stroke-width="2px" d="M70,302.0 C70,2.0 1350.0,2.0 1350.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-64151aaf163546d59923586dd0c25f23-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64151aaf163546d59923586dd0c25f23-0-1" stroke-width="2px" d="M170,302.0 C170,252.0 225.0,252.0 225.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-64151aaf163546d59923586dd0c25f23-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,304.0 L162,292.0 178,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64151aaf163546d59923586dd0c25f23-0-2" stroke-width="2px" d="M270,302.0 C270,52.0 1345.0,52.0 1345.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-64151aaf163546d59923586dd0c25f23-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,304.0 L262,292.0 278,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64151aaf163546d59923586dd0c25f23-0-3" stroke-width="2px" d="M370,302.0 C370,202.0 530.0,202.0 530.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-64151aaf163546d59923586dd0c25f23-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,304.0 L362,292.0 378,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64151aaf163546d59923586dd0c25f23-0-4" stroke-width="2px" d="M470,302.0 C470,252.0 525.0,252.0 525.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-64151aaf163546d59923586dd0c25f23-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,304.0 L462,292.0 478,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64151aaf163546d59923586dd0c25f23-0-5" stroke-width="2px" d="M270,302.0 C270,152.0 535.0,152.0 535.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-64151aaf163546d59923586dd0c25f23-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M535.0,304.0 L543.0,292.0 527.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64151aaf163546d59923586dd0c25f23-0-6" stroke-width="2px" d="M670,302.0 C670,252.0 725.0,252.0 725.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style=

# %% [markdown]
# # In-class exercises

# %% [markdown]
# ## Ex 1
#
# The sentence above mentions an "idiotic smile". What else can be idiotic? Find all examples of "idiotic" + the word it refers to and list them together with the entire sentence they occur in.

# %%
for par in docs:
    for tok in par:
        if tok.lemma_ == 'idiotic':
            print(tok, tok.head, tok.sent, sep='\t')
# Out:
# idiotic	smile	Instead of being hurt, denying, defending himself, begging forgiveness, instead of remaining indifferent even—anything would have been better than what he did do—his face utterly involuntarily (reflex spinal action, reflected Stepan Arkadyevitch, who was fond of physiology)—utterly involuntarily assumed its habitual, good-humored, and therefore idiotic smile.
# idiotic	smile	This idiotic smile he could not forgive himself.
# idiotic	smile	“It’s that idiotic smile that’s to blame for it all,” thought Stepan Arkadyevitch.
# idiotic	’s	“Oh, it’s so idiotic!
# idiotic	expression	He takes away his hands and feels the shamestruck and idiotic expression of his face.
# Idiotic	woman	“Idiotic woman!”

# %% [markdown]
# ## Ex 2
#
# Is there a relationship between a word's dependency type (i.e. the role that it plays in the sentence) and its POS tag? Create a dictionary `tags_by_dep` that contains a frequency list of POS tags for each dependency type.

# %%
tags_by_dep = defaultdict(lambda: defaultdict(lambda: 0))

for par in docs:
    for tok in par:
        tags_by_dep[tok.dep_][tok.pos_] += 1

for key in tags_by_dep:
    tags_by_dep[key] = sorted(tags_by_dep[key].items(), reverse=True, key=itemgetter(1))

# %%
tags_by_dep['nsubj'][:5]
# Out:
# [('PRON', 25189), ('NOUN', 6373), ('PROPN', 4960), ('DET', 1913), ('NUM', 124)]

# %%
tags_by_dep['case'][:5]
# Out:
# [('PART', 1321), ('PUNCT', 15), ('PROPN', 9), ('NOUN', 7), ('PRON', 6)]

# %%
tags_by_dep['ROOT'][:5]
# Out:
# [('VERB', 16818), ('AUX', 2607), ('NOUN', 552), ('PUNCT', 527), ('SPACE', 250)]

# %% [markdown]
# # Homework

# %% [markdown]
# ## Ex 3 (2p.)
#
# Write a function `deps(docs, lemma, tag)` that counts the dependents of word with a certain lemma and tag, segregated by dependency type. The function should for example allow us to see the frequency lists of subjects and objects of the verb "love", as shown below.

# %%
# double dictionary

# %%
deps_love = deps(docs, 'love', 'VERB')

# %%
deps_love['nsubj'][:10]    # who loves?
# Out:
# [('i', 50),
#  ('he', 43),
#  ('she', 40),
#  ('you', 29),
#  ('who', 6),
#  ('one', 5),
#  ('wife', 3),
#  ('they', 2),
#  ('anna', 2),
#  ('your', 2)]

# %%
deps_love['dobj'][:10]    # who is loved?
# Out:
# [('him', 49),
#  ('her', 39),
#  ('me', 32),
#  ('you', 14),
#  ('whom', 9),
#  ('man', 5),
#  ('child', 4),
#  ('wife', 4),
#  ('someone', 4),
#  ('anna', 4)]

# %% [markdown]
# ## Ex 4 (3p.)
#
# Write a function `frames(docs, lemma, tag)` that extracts *frames* for a word with a specific lemma and tag (typically a verb) and counts them. A frame is a list of dependents that the word may take in a sentence, each dependent being specified by its type and POS-tag. For example the frame `(('nsubj', 'PRON'), ('dobj', 'PRON'))` means that the word takes a pronoun as subject *and* a pronoun as object.

# %%
#"I found it hard to love her." - example 2
# what kind of syntactic structure it is?

# extract a frame of a single token
# tokens attached to verb 'love'
frame = defaultdict(lambda: list())
for par in docs:
    for tok in par:
        if tok.head.lemma_ == 'love':
            frame[tok.head].append((tok.dep_, tok.pos_))

# %%
for key, val in frame.items():
    print(key, val)
# convert to tuples, so it can be a key in a dictionary
# Out:
# love [('prep', 'ADP')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'NOUN'), ('advmod', 'ADJ'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loving [('dobj', 'PRON')]
# loved [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'ADV'), ('dobj', 'PRON')]
# love [('neg', 'PART')]
# loves [('intj', 'INTJ'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'NOUN')]
# loved [('punct', 'PUNCT'), ('cc', 'CCONJ'), ('advmod', 'ADV'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loved [('npadvmod', 'PROPN'), ('punct', 'PUNCT'), ('advmod', 'ADV'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loved [('advmod', 'ADV'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('cc', 'CCONJ'), ('advmod', 'ADV'), ('aux', 'AUX'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('aux', 'AUX'), ('neg', 'PART'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('advmod', 'ADV'), ('punct', 'PUNCT')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('aux', 'PART')]
# love [('mark', 'SCONJ'), ('nsubj', 'PROPN'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('nsubj', 'ADJ'), ('punct', 'PUNCT'), ('csubj', 'VERB'), ('aux', 'AUX'), ('neg', 'PART'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('advcl', 'VERB'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('punct', 'PUNCT'), ('prep', 'ADP'), ('punct', 'PUNCT')]
# love [('aux', 'PART')]
# loved [('aux', 'PART'), ('auxpass', 'AUX'), ('prep', 'ADP')]
# love [('predet', 'DET'), ('det', 'DET'), ('prep', 'ADP')]
# loved [('prep', 'ADP'), ('nsubj', 'PRON'), ('dobj', 'PROPN')]
# loved [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('dobj', 'NOUN'), ('punct', 'PUNCT')]
# love [('dobj', 'SCONJ'), ('nsubj', 'PRON')]
# love [('prep', 'ADP')]
# love [('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'ADJ')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'NOUN'), ('prep', 'ADP')]
# love [('poss', 'PRON'), ('punct', 'PUNCT'), ('relcl', 'VERB')]
# love [('prep', 'ADP'), ('punct', 'PUNCT'), ('punct', 'PUNCT'), ('appos', 'NOUN'), ('punct', 'PUNCT')]
# love [('det', 'DET'), ('amod', 'ADJ'), ('amod', 'ADJ'), ('amod', 'ADJ')]
# love [('amod', 'ADJ')]
# love [('amod', 'ADJ')]
# love [('det', 'DET')]
# love [('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('prep', 'ADP')]
# love [('amod', 'ADJ'), ('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# loved [('dobj', 'PRON'), ('nsubj', 'PRON')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('punct', 'PUNCT'), ('dobj', 'PRON')]
# love [('prep', 'ADP')]
# love [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('aux', 'AUX'), ('ROOT', 'VERB'), ('xcomp', 'VERB'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'NOUN')]
# loved [('dobj', 'PRON'), ('nsubj', 'PRON')]
# love [('det', 'DET'), ('prep', 'ADP')]
# loved [('nsubj', 'PRON')]
# love [('poss', 'PROPN')]
# love [('prep', 'ADP')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# loves [('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('prep', 'ADP'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('advcl', 'VERB')]
# loved [('dobj', 'PRON')]
# love [('poss', 'PRON')]
# loving [('punct', 'PUNCT'), ('advcl', 'VERB'), ('punct', 'PUNCT'), ('dobj', 'PRON'), ('prep', 'ADP')]
# loving [('dobj', 'PRON'), ('punct', 'PUNCT'), ('intj', 'INTJ')]
# love [('advmod', 'ADV'), ('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'NOUN'), ('dative', 'ADP')]
# love [('poss', 'PRON'), ('amod', 'ADJ')]
# love [('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('amod', 'ADJ')]
# love [('prep', 'ADP')]
# loved [('dobj', 'PRON'), ('advmod', 'ADV'), ('nsubj', 'PRON')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PRON'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('prep', 'ADP')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('amod', 'ADJ')]
# loved [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PROPN'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('aux', 'AUX'), ('advmod', 'ADV'), ('dobj', 'PRON'), ('prep', 'ADP')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('punct', 'PUNCT'), ('intj', 'INTJ'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('nsubj', 'PRON')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('poss', 'PRON')]
# love [('det', 'PRON'), ('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PROPN'), ('cc', 'CCONJ'), ('conj', 'ADP')]
# love [('poss', 'PRON')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('neg', 'PART')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# loves [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('intj', 'INTJ'), ('punct', 'PUNCT')]
# love [('mark', 'SCONJ'), ('nsubj', 'NOUN'), ('aux', 'AUX'), ('advmod', 'ADV'), ('dobj', 'PRON')]
# loving [('nsubj', 'NOUN'), ('dobj', 'PRON')]
# loving [('nsubj', 'NOUN'), ('dobj', 'PRON')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('nsubj', 'NOUN'), ('dobj', 'NOUN')]
# love [('aux', 'AUX'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('punct', 'PUNCT')]
# love [('det', 'PRON')]
# love [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('poss', 'PRON'), ('punct', 'PUNCT'), ('appos', 'NOUN')]
# love [('poss', 'PRON')]
# love [('prep', 'ADP')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('det', 'DET'), ('relcl', 'VERB')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON'), ('amod', 'ADJ'), ('prep', 'ADP')]
# love [('poss', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('dobj', 'PRON'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('punct', 'PUNCT'), ('punct', 'PUNCT'), ('intj', 'INTJ'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('punct', 'PUNCT'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('prep', 'ADP'), ('punct', 'PUNCT'), ('conj', 'NOUN')]
# love [('prep', 'ADP')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('nsubj', 'PRON'), ('aux', 'AUX'), ('dobj', 'NOUN'), ('punct', 'PUNCT')]
# love [('poss', 'PRON')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('advmod', 'ADV'), ('cc', 'CCONJ'), ('conj', 'PART')]
# love [('dobj', 'DET'), ('nsubj', 'PRON'), ('aux', 'AUX')]
# love [('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('dobj', 'NOUN')]
# love [('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'NOUN'), ('punct', 'PUNCT')]
# love [('det', 'DET')]
# love [('dobj', 'PRON'), ('nsubj', 'PRON'), ('advcl', 'VERB')]
# love [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('dobj', 'PRON'), ('nsubj', 'PRON')]
# love [('dobj', 'PRON'), ('nsubj', 'PRON')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('poss', 'PRON')]
# love [('punct', 'PUNCT'), ('neg', 'PART')]
# love [('dobj', 'PRON'), ('nsubj', 'PRON'), ('advcl', 'VERB')]
# love [('mark', 'ADP'), ('nsubj', 'PRON'), ('dobj', 'NOUN')]
# love [('amod', 'ADJ'), ('punct', 'PUNCT'), ('amod', 'ADJ'), ('punct', 'PUNCT'), ('amod', 'VERB')]
# love [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('dobj', 'PRON'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('advcl', 'VERB'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# loving [('dobj', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'NOUN'), ('advcl', 'VERB')]
# love [('advmod', 'ADV'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'NOUN')]
# love [('mark', 'SCONJ'), ('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('dobj', 'PRON'), ('nsubj', 'PRON')]
# love [('dobj', 'SCONJ'), ('nsubj', 'PRON')]
# love [('aux', 'AUX'), ('dobj', 'PRON')]
# love [('poss', 'PRON')]
# loved [('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('punct', 'PUNCT')]
# loved [('nsubj', 'PRON')]
# loved [('advmod', 'DET'), ('nsubj', 'PROPN'), ('dobj', 'PROPN')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# loves [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'NOUN'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loved [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'ADV')]
# love [('punct', 'PUNCT'), ('cc', 'CCONJ'), ('advcl', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('advmod', 'ADV'), ('punct', 'PUNCT')]
# love [('poss', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# loved [('mark', 'SCONJ'), ('prep', 'ADP'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('ccomp', 'VERB')]
# love [('poss', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('poss', 'PRON')]
# love [('prep', 'ADP')]
# loved [('nsubj', 'PROPN'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loved [('advmod', 'ADV')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('poss', 'PRON')]
# loved [('advmod', 'ADV'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('advcl', 'VERB'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('punct', 'PUNCT')]
# love [('mark', 'ADP'), ('nsubj', 'NOUN'), ('aux', 'AUX'), ('advcl', 'VERB')]
# love [('poss', 'PRON')]
# love [('det', 'DET')]
# love [('det', 'DET'), ('prep', 'ADP')]
# love [('aux', 'PART'), ('dobj', 'PRON'), ('advmod', 'ADV')]
# love [('punct', 'PUNCT'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loves [('nsubj', 'PRON'), ('dobj', 'PROPN')]
# loves [('ccomp', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('cc', 'CCONJ'), ('nsubj', 'PRON'), ('dobj', 'PROPN'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# Love [('punct', 'PUNCT'), ('ROOT', 'VERB'), ('dobj', 'DET'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# Love [('dobj', 'DET'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('aux', 'PART'), ('dobj', 'NOUN')]
# loving [('dobj', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('punct', 'PUNCT'), ('intj', 'INTJ'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('npadvmod', 'PRON'), ('punct', 'PUNCT'), ('advcl', 'VERB'), ('punct', 'PUNCT'), ('aux', 'AUX'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# Love [('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('prep', 'ADP')]
# loved [('nsubj', 'PRON'), ('advmod', 'ADV'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('advmod', 'ADV'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loved [('ccomp', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('dobj', 'NOUN')]
# love [('cc', 'CCONJ'), ('conj', 'NOUN')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'ADV'), ('dobj', 'PRON'), ('prep', 'SCONJ')]
# love [('aux', 'PART'), ('dobj', 'PRON'), ('advcl', 'VERB')]
# loved [('mark', 'ADP'), ('nsubjpass', 'PRON'), ('aux', 'AUX'), ('auxpass', 'AUX')]
# love [('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# loved [('advmod', 'ADV')]
# love [('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('nsubj', 'PRON'), ('advmod', 'ADV'), ('dobj', 'PRON'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('punct', 'PUNCT')]
# loves [('nsubj', 'PRON')]
# love [('mark', 'SCONJ'), ('nsubj', 'NOUN'), ('dobj', 'NOUN'), ('prep', 'ADP')]
# love [('det', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'NOUN')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# loved [('dobj', 'PRON'), ('nsubj', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('det', 'DET'), ('prep', 'ADP')]
# loved [('nsubj', 'PRON'), ('prep', 'ADP')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'NOUN'), ('prep', 'ADP')]
# loving [('nsubj', 'PRON'), ('dobj', 'NOUN')]
# love [('prep', 'ADP')]
# loving [('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('punct', 'PUNCT'), ('dep', 'PRON'), ('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('punct', 'PUNCT'), ('intj', 'INTJ'), ('punct', 'PUNCT'), ('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('aux', 'AUX'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# loved [('nsubj', 'PRON'), ('dobj', 'PRON'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('advcl', 'VERB')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('advcl', 'VERB')]
# love [('amod', 'VERB'), ('acl', 'VERB')]
# love [('dobj', 'PRON')]
# love [('dobj', 'PRON')]
# loved [('nsubj', 'PRON'), ('aux', 'AUX')]
# loved [('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('advmod', 'ADV'), ('poss', 'PRON'), ('amod', 'ADJ'), ('amod', 'ADJ')]
# love [('cc', 'CCONJ'), ('conj', 'NOUN'), ('prep', 'ADP')]
# loved [('nsubj', 'PRON')]
# loved [('ccomp', 'VERB'), ('advmod', 'ADV'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loved [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'ADP'), ('punct', 'PUNCT')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('poss', 'PRON')]
# loved [('nsubj', 'PRON')]
# love [('dobj', 'PRON'), ('advcl', 'VERB')]
# loved [('mark', 'ADP'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('dobj', 'PRON'), ('xcomp', 'VERB')]
# loved [('nsubj', 'PRON')]
# love [('poss', 'PRON')]
# loving [('dobj', 'PRON'), ('advcl', 'VERB')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# loved [('agent', 'ADP')]
# love [('poss', 'PRON')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('mark', 'ADP'), ('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('dobj', 'PRON')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('advmod', 'ADV')]
# loved [('nsubj', 'PRON')]
# loved [('nsubj', 'PRON'), ('advmod', 'ADV')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'NOUN'), ('advmod', 'ADJ')]
# love [('det', 'DET')]
# love [('aux', 'PART'), ('cc', 'CCONJ'), ('conj', 'ADP')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('punct', 'PUNCT'), ('ccomp', 'AUX'), ('punct', 'PUNCT'), ('nsubj', 'DET'), ('ROOT', 'VERB'), ('ccomp', 'VERB'), ('punct', 'PUNCT')]
# love [('poss', 'PRON'), ('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PROPN'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('det', 'DET'), ('punct', 'PUNCT'), ('appos', 'NOUN')]
# love [('amod', 'ADJ')]
# loving [('poss', 'PRON'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('punct', 'PUNCT'), ('conj', 'PROPN'), ('punct', 'PUNCT')]
# love [('ccomp', 'VERB'), ('punct', 'PUNCT'), ('advmod', 'ADV'), ('aux', 'AUX'), ('neg', 'PART'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loving [('dobj', 'NOUN')]
# loved [('nsubj', 'PRON')]
# loved [('advmod', 'ADV'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('dobj', 'PRON'), ('advmod', 'ADV')]
# loved [('dobj', 'PRON')]
# love [('punct', 'PUNCT'), ('npadvmod', 'NOUN'), ('parataxis', 'VERB'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('conj', 'VERB')]
# love [('amod', 'ADJ'), ('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('predet', 'DET'), ('det', 'DET'), ('relcl', 'VERB')]
# loved [('nsubj', 'NOUN'), ('advmod', 'ADV'), ('punct', 'PUNCT')]
# loved [('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('relcl', 'VERB')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'ADJ')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('poss', 'PRON')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('advcl', 'VERB')]
# love [('mark', 'ADP'), ('nsubj', 'PRON'), ('punct', 'PUNCT'), ('advcl', 'VERB')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON'), ('punct', 'PUNCT')]
# love [('punct', 'PUNCT'), ('advmod', 'ADV'), ('punct', 'PUNCT'), ('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loved [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('advmod', 'ADV'), ('punct', 'PUNCT'), ('advcl', 'VERB'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# loved [('nsubj', 'PRON')]
# love [('prep', 'ADP')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# loved [('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('aux', 'PART'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('advcl', 'VERB'), ('punct', 'PUNCT')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# loved [('advcl', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('advmod', 'ADV'), ('advcl', 'AUX')]
# love [('aux', 'PART')]
# loved [('cc', 'CCONJ'), ('nsubj', 'NOUN'), ('punct', 'PUNCT'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loved [('cc', 'CCONJ'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loved [('nsubj', 'PRON'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('aux', 'AUX'), ('punct', 'PUNCT'), ('advmod', 'ADV'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('advcl', 'VERB'), ('punct', 'PUNCT')]
# love [('nsubj', 'PRON')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PROPN'), ('neg', 'ADV'), ('dobj', 'NOUN')]
# loved [('nsubj', 'PRON'), ('aux', 'AUX'), ('aux', 'AUX'), ('ROOT', 'VERB'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('punct', 'PUNCT')]
# loved [('aux', 'AUX'), ('auxpass', 'AUX'), ('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('prep', 'ADP')]
# loved [('nsubj', 'PRON'), ('advmod', 'ADV'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loves [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# loves [('advcl', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('advcl', 'VERB')]
# love [('nsubj', 'PRON')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON'), ('advmod', 'ADJ'), ('punct', 'PUNCT')]
# love [('det', 'DET'), ('cc', 'CCONJ'), ('conj', 'NOUN'), ('prep', 'ADP'), ('prep', 'ADP')]
# love [('amod', 'ADJ')]
# love [('amod', 'ADJ')]
# loved [('advmod', 'ADV'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PROPN'), ('prep', 'ADP'), ('punct', 'PUNCT')]
# love [('prep', 'ADP')]
# love [('punct', 'PUNCT'), ('nsubj', 'PRON'), ('advmod', 'ADV'), ('dobj', 'PRON'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('poss', 'PRON')]
# love [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('advmod', 'ADV'), ('punct', 'PUNCT')]
# loves [('nsubj', 'PRON')]
# loved [('cc', 'CCONJ'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PROPN'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loves [('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('advmod', 'ADV'), ('punct', 'PUNCT')]
# loves [('mark', 'ADP'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('poss', 'PRON')]
# love [('nsubj', 'PRON'), ('punct', 'PUNCT')]
# love [('dobj', 'DET'), ('nsubj', 'PRON')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('det', 'DET'), ('amod', 'ADJ'), ('punct', 'PUNCT'), ('amod', 'ADJ'), ('relcl', 'VERB')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('poss', 'PRON')]
# love [('advcl', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('amod', 'ADJ')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# loved [('nsubj', 'PRON')]
# loved [('mark', 'ADP'), ('nsubj', 'PRON'), ('ccomp', 'VERB')]
# loves [('nummod', 'NUM')]
# loving [('nsubj', 'PRON'), ('dobj', 'PRON'), ('advmod', 'ADJ')]
# love [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'PRON'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('nummod', 'NUM')]
# love [('aux', 'PART'), ('dobj', 'NOUN')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('prep', 'ADP'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('prep', 'ADP')]
# love [('aux', 'PART'), ('dobj', 'DET')]
# loves [('nsubj', 'PRON'), ('dobj', 'NOUN')]
# loves [('ccomp', 'AUX'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('det', 'DET'), ('relcl', 'VERB')]
# loved [('nsubj', 'PRON'), ('dobj', 'NOUN')]
# loved [('nsubj', 'PRON'), ('prep', 'ADP')]
# loved [('punct', 'PUNCT'), ('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('prep', 'ADP')]
# loving [('dobj', 'PRON')]
# love [('poss', 'PRON')]
# love [('nsubj', 'PRON'), ('dobj', 'PRON')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# love [('prep', 'ADP')]
# love [('poss', 'PRON')]
# love [('prep', 'ADP'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'NOUN')]
# love [('det', 'DET')]
# love [('det', 'DET')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('dobj', 'PRON')]
# loved [('nsubj', 'PRON'), ('dobj', 'PRON')]
# loving [('neg', 'PART'), ('dobj', 'NOUN'), ('punct', 'PUNCT')]
# love [('aux', 'PART'), ('dobj', 'NOUN')]
# love [('prep', 'ADP')]
# love [('poss', 'PRON'), ('prep', 'ADP')]
# loves [('intj', 'INTJ'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('dobj', 'NOUN')]
# loves [('punct', 'PUNCT'), ('ccomp', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# love [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('advcl', 'VERB')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('advcl', 'VERB')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON'), ('advmod', 'ADV')]
# loves [('nsubj', 'PRON'), ('dobj', 'NOUN'), ('punct', 'PUNCT'), ('conj', 'VERB')]
# love [('ccomp', 'VERB'), ('punct', 'PUNCT'), ('aux', 'AUX'), ('dobj', 'PRON')]
# love [('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')]
# love [('ccomp', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# loved [('punct', 'PUNCT'), ('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('advmod', 'ADV')]
# love [('det', 'DET')]
# love [('punct', 'PUNCT'), ('nmod', 'PROPN'), ('advmod', 'ADV')]
# love [('punct', 'PUNCT'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('ROOT', 'VERB'), ('dobj', 'NOUN'), ('punct', 'PUNCT')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'NOUN')]
# loved [('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loves [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('advmod', 'ADV')]
# love [('dobj', 'NOUN'), ('advcl', 'VERB')]
# love [('advmod', 'ADV'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loves [('advmod', 'ADV'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loved [('advmod', 'ADV'), ('advcl', 'VERB'), ('punct', 'PUNCT'), ('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('advcl', 'VERB'), ('punct', 'PUNCT')]
# love [('poss', 'PRON')]
# loves [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('prep', 'ADP')]
# love [('neg', 'PART'), ('ROOT', 'VERB'), ('advmod', 'ADV'), ('punct', 'PUNCT'), ('punct', 'PUNCT')]
# loves [('nsubj', 'PRON'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'ADV'), ('punct', 'PUNCT')]
# love [('poss', 'PRON')]
# love [('poss', 'PRON')]
# love [('prep', 'ADP')]
# loving [('dobj', 'PRON')]
# loved [('prep', 'ADP'), ('advmod', 'ADV'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('ROOT', 'VERB'), ('dobj', 'PRON'), ('punct', 'PUNCT')]
# loved [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('dobj', 'PRON'), ('punct', 'PUNCT'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('det', 'DET')]
# love [('det', 'DET')]
# love [('det', 'DET')]
# loved [('advmod', 'ADV'), ('nsubj', 'PRON'), ('cc', 'CCONJ'), ('conj', 'VERB'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# love [('amod', 'ADJ'), ('cc', 'CCONJ'), ('conj', 'NOUN')]
# loving [('punct', 'PUNCT'), ('conj', 'VERB')]
# loving [('dobj', 'NOUN'), ('advmod', 'ADJ')]
# love [('dobj', 'NOUN')]
# love [('mark', 'SCONJ'), ('nsubj', 'PRON'), ('aux', 'AUX'), ('dobj', 'NOUN'), ('cc', 'CCONJ'), ('conj', 'VERB')]
# loving [('dobj', 'NOUN')]
# love [('aux', 'PART'), ('dobj', 'PRON')]
# love [('advmod', 'ADV'), ('nsubj', 'PRON'), ('dobj', 'PRON')]

# %%
fr_love = frames(docs, 'love', 'VERB')

# %%
fr_love[:5]
# Out:
# [((('nsubj', 'PRON'),), 6),
#  ((('dobj', 'PRON'),), 4),
#  ((('nsubj', 'PRON'), ('aux', 'AUX'), ('neg', 'PART'), ('dobj', 'PRON')), 3),
#  ((('nsubj', 'PRON'), ('dobj', 'PRON')), 3),
#  ((('dobj', 'NOUN'),), 3)]
