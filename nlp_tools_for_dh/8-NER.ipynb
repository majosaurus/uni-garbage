# %% [markdown]
# # 8. Named Entity Recognition
#
# Today we will have a look at the last type of annotations provided by the basic spaCy pipeline: *Named Entity Recognition*. Named entities are typically proper names (e.g. names of persons, places or organizations). Sometimes also other types of expressions are included in this category, e.g. temporal expressions ("last January") or quantities ("100 000 euros"). Especially for news and generally text that reports on events, the most essential information is usually encoded in the named entities.
#
# We start as always by reading the data. We continue with the YLE English dataset from the last class:

# %%
from collections import defaultdict
import csv
from operator import itemgetter
import spacy

# %%
def read_articles(filename):
    result = []
    with open(filename) as fp:
        reader = csv.DictReader(fp)
        for row in reader:
            result.append(row['text'])
    return result

# %%
nlp = spacy.load('en_core_web_sm')

# %%
texts = read_articles('yle_en.csv')
docs = [nlp(text) for text in texts]

# %% [markdown]
# Previously we were able to recognize proper names already by their part-of-speech tag `PROPN`. In addition to that, the named entity annotation distinguishes between different categories of names (e.g. `ORG` - names of organizations).
#
# On the token level, this information is contained in the fields `ent_type_` (the type of the entity) and `ent_iob_`. The latter is either `B`, `I` or `O` and is a way to encode annotations spanning over multiple tokens. Those labels have the following meaning:
# * `B` -- "base" -- a named entity starts here,
# * `I` -- "inside" -- previously started named entity continues here,
# * `O` -- "outside" -- there is no named entity here.

# %%
for tok in docs[0][:10]:
    print(tok.i, tok.norm_, tok.lemma_, tok.pos_, tok.ent_iob_, tok.ent_type_, sep='\t')
# Out:
# 0	nokia	Nokia	PROPN	B	ORG
# 1	has	have	AUX	O
# 2	announced	announce	VERB	O
# 3	plans	plan	NOUN	O
# 4	to	to	PART	O
# 5	cut	cut	VERB	O
# 6	up	up	ADP	B	CARDINAL
# 7	to	to	PART	I	CARDINAL
# 8	10,000	10,000	NUM	I	CARDINAL
# 9	jobs	job	NOUN	O

# %% [markdown]
# We can also get a list of all named entites as spans from the document object, using its field `ents`:

# %%
for ent in docs[0].ents:
    print(ent, ent.label_, sep='\t')
# Out:
# Nokia	ORG
# up to 10,000	CARDINAL
# the next two years	DATE
# Espoo	ORG
# around 600 million	CARDINAL
# the end of 2023	DATE
# 5	CARDINAL
# Finland	GPE
# 5	CARDINAL
# Nokia	ORG
# around 90,000	CARDINAL
# Pekka Lundmark	PERSON
# 6 percent	PERCENT
# Nokia	ORG
# last year	DATE
# 918 million	CARDINAL
# 2020	DATE
# 485 million	CARDINAL
# 2019	DATE

# %% [markdown]
# The module `spacy.displacy` provides a neat visualization of text with recognized named entities:

# %%
spacy.displacy.render(docs[0], style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nokia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has announced plans to cut
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to 10,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  jobs worldwide over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the next two years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>In a statement, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Espoo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -based telecoms company said it intended to &quot;reset its cost base,&quot; aiming to make savings of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around 600 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  euros by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of 2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>The company said that the cuts would offset investments in research and development focused on areas including
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# G and cloud computing. The development could mean a net increase of jobs in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as the company continues to hire experts to work on its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# G technology.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nokia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  currently employs
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around 90,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people worldwide.</br>&quot;Decisions that may have a potential impact on our employees are never taken lightly. Ensuring we have the right setup and capabilities is a necessary step to deliver sustainable long-term performance. My priority is to ensure that everyone impacted is supported through this process,&quot; said company CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pekka Lundmark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in a statement.</br>Despite a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  drop in sales,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nokia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reported increased profits
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The company made
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     918 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  euros in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , up from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     485 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>

# %% [markdown]
# ## Ex 1
#
# Create a frequency list of all recognized named entities in the whole corpus.

# %%
from collections import Counter

# %%
ent_freqs = Counter() # similar to defaultdict(lambda: 0)
for d in docs:
    ent_freqs.update(str(ent) for ent in d.ents)
ent_freqs_lst = sorted(ent_freqs.items(), reverse=True, key=itemgetter(1))

# %%
ent_freqs = defaultdict(lambda: 0)
for doc in docs:
    for ent in doc.ents:
        ent_freqs[str(ent)] += 1
ent_freqs_lst = sorted(ent_freqs.items(), reverse=True, key=itemgetter(1))

# %%
ent_freqs_lst[:20]
# Out:
# [('Finland', 424),
#  ('Finnish', 150),
#  ('Helsinki', 143),
#  ('Parliament', 82),
#  ('first', 68),
#  ('two', 61),
#  ('last year', 59),
#  ('one', 55),
#  ('Tuesday', 51),
#  ('three', 51),
#  ('Wednesday', 46),
#  ('Thursday', 43),
#  ('SDP', 40),
#  ('Friday', 40),
#  ('Turku', 39),
#  ('Monday', 36),
#  ('Saturday', 36),
#  ('2019', 35),
#  ('EU', 33),
#  ('AstraZeneca', 32)]

# %% [markdown]
# # Ex 2
#
# Find sentences in which a place name (like "Finland") is subject of a verb.
#
# You can solve this either with or without a `DepencencyMatcher`.

# %%
# Without DependencyMatcher
for d in docs:
    for tok in d:
        if tok.dep_ == 'nsubj' and tok.ent_type_ == 'GPE':
            print(' '.join(str(t) for t in tok.subtree), tok.head, tok.sent)
# Out:
# the City of Espoo issued Following a spike in quarantine rule breakers, the City of Espoo has issued a warning that breaking quarantine orders is punishable by law.
#
# Finland take
# The paper's numbers are based on an estimate from the Institute for Health and Welfare (THL) which assumes Finland will take delivery of 5.5 million doses of the vaccine by June this year.
# Finland is According to current estimates--and pending Parliamentary approval of the arrangement--Finland is to receive a total of around 2.9 billion euros out of the EU's 750 billion euro stimulus package over the next few years.
# Finland made According to the Minister of the Environment and Climate Change, Krista Mikkonen (Green), the green transition funding would be the largest single climate investment that Finland has ever made.
#
# Finland receive In total, Finland can receive about 3 billion in grants.
# Finland facing Like other EU states, Finland is facing an EU deadline at the end of April to present plans on how plans to use the funds.
#
#  Finland identified
# Finland has already identified a shortage of specialists in the IT sector, healthcare and construction.
# Finland be "If jobs are not created, Finland will not be able to fully develop."
# Finland had In December last year it was reported that Finland had the lowest birth rate in the Nordic countries.
#
# Finland is Overall, HS finds that Finland is worse at employing foreign-born people than other Nordic countries, with an employment rate of 60 percent, compared to the 65-68 percent seen in Sweden, Denmark and Norway.
#
#  Markku Broas , chief physician for infectious diseases at the Lapland Hospital District , estimates
# Markku Broas, chief physician for infectious diseases at the Lapland Hospital District, estimates that in Lapland between 80 and 90 percent of people over age 80 have received at least the first shot.
# Nysse runs Föli operates in Turku, Kaarina, Raisio, Naantali, Lieto and Rusko, while Nysse runs in Tampere, Kangasala, Lempäälä, Nokia, Orivesi, Pirkkala, Vesilahti and Ylöjärvi.
# Nysse says Nysse says that the cleaning of buses has been stepped up, and that all doors are always opened at every stop to ensure good ventilation.
# Finland adopted Ever since Finland adopted the euro at the beginning of 2002, Otto ATMs only offered customers from various banks the opportunity to withdraw 20 and 50 euro notes.
# Finland ends As Finland ends the first of three weeks of partial shutdown, Ilta-Sanomat has a visual representation of what some school kids are getting for their midday meals.
# Finland done APN askedAndersson if Finland has done enough to keep schools safe, as it has not introduced mass testing.
# Finland claims Finland often claims it wants to attract people from abroad, so APN asked Andersson if the education system was prepared to welcome international families.
# Kataja played In 2018-19, Kataja played a key role in a process whereby Torssonen was first barred from running as a Finns Party parliamentary candidate and then expelled from the party.
# Kataja reported The court said it is clear that last summer's attack by two men took place as Kataja reported, and that the act likely had a political motive.
# Russia are Boat trips along the waterways of St Petersburg, Russia are popular tourist attractions.
# The Port held The Port has held preliminary talks with ferry operators interested in the route, but plans are still at an early stage, Kuitunen said.
# Kotka and Hamina have Although Kotka and Hamina have very busy shipping ports, passenger traffic has been rare, as the few attempts at opening new passenger routes have been unsuccessful in recent decades.
# Jäske encountered That series of events is just one example of the microaggressions that Jäske has encountered her whole life.
# Ojala lived Ojala has lived in Finland her whole life, with her Finnish mother and Thai father.
#
# Ojala met At university Ojala met others who had lived through similar experiences.
# Ojala created Together with Alice Jäske and Priska Niemi-Sampan, Ojala created "Mixed Finns", an Instagram account which aims to provide support and information about being a mixed-race Finn.
#
# Finland continue The health agency said Finland would continue to use the vaccine, despite that several countries have suspended its use due to concerns about blod clots in a small number of people who received the jab.
# Norway and Denmark suspended Norway and Denmark also suspended use of the vaccine last week due to side effect concerns.
#
# The City of Helsinki announced The City of Helsinki has announced the winners of its million-euro Helsinki Energy Challenge.
#
# Finland received How many vaccine doses has Finland received so far?
#
# Finland administering THL estimates that Finland could be administering up to 600,000 vaccines weekly by this summer.
# Finland purchased MK: It doesn't play an especially significant role, mainly because Finland has not purchased much of it.
# Finland bought Finland has bought 2.4 million doses, compared to 6.2 million of the Biontech-Pfizer vaccine.
# Finland ordered Why has Finland ordered more vaccine doses than it needs?
#
# Finland taken MK: Finland has taken part in all the European Union's joint procurements.
# Finland increase An increasing number of crisis management operations are in Africa, and Finland should also increase its participation on the continent, a cross-party parliamentary committee outlines in a report published on Wednesday.
# Finland emphasised Finland has traditionally emphasised that it participates in operations that aim to make Europe's immediate vicinity safer.
# Finland participates Most Finnish soldiers are currently stationed in the Middle East, where Finland participates in conflict resolution operations in Lebanon, Iraq and Afghanistan, for example.
# Sillanaukee said "The people in charge there have pointed out that no such agreements have yet been concluded, and in any case it would require the approval of the European Medicines Agency (EMA) and a wide range of other approvals from the pharmaceutical authorities in each country," Sillanaukee said, adding that Russia is testing the reaction of other countries with the announcement of the agreements.
#
# Russia testing "The people in charge there have pointed out that no such agreements have yet been concluded, and in any case it would require the approval of the European Medicines Agency (EMA) and a wide range of other approvals from the pharmaceutical authorities in each country," Sillanaukee said, adding that Russia is testing the reaction of other countries with the announcement of the agreements.
#
# the US , Canada and the Netherlands compared Additionally, the US, Canada and the Netherlands have compared China's activities in the region to acts of genocide.
#
# Helsinki and Turku see During the spring season Helsinki and Turku usually see an average of more than 2,000 home sales per month, and those cities are expected to be first to face lockdown rules.
# Mannerberg explained "Last year many people who were in the market for a cottage couldn't find what they wanted, so this spring lots of buyers are expected," Mannerberg explained in a statement, noting that restrictions on movement would likely significantly delay the summer cottage sales season.
# Russia exported Russia has also exported the vaccine abroad including to EU states Hungary and the Czech Republic.
# Russia faced Like other coronavirus vaccine producers, Russia has faced slowdowns due to production difficulties, as the country does not have the capacity to make large quantities of the vaccines itself.
# South Karelia District Court sentenced South Karelia District Court has sentenced a man to almost two years in jail for his part in a 2019 raid on a Lappeenranta jewellery store.
# Finland achieve The centre-left cabinet has pledged that Finland will achieve carbon neutrality by 2035.
# pollster Taloustutkimus carried The SDP started the municipal election campaign as the most popular party when pollster Taloustutkimus carried out its first municipal election survey of the year in January.
# Finland fallen "Finland has fallen into the so-called growth trap.
# Finland saw "Last year, prices were negative on three occasions, and last February was the first time in history that Finland saw negative electricity prices," he said.
# State - owned energy company Fortum , which runs Finland ’s sole plastics recycling facility in Riihimäki , recycles State-owned energy company Fortum, which runs Finland’s sole plastics recycling facility in Riihimäki, only recycles around a third of all incoming plastic waste, according to Yle investigative programme MOT.
# Fortum said Over the past few years, Fortum has said that 75 percent of the household plastic waste it processes is recycled into new raw material--a statement the company still made on its website in January.
# Fortum sells At the Riihimäki plant, household plastic passes through several processing stages, ending in plastic pellets that Fortum sells to manufacturers as raw material.
#
# Finland ships Fortum previously said it lacked the capacity to process all of the sorted plastic arriving in Riihimäki, which is why Finland ships some household plastic waste to Sweden and Germany.
# " Lapland , particularly in the west see "Lapland, particularly in the west, can see up to 10 centimeters of snow," he said.
# southern Finland expect But one thing is sure, which is that we’ve yet to see the last of the spring snow," Huutonen said, adding that southern Finland can still expect overnight subzero temperatures.
# Finland recorded Finland recorded some 302 new Covid infections on Sunday.
# Kuortane require Whereas for an ordinary detached house just one borehole would be needed, Kuortane will require 104 of them, all drilled to a depth of more than 200 metres.
# Gal tweeted "This means that if you have a Facebook account, it is extremely likely the phone number used for the account was leaked," tweeted Gal.
# Vehviläinen wrote
#
# In her own tweet, Vehviläinen wrote that threats of violence are always to be condemned.
# Marin answered Yle asked the Prime Minister for an interview, and Marin answered the questions in writing.
# Marin wrote "As Prime Minister, I stand behind the government's proposals and I value the work that our office is doing in a very difficult situation and under a lot of time pressure," Marin wrote.
# Marin wrote We would also need to determine a schedule for submitting the proposal," Marin wrote.
# Finland slipping "Finland is slipping away from the other Nordic countries as it falls further into debt.
# Finland distributes
# Cavaleri's statement will have no immediate effect on how Finland distributes the AstraZeneca vaccine, according to Hanna Nohynek, head of the vaccine unit at the Finnish Institute for Health and Welfare THL.
# Finland follow "For the time being, Finland will follow the precautionary recommendation that the use of AstraZeneca be restricted to people aged 65 and over, because no such rare side effects have been observed in that age group," Nohynek said.
# Finland remains Anttila says that although air quality routinely deteriorates in spring, Finland still remains a top contender for the cleanest air in Europe.
# Finland and Indonesia co Finland and Indonesia co-chair the group, which commits its members to a set of ideas known as the Helsinki Principles.
# Finland received While the Amnesty report highlighted that domestic violence against women had grown worldwide during the pandemic, Finland received specific criticism for what Amnesty called a lack of long-term support for victims of sexual violence.
# Marin added However, Turun Sanomat notes that Marin added that it is not yet possible to give any exact date for a return to normal.
#
#  Ilta - Sanomat reports Posti loses client
# Ilta-Sanomat reports that Finland's National Archives has announced it is terminating cooperation with the Finnish postal service Posti, after an incident in which the company said it had lost a shipment of archive materials.
# Vainikka says After that, all the climate benefits basically fall into your lap when this disconnection can be accomplished," says Vainikka.
# Marin said We also do not have legislation to ban those who have not been vaccinated from using services," said Marin.
# Finland preparing Finland is preparing for the Finnish vaccine passport to be ready by the end of the summer.
# Finland be The All Points North podcast investigated last year if Finland be a global telecommuting haven.
# Marin highlighted Marin also highlighted actions against bullying and violence.
# Marin held Finland's longest serving female PM, Marin has held the office since December 2019, becoming party chair last August.
# Henriksson , 57 is Henriksson, 57, is one of Finland's longest-serving justice ministers, having held the post in three cabinets, from 2011 to 2015 and again since mid-2019.
# Jukkola says We get food for them during the quarantine period, when they stay in their own premises," says Jukkola.
# Jukkola says Jukkola says that this year each farm must draw up a health and safety plan together with the chief infection doctor of the local hospital district.
# Finland has According to estimates from hospital districts around the country, Finland has the capacity to administer up to 600,000 doses of the coronavirus vaccine per week.
# Finland administer In May, Finland will administer around 300,000 jabs per week, Kontio said.
# Finland expecting Kontio said Finland is expecting to receive about 20,000 doses of the Johnsson & Johnsson jabs per week by the end of this month.
#
# Finland stop Kontio said that if the group recommends that AstraZeneca's vaccine be limited to people over the age of 65, it is likely that Finland would soon stop using it.
#
# Finland target There has also been discussion about whether Finland should target vaccinations regionally, to areas hardest-hit by the epidemic, but a final decision has not yet been made.
# Finland recorded Finland recorded 5,973 new coronavirus cases over the past two weeks, which is 3,102 fewer cases seen during the previous fortnight, according to the data.
#
# Moderna and Johnson & Johnson testing Meanwhile, Moderna and Johnson & Johnson are also testing their respective coronavirus vaccines on children and youths.

# %%
# With DependencyMatcher
pattern = [
    {'RIGHT_ID': 'subject',
     'RIGHT_ATTRS': {'DEP': 'nsubj', 'ENT_TYPE': 'GPE'}}
]
matcher = spacy.matcher.DependencyMatcher(nlp.vocab)
matcher.add('pattern', [pattern])
for d in docs:
    for m_id, tok_index in matcher(d):
        print(' '.join(str(t) for t in d[tok_index[0]].subtree), d[tok_index[0]].sent)
        #print(m_id, tok_index, d[tok_index[0]], d[tok_index[0]].sent)
# Out:
# the City of Espoo Following a spike in quarantine rule breakers, the City of Espoo has issued a warning that breaking quarantine orders is punishable by law.
#
# Finland
# The paper's numbers are based on an estimate from the Institute for Health and Welfare (THL) which assumes Finland will take delivery of 5.5 million doses of the vaccine by June this year.
# Finland According to current estimates--and pending Parliamentary approval of the arrangement--Finland is to receive a total of around 2.9 billion euros out of the EU's 750 billion euro stimulus package over the next few years.
# Finland According to the Minister of the Environment and Climate Change, Krista Mikkonen (Green), the green transition funding would be the largest single climate investment that Finland has ever made.
#
# Finland In total, Finland can receive about 3 billion in grants.
# Finland Like other EU states, Finland is facing an EU deadline at the end of April to present plans on how plans to use the funds.
#
#  Finland
# Finland has already identified a shortage of specialists in the IT sector, healthcare and construction.
# Finland "If jobs are not created, Finland will not be able to fully develop."
# Finland In December last year it was reported that Finland had the lowest birth rate in the Nordic countries.
#
# Finland Overall, HS finds that Finland is worse at employing foreign-born people than other Nordic countries, with an employment rate of 60 percent, compared to the 65-68 percent seen in Sweden, Denmark and Norway.
#
#  Markku Broas , chief physician for infectious diseases at the Lapland Hospital District ,
# Markku Broas, chief physician for infectious diseases at the Lapland Hospital District, estimates that in Lapland between 80 and 90 percent of people over age 80 have received at least the first shot.
# Nysse Föli operates in Turku, Kaarina, Raisio, Naantali, Lieto and Rusko, while Nysse runs in Tampere, Kangasala, Lempäälä, Nokia, Orivesi, Pirkkala, Vesilahti and Ylöjärvi.
# Nysse Nysse says that the cleaning of buses has been stepped up, and that all doors are always opened at every stop to ensure good ventilation.
# Finland Ever since Finland adopted the euro at the beginning of 2002, Otto ATMs only offered customers from various banks the opportunity to withdraw 20 and 50 euro notes.
# Finland As Finland ends the first of three weeks of partial shutdown, Ilta-Sanomat has a visual representation of what some school kids are getting for their midday meals.
# Finland APN askedAndersson if Finland has done enough to keep schools safe, as it has not introduced mass testing.
# Finland Finland often claims it wants to attract people from abroad, so APN asked Andersson if the education system was prepared to welcome international families.
# Kataja In 2018-19, Kataja played a key role in a process whereby Torssonen was first barred from running as a Finns Party parliamentary candidate and then expelled from the party.
# Kataja The court said it is clear that last summer's attack by two men took place as Kataja reported, and that the act likely had a political motive.
# Russia Boat trips along the waterways of St Petersburg, Russia are popular tourist attractions.
# The Port The Port has held preliminary talks with ferry operators interested in the route, but plans are still at an early stage, Kuitunen said.
# Kotka and Hamina Although Kotka and Hamina have very busy shipping ports, passenger traffic has been rare, as the few attempts at opening new passenger routes have been unsuccessful in recent decades.
# Jäske That series of events is just one example of the microaggressions that Jäske has encountered her whole life.
# Ojala Ojala has lived in Finland her whole life, with her Finnish mother and Thai father.
#
# Ojala At university Ojala met others who had lived through similar experiences.
# Ojala Together with Alice Jäske and Priska Niemi-Sampan, Ojala created "Mixed Finns", an Instagram account which aims to provide support and information about being a mixed-race Finn.
#
# Finland The health agency said Finland would continue to use the vaccine, despite that several countries have suspended its use due to concerns about blod clots in a small number of people who received the jab.
# Norway and Denmark Norway and Denmark also suspended use of the vaccine last week due to side effect concerns.
#
# The City of Helsinki The City of Helsinki has announced the winners of its million-euro Helsinki Energy Challenge.
#
# Finland How many vaccine doses has Finland received so far?
#
# Finland THL estimates that Finland could be administering up to 600,000 vaccines weekly by this summer.
# Finland MK: It doesn't play an especially significant role, mainly because Finland has not purchased much of it.
# Finland Finland has bought 2.4 million doses, compared to 6.2 million of the Biontech-Pfizer vaccine.
# Finland Why has Finland ordered more vaccine doses than it needs?
#
# Finland MK: Finland has taken part in all the European Union's joint procurements.
# Finland According to the paper, Finland has the lowest proportion of patients in ICU with Covid-19 of any of the 18 European countries monitored by the European Centre for Disease Prevention and Control (ECDC).
# Finland Finland currently has 0.5 coronavirus patients in intensive care per 100,000 residents, HS notes.
# Finland SCMP noted that since 2017, Finland had exported roughly 311 million euros worth of the pulp to the region, according to Chinese customs data.
# China China has denied the allegations of forced labour and human rights violations.
# China In a tweet in February, Finnish Prime Minister Sanna Marin (SDP), said that China had violated human rights and oppressed minorities, adding that doing business "was no reason to turn a blind eye to these atrocities."
# the US , Canada and the Netherlands Additionally, the US, Canada and the Netherlands have compared China's activities in the region to acts of genocide.
#
# Helsinki and Turku During the spring season Helsinki and Turku usually see an average of more than 2,000 home sales per month, and those cities are expected to be first to face lockdown rules.
# Mannerberg "Last year many people who were in the market for a cottage couldn't find what they wanted, so this spring lots of buyers are expected," Mannerberg explained in a statement, noting that restrictions on movement would likely significantly delay the summer cottage sales season.
# Russia Russia has also exported the vaccine abroad including to EU states Hungary and the Czech Republic.
# Russia Like other coronavirus vaccine producers, Russia has faced slowdowns due to production difficulties, as the country does not have the capacity to make large quantities of the vaccines itself.
# South Karelia District Court South Karelia District Court has sentenced a man to almost two years in jail for his part in a 2019 raid on a Lappeenranta jewellery store.
# Finland The centre-left cabinet has pledged that Finland will achieve carbon neutrality by 2035.
# pollster Taloustutkimus The SDP started the municipal election campaign as the most popular party when pollster Taloustutkimus carried out its first municipal election survey of the year in January.
# Finland "Finland has fallen into the so-called growth trap.
# Finland "Last year, prices were negative on three occasions, and last February was the first time in history that Finland saw negative electricity prices," he said.
# State - owned energy company Fortum , which runs Finland ’s sole plastics recycling facility in Riihimäki , State-owned energy company Fortum, which runs Finland’s sole plastics recycling facility in Riihimäki, only recycles around a third of all incoming plastic waste, according to Yle investigative programme MOT.
# Fortum Over the past few years, Fortum has said that 75 percent of the household plastic waste it processes is recycled into new raw material--a statement the company still made on its website in January.
# Fortum At the Riihimäki plant, household plastic passes through several processing stages, ending in plastic pellets that Fortum sells to manufacturers as raw material.
#
# Finland Fortum previously said it lacked the capacity to process all of the sorted plastic arriving in Riihimäki, which is why Finland ships some household plastic waste to Sweden and Germany.
# " Lapland , particularly in the west "Lapland, particularly in the west, can see up to 10 centimeters of snow," he said.
# southern Finland But one thing is sure, which is that we’ve yet to see the last of the spring snow," Huutonen said, adding that southern Finland can still expect overnight subzero temperatures.
# Finland Finland recorded some 302 new Covid infections on Sunday.
# Kuortane Whereas for an ordinary detached house just one borehole would be needed, Kuortane will require 104 of them, all drilled to a depth of more than 200 metres.
# Gal "This means that if you have a Facebook account, it is extremely likely the phone number used for the account was leaked," tweeted Gal.
# Vehviläinen
#
# In her own tweet, Vehviläinen wrote that threats of violence are always to be condemned.
# Marin Yle asked the Prime Minister for an interview, and Marin answered the questions in writing.
# Marin "As Prime Minister, I stand behind the government's proposals and I value the work that our office is doing in a very difficult situation and under a lot of time pressure," Marin wrote.
# Marin We would also need to determine a schedule for submitting the proposal," Marin wrote.
# Finland "Finland is slipping away from the other Nordic countries as it falls further into debt.
# Finland
# Cavaleri's statement will have no immediate effect on how Finland distributes the AstraZeneca vaccine, according to Hanna Nohynek, head of the vaccine unit at the Finnish Institute for Health and Welfare THL.
# Finland "For the time being, Finland will follow the precautionary recommendation that the use of AstraZeneca be restricted to people aged 65 and over, because no such rare side effects have been observed in that age group," Nohynek said.
# Finland Anttila says that although air quality routinely deteriorates in spring, Finland still remains a top contender for the cleanest air in Europe.
# Finland and Indonesia Finland and Indonesia co-chair the group, which commits its members to a set of ideas known as the Helsinki Principles.
# Finland While the Amnesty report highlighted that domestic violence against women had grown worldwide during the pandemic, Finland received specific criticism for what Amnesty called a lack of long-term support for victims of sexual violence.
# Marin However, Turun Sanomat notes that Marin added that it is not yet possible to give any exact date for a return to normal.
#
#  Ilta - Sanomat Posti loses client
# Ilta-Sanomat reports that Finland's National Archives has announced it is terminating cooperation with the Finnish postal service Posti, after an incident in which the company said it had lost a shipment of archive materials.
# Vainikka After that, all the climate benefits basically fall into your lap when this disconnection can be accomplished," says Vainikka.
# Marin We also do not have legislation to ban those who have not been vaccinated from using services," said Marin.
# Finland Finland is preparing for the Finnish vaccine passport to be ready by the end of the summer.
# Finland The All Points North podcast investigated last year if Finland be a global telecommuting haven.
# Marin Marin also highlighted actions against bullying and violence.
# Marin Finland's longest serving female PM, Marin has held the office since December 2019, becoming party chair last August.
# Henriksson , 57 Henriksson, 57, is one of Finland's longest-serving justice ministers, having held the post in three cabinets, from 2011 to 2015 and again since mid-2019.
# Jukkola We get food for them during the quarantine period, when they stay in their own premises," says Jukkola.
# Jukkola Jukkola says that this year each farm must draw up a health and safety plan together with the chief infection doctor of the local hospital district.
# Finland According to estimates from hospital districts around the country, Finland has the capacity to administer up to 600,000 doses of the coronavirus vaccine per week.
# Finland In May, Finland will administer around 300,000 jabs per week, Kontio said.
# Finland Kontio said Finland is expecting to receive about 20,000 doses of the Johnsson & Johnsson jabs per week by the end of this month.
#
# Finland Kontio said that if the group recommends that AstraZeneca's vaccine be limited to people over the age of 65, it is likely that Finland would soon stop using it.
#
# Finland There has also been discussion about whether Finland should target vaccinations regionally, to areas hardest-hit by the epidemic, but a final decision has not yet been made.
# Finland Finland recorded 5,973 new coronavirus cases over the past two weeks, which is 3,102 fewer cases seen during the previous fortnight, according to the data.
#
# Moderna and Johnson & Johnson Meanwhile, Moderna and Johnson & Johnson are also testing their respective coronavirus vaccines on children and youths.

# %% [markdown]
# ## Ex 3
#
# Using a `DependencyMatcher`, find all instances of a person related to an organization. We will look for the following structures in the dependency tree:
# * a named entity of type `ORG`,
# * a named entity of type `PERSON` contained in the **subtree** of the above, i.e. being its descendent, but not necessarily immediate descendent.
# For every matches, print the document ID, positions of the matching tokens, the matched tokens (organization and person) and the sentence where they occur.
#
# The results might look poor because of the many errors of both parsing and named entity recognition.

# %%
pattern = [
    # organization name
    {'RIGHT_ID': 'organization',
     'RIGHT_ATTRS': {'ENT_TYPE': 'ORG'}},
    # person name
    {'LEFT_ID': 'organization',
     'REL_OP': '>>',
     'RIGHT_ID': 'person',
     'RIGHT_ATTRS': {'ENT_TYPE': 'PERSON'}}
]
matcher = spacy.matcher.DependencyMatcher(nlp.vocab)
matcher.add('pattern', [pattern])
for d in docs:
    for m_id, tok_idx in matcher(d):
            print(m_id, tok_idx, d[tok_idx[0]], d[tok_idx[1]])
            print(d[tok_idx[0]].sent)
            print()
# Out:
# 15329811787164753587 [693, 695] Services Migri
# The offices of the Finnish Immigration Services, Migri.
#
# 15329811787164753587 [140, 142] Vantaa Kaunianen
# In Helsinki, Espoo, Vantaa and Kaunianen, incoming people with a native language other than Finnish, Swedish or Sámi accounted for 70 percent of population growth between 2015 and 2019.
#
# 15329811787164753587 [209, 217] Nokia Ylöjärvi
# Föli operates in Turku, Kaarina, Raisio, Naantali, Lieto and Rusko, while Nysse runs in Tampere, Kangasala, Lempäälä, Nokia, Orivesi, Pirkkala, Vesilahti and Ylöjärvi.
#
# 15329811787164753587 [128, 137] Pirkanmaa Ostrobothnia
# A similar trend was also observed at Finland's largest laboratory firm, Fimlab, which tests and analyses samples in the regions of Pirkanmaa, Central Finland, Kanta-Häme, Ostrobothnia and Päijät-Häme.
#
# 15329811787164753587 [131, 137] Finland Ostrobothnia
# A similar trend was also observed at Finland's largest laboratory firm, Fimlab, which tests and analyses samples in the regions of Pirkanmaa, Central Finland, Kanta-Häme, Ostrobothnia and Päijät-Häme.
#
# 15329811787164753587 [13, 15] Institution Kela
# Finland's new 'baby box' was unveiled by the Social Insurance Institution (Kela) on Friday.
#
# 15329811787164753587 [153, 167] Torssonen Torssonen
# A fake package apparently used as a pretext for gaining access to Kataja's home was found to bear fingerprints from Torssonen and the other suspect, who is a friend and political supporter of Torssonen's.
#
# 15329811787164753587 [176, 180] Hämeenlinnanväylä Lahdenväylä
# Buses running along main rail routes, as well as on Hämeenlinnanväylä, Tuusulanväylä and Lahdenväylä were heavily congested.
#
# 15329811787164753587 [47, 53] Helsinki Kauniainen
# The restrictions would apply to Helsinki, Espoo, Vantaa, Kauniainen and Turku.
#
# 15329811787164753587 [49, 53] Espoo Kauniainen
# The restrictions would apply to Helsinki, Espoo, Vantaa, Kauniainen and Turku.
#
# 15329811787164753587 [194, 199] Party Left
# The submission to parliament comes after the parliamentary groups of three of the government’s coalition parties — the Swedish People’s Party, Green Party and Left Alliance — decided to support the bill after each holding marathon talks on Wednesday evening.
#
# 15329811787164753587 [194, 200] Party Alliance
# The submission to parliament comes after the parliamentary groups of three of the government’s coalition parties — the Swedish People’s Party, Green Party and Left Alliance — decided to support the bill after each holding marathon talks on Wednesday evening.
#
# 15329811787164753587 [197, 199] Party Left
# The submission to parliament comes after the parliamentary groups of three of the government’s coalition parties — the Swedish People’s Party, Green Party and Left Alliance — decided to support the bill after each holding marathon talks on Wednesday evening.
#
# 15329811787164753587 [197, 200] Party Alliance
# The submission to parliament comes after the parliamentary groups of three of the government’s coalition parties — the Swedish People’s Party, Green Party and Left Alliance — decided to support the bill after each holding marathon talks on Wednesday evening.
#
#
# 15329811787164753587 [187, 189] Party Ano
# In addition to the Finns Party, only the National Coalition Party and Ano Turtiainen, a lone MP expelled from the Finns Party, supported the no-confidence motion.
#
# 15329811787164753587 [187, 190] Party Turtiainen
# In addition to the Finns Party, only the National Coalition Party and Ano Turtiainen, a lone MP expelled from the Finns Party, supported the no-confidence motion.
#
# 15329811787164753587 [259, 261] Viikari Mikko
# That was the result of an agreement between Yli-Viikari and Mikko Koiranen, VTV's Director of Legal Affairs, which resulted in both civil servants receiving a warning from the Parliamentary Ombudsman.
#
# 15329811787164753587 [259, 262] Viikari Koiranen
# That was the result of an agreement between Yli-Viikari and Mikko Koiranen, VTV's Director of Legal Affairs, which resulted in both civil servants receiving a warning from the Parliamentary Ombudsman.
#
# 15329811787164753587 [23, 30] Party Sanna
# The Social Democratic Party (SDP) of Prime Minister Sanna Marin dropped from first to third place in March, falling behind the main opposition blocs, the Finns Party and the National Coalition Party (NCP).
#
# 15329811787164753587 [23, 31] Party Marin
# The Social Democratic Party (SDP) of Prime Minister Sanna Marin dropped from first to third place in March, falling behind the main opposition blocs, the Finns Party and the National Coalition Party (NCP).
#
# 15329811787164753587 [516, 523] Confederation Antti
# The article quotes Finnish Confederation of Professionals (STTK) economist Antti Koskela, who says the government should aim to support the growth of cities across the country as rapid growth in big cities raises house prices and increases regional divides.
#
# 15329811787164753587 [516, 524] Confederation Koskela
# The article quotes Finnish Confederation of Professionals (STTK) economist Antti Koskela, who says the government should aim to support the growth of cities across the country as rapid growth in big cities raises house prices and increases regional divides.
#
# 15329811787164753587 [517, 523] of Antti
# The article quotes Finnish Confederation of Professionals (STTK) economist Antti Koskela, who says the government should aim to support the growth of cities across the country as rapid growth in big cities raises house prices and increases regional divides.
#
# 15329811787164753587 [517, 524] of Koskela
# The article quotes Finnish Confederation of Professionals (STTK) economist Antti Koskela, who says the government should aim to support the growth of cities across the country as rapid growth in big cities raises house prices and increases regional divides.
#
# 15329811787164753587 [154, 155] Managing DirectorAki
# In addition, Finland is weighed down by a zero-interest liquidity trap, where monetary policy makes it difficult to revive the economy," said Etla Managing DirectorAki Kangasharju in a press release.
#
# 15329811787164753587 [154, 156] Managing Kangasharju
# In addition, Finland is weighed down by a zero-interest liquidity trap, where monetary policy makes it difficult to revive the economy," said Etla Managing DirectorAki Kangasharju in a press release.
#
# 15329811787164753587 [125, 130] Apprentice Donald
#
#
# Harkimo, a businessman and media personality, said he did not identify with the most famous presenter of The Apprentice, former US President Donald Trump.
#
# 15329811787164753587 [125, 131] Apprentice Trump
#
#
# Harkimo, a businessman and media personality, said he did not identify with the most famous presenter of The Apprentice, former US President Donald Trump.
# 15329811787164753587 [143, 153] AstraZeneca Pfizer
# The City of Helsinki currently uses two different vaccines, AstraZeneca for those over the age of 65, and Pfizer, which is given to people between the ages of 16-64.
#
# 15329811787164753587 [60, 62] Merimasku Naantali
# On Tamsaari farm in Merimasku, Naantali, where four workers from the first flight are already settling into their routines, another Covid test was issued a few days later, explains owner Stiina Lerkki.
#
#
# 15329811787164753587 [304, 306] Wallend Scott
# Of the other respondents who committed serious drug offenses, Krister Wallend and Scott Hendry were sentenced to 10 years, ex-Cannonball leader Ari Ronkainen to 9 and a half years, Juho Kieloniemi to 9 years 4 months, Matias Palmroth to just over 9 years, and Oscar Fagerström and Jarkko Hietikko to 8 years in prison.
#
# 15329811787164753587 [304, 307] Wallend Hendry
# Of the other respondents who committed serious drug offenses, Krister Wallend and Scott Hendry were sentenced to 10 years, ex-Cannonball leader Ari Ronkainen to 9 and a half years, Juho Kieloniemi to 9 years 4 months, Matias Palmroth to just over 9 years, and Oscar Fagerström and Jarkko Hietikko to 8 years in prison.
#
# 15329811787164753587 [236, 238] Sitra Saara
# However a leading expert at Sitra, Saara Tamminen, said just because it is possible to combine improved climate and economic goals, it does not mean that economic growth can continue the way it has to date.
#
# 15329811787164753587 [236, 239] Sitra Tamminen
# However a leading expert at Sitra, Saara Tamminen, said just because it is possible to combine improved climate and economic goals, it does not mean that economic growth can continue the way it has to date.
#
# 15329811787164753587 [7, 2] Party Sanna
# Prime Minister Sanna Marin's Social Democratic Party (SDP) has unveiled its agenda in the run-up to local elections in June.
#
# 15329811787164753587 [7, 3] Party Marin
# Prime Minister Sanna Marin's Social Democratic Party (SDP) has unveiled its agenda in the run-up to local elections in June.
#
# 15329811787164753587 [400, 402] Kekkonen Tarja
# Her predecessors in the post include three presidents: Urho Kekkonen, Tarja Halonen and the incumbent, Sauli Niinistö.
#
# 15329811787164753587 [400, 403] Kekkonen Halonen
# Her predecessors in the post include three presidents: Urho Kekkonen, Tarja Halonen and the incumbent, Sauli Niinistö.

# %%
# Out:
# 8 693 695
# Services Migri
# The offices of the Finnish Immigration Services, Migri.
#
# 12 140 142
# Vantaa Kaunianen
# In Helsinki, Espoo, Vantaa and Kaunianen, incoming people with a native language other than Finnish, Swedish or Sámi accounted for 70 percent of population growth between 2015 and 2019.
#
# 17 209 217
# Nokia Ylöjärvi
# Föli operates in Turku, Kaarina, Raisio, Naantali, Lieto and Rusko, while Nysse runs in Tampere, Kangasala, Lempäälä, Nokia, Orivesi, Pirkkala, Vesilahti and Ylöjärvi.
#
# 19 128 137
# Pirkanmaa Ostrobothnia
# A similar trend was also observed at Finland's largest laboratory firm, Fimlab, which tests and analyses samples in the regions of Pirkanmaa, Central Finland, Kanta-Häme, Ostrobothnia and Päijät-Häme.
#
# 19 131 137
# Finland Ostrobothnia
# A similar trend was also observed at Finland's largest laboratory firm, Fimlab, which tests and analyses samples in the regions of Pirkanmaa, Central Finland, Kanta-Häme, Ostrobothnia and Päijät-Häme.
#
# 24 13 15
# Institution Kela
# Finland's new 'baby box' was unveiled by the Social Insurance Institution (Kela) on Friday.
#
# 29 153 167
# Torssonen Torssonen
# A fake package apparently used as a pretext for gaining access to Kataja's home was found to bear fingerprints from Torssonen and the other suspect, who is a friend and political supporter of Torssonen's.
#
# 45 176 180
# Hämeenlinnanväylä Lahdenväylä
#
# 92 469 477
# of Pimiä
#
# Article continues after photo
# Kirsi Pimiä, Permanent Secretary of the Ministry of the InteriorYle/Anna Savonius
# Kirsi Pimiä, Permanent Secretary of the Ministry of the Interior, said on Wednesday that the current number of police officers would be insufficient to enforce the planned restrictions on movement.
#
# 96 294 300
# Helsinki Kauniainen
# The measures would affect five cities: Helsinki, Espoo, Vantaa, Kauniainen and Turku.
#
# 96 296 300
# Espoo Kauniainen
# The measures would affect five cities: Helsinki, Espoo, Vantaa, Kauniainen and Turku.
#
# 97 2 7
# Party Petteri
# National Coalition Party (NCP) leader Petteri Orpo told the All Points North podcast that his party did not support curfews as opposition parties had been excluded from government negotiations on new restrictions to curb the spread of coronavirus in Finland.
#
#
# 97 2 8
# Party Orpo
# National Coalition Party (NCP) leader Petteri Orpo told the All Points North podcast that his party did not support curfews as opposition parties had been excluded from government negotiations on new restrictions to curb the spread of coronavirus in Finland.
#
#
# 106 187 189
# Party Ano
# In addition to the Finns Party, only the National Coalition Party and Ano Turtiainen, a lone MP expelled from the Finns Party, supported the no-confidence motion.
#
# 106 187 190
# Party Turtiainen
# In addition to the Finns Party, only the National Coalition Party and Ano Turtiainen, a lone MP expelled from the Finns Party, supported the no-confidence motion.
#
# 120 259 261
# Viikari Mikko
# That was the result of an agreement between Yli-Viikari and Mikko Koiranen, VTV's Director of Legal Affairs, which resulted in both civil servants receiving a warning from the Parliamentary Ombudsman.
#
# 120 259 262
# Viikari Koiranen
# That was the result of an agreement between Yli-Viikari and Mikko Koiranen, VTV's Director of Legal Affairs, which resulted in both civil servants receiving a warning from the Parliamentary Ombudsman.
#
# 144 23 30
# Party Sanna
# The Social Democratic Party (SDP) of Prime Minister Sanna Marin dropped from first to third place in March, falling behind the main opposition blocs, the Finns Party and the National Coalition Party (NCP).
#
# 144 23 31
# Party Marin
# The Social Democratic Party (SDP) of Prime Minister Sanna Marin dropped from first to third place in March, falling behind the main opposition blocs, the Finns Party and the National Coalition Party (NCP).
#
# 145 516 523
# Confederation Antti
# The article quotes Finnish Confederation of Professionals (STTK) economist Antti Koskela, who says the government should aim to support the growth of cities across the country as rapid growth in big cities raises house prices and increases regional divides.
#
# 145 516 524
# Confederation Koskela
# The article quotes Finnish Confederation of Professionals (STTK) economist Antti Koskela, who says the government should aim to support the growth of cities across the country as rapid growth in big cities raises house prices and increases regional divides.
#
# 145 517 523
# of Antti
# The article quotes Finnish Confederation of Professionals (STTK) economist Antti Koskela, who says the government should aim to support the growth of cities across the country as rapid growth in big cities raises house prices and increases regional divides.
#
# 145 517 524
# of Koskela
# The article quotes Finnish Confederation of Professionals (STTK) economist Antti Koskela, who says the government should aim to support the growth of cities across the country as rapid growth in big cities raises house prices and increases regional divides.
#
# 150 154 155
# Managing DirectorAki
# In addition, Finland is weighed down by a zero-interest liquidity trap, where monetary policy makes it difficult to revive the economy," said Etla Managing DirectorAki Kangasharju in a press release.
#
# 150 154 156
# Managing Kangasharju
# In addition, Finland is weighed down by a zero-interest liquidity trap, where monetary policy makes it difficult to revive the economy," said Etla Managing DirectorAki Kangasharju in a press release.
#
# 166 125 130
# Apprentice Donald
#
#
# Harkimo, a businessman and media personality, said he did not identify with the most famous presenter of The Apprentice, former US President Donald Trump.
#
# 166 125 131
# Apprentice Trump
#
#
# Harkimo, a businessman and media personality, said he did not identify with the most famous presenter of The Apprentice, former US President Donald Trump.
#
# 183 143 153
# AstraZeneca Pfizer
# The City of Helsinki currently uses two different vaccines, AstraZeneca for those over the age of 65, and Pfizer, which is given to people between the ages of 16-64.
#
# 185 60 62
# Merimasku Naantali
# On Tamsaari farm in Merimasku, Naantali, where four workers from the first flight are already settling into their routines, another Covid test was issued a few days later, explains owner Stiina Lerkki.
#
#
# 187 304 306
# Wallend Scott
# Of the other respondents who committed serious drug offenses, Krister Wallend and Scott Hendry were sentenced to 10 years, ex-Cannonball leader Ari Ronkainen to 9 and a half years, Juho Kieloniemi to 9 years 4 months, Matias Palmroth to just over 9 years, and Oscar Fagerström and Jarkko Hietikko to 8 years in prison.
#
# 187 304 307
# Wallend Hendry
# Of the other respondents who committed serious drug offenses, Krister Wallend and Scott Hendry were sentenced to 10 years, ex-Cannonball leader Ari Ronkainen to 9 and a half years, Juho Kieloniemi to 9 years 4 months, Matias Palmroth to just over 9 years, and Oscar Fagerström and Jarkko Hietikko to 8 years in prison.
#
# 199 236 238
# Sitra Saara
# However a leading expert at Sitra, Saara Tamminen, said just because it is possible to combine improved climate and economic goals, it does not mean that economic growth can continue the way it has to date.
#
# 199 236 239
# Sitra Tamminen
# However a leading expert at Sitra, Saara Tamminen, said just because it is possible to combine improved climate and economic goals, it does not mean that economic growth can continue the way it has to date.
#
# 206 7 2
# Party Sanna
# Prime Minister Sanna Marin's Social Democratic Party (SDP) has unveiled its agenda in the run-up to local elections in June.
#
# 206 7 3
# Party Marin
# Prime Minister Sanna Marin's Social Democratic Party (SDP) has unveiled its agenda in the run-up to local elections in June.
#
# 208 400 402
# Kekkonen Tarja
# Her predecessors in the post include three presidents: Urho Kekkonen, Tarja Halonen and the incumbent, Sauli Niinistö.
#
# 208 400 403
# Kekkonen Halonen
# Her predecessors in the post include three presidents: Urho Kekkonen, Tarja Halonen and the incumbent, Sauli Niinistö.
#
# 235 148 145
# Prague Kúdela
# The incident occurred during a Europa League tie between Kamara's Glasgow Rangers and Kúdela's Slavia Prague in Scotland on 18 March, when Kúdela was caught by TV cameras covering his mouth with his hand and whispering something in Kamara's ear.

# %% [markdown]
# # Optional homework

# %% [markdown]
# ## Ex 4
#
# Write the function `ent_rel(nlp, docs)` that finds occurrences of verbs for which both the subject (`nsubj`) and the direct object (`dobj`) is a named entity of one of the following types: `PERSON, GPE, LOC, ORG, NORP`. For each such occurrence, display as in the example:
# * index of the document
# * the verb
# * the subject and object in form `word:dependency_type:entity_type`
# * the entire sentence
#
# Use `DependencyMatcher`! In order to test whether a token belongs to *one of* the given named entity categories, use the construct `IN`. You will find examples here: https://spacy.io/api/matcher
#
# This can be a first step towards extracting events or relations between entities.

# %%
def ent_rel(nlp, docs):
    pattern = [
        # verb
        {'RIGHT_ID': 'verb',
         'RIGHT_ATTRS': {'POS': 'VERB'}},
        # subject
        {'LEFT_ID': 'verb',
         'REL_OP': '>',
         'RIGHT_ID': 'subject',
         'RIGHT_ATTRS': {'DEP': 'nsubj', 'ENT_TYPE': {'IN': ['PERSON', 'GPE', 'LOC', 'ORG', 'NORP']}},
        # object
        {'LEFT_ID': 'verb',
         'REL_OP': '>',
         'RIGHT_ID': 'object',
         'RIGHT_ATTRS': {'DEP': 'nsubj', 'ENT_TYPE': {'IN': ['PERSON', 'GPE', 'LOC', 'ORG', 'NORP']}}}
    ]
    matcher = spacy.matcher.DependencyMatcher(nlp.vocab)
    matcher.add('verb_with_entities', [pattern])
    for d in docs:
        for m_id, tok_idx in matcher(d):

# %%
for i, doc_ent_rel in enumerate(ent_rel(nlp, docs)):
    for toks in doc_ent_rel:
        print(i, toks[0],
              str(toks[1])+':'+toks[1].dep_+':'+toks[1].ent_type_,
              str(toks[2])+':'+toks[2].dep_+':'+toks[2].ent_type_)
        print(toks[0].sent)
        print()
# Out:
# 1 told Kalo:nsubj:PERSON HS:dobj:ORG
# "When information about [the transition to] distance learning came, we had to arrange everything at short notice," Vantaa's Director of Basic Education Ilkka Kalo told HS.
#
# 4 urged Commission:nsubj:ORG Finland:dobj:GPE
# The EU Commission has urged Finland and many other countries to focus on fewer but more effective projects.
#
# 13 won Saariaho:nsubj:PERSON Award:dobj:ORG
# Finnish composer Kaija Saariaho has won the Venice Biennale's Golden Lion Award for Lifetime Achievement.
#
# 15 told Broas:nsubj:PERSON Yle:dobj:ORG
# "A slightly larger amount of the Moderna vaccine came to Lapland than to the rest of the country, because distances are long here," Broas told Yle.
#
# 28 asked APN:nsubj:ORG Andersson:dobj:ORG
# Finland often claims it wants to attract people from abroad, so APN asked Andersson if the education system was prepared to welcome international families.
#
# 31 told Wit:nsubj:PERSON Yle:dobj:PERSON
# "I am absolutely innocent, and this [case] is revenge by politicised officials because the Laitonlehti website writes critically and very reasonably about the activities of these authorities," de Wit told Yle last October.
#
# 32 learning Ojala:nsubj:PERSON Thai:dobj:NORP
#
# 24-year-old Janina Ojala is now learning Thai from  YouTube because she didn't dare speak it as a child.
#
# 32 learning Ojala:nsubj:PERSON YouTube:dobj:ORG
#
# 24-year-old Janina Ojala is now learning Thai from  YouTube because she didn't dare speak it as a child.
#
# 35 use City:nsubj:PERSON AI:dobj:ORG
# Winning entrant Beyond Fossils proposed a model to transition Helsinki to clean energy through an auctioning system for energy producers, while Smart Salt City would use AI and a new form of limestone-based energy storage to meet the city's demands.
#
# 36 told Kivitie:nsubj:PERSON Kauppalehti:dobj:GPE
# The top floor can be reached without passing through the office space," Newsec's Jussi Kivitie told Kauppalehti.
#
# 37 told Järvinen:nsubj:PERSON Svenska:dobj:PERSON
# Now it seems that the majority of them are getting sick," HUS's chief physician of infectious diseases Asko Järvinen told Yle Svenska.
#
# 37 told Brodin:nsubj:PERSON Svenska:dobj:PERSON
# Petter Brodin, an assistant professor of immunology, told Yle Svenska that he agrees with this assessment.
#
# 52 told Kolehmainen:nsubj:PERSON Sanomat:dobj:PERSON
# Police Commissioner Kolehmainen told Helsingin Sanomat that he does not want to see a situation in which the police have to interpret the rules, or one in which police have to interrogate citizens about their comings and goings.
#
# 58 told Heinonen:nsubj:PERSON Yle:dobj:ORG
# Other protesters were supposed to remain outside the area," Police Inspector Jarmo Heinonen told Yle, saying police worried about the gathering’s health implications.
#
# 75 told Honkanen:nsubj:PERSON HS:dobj:ORG
# "If the infections have started to decrease, we will see it in around a weeks' time on the hospital wards, and in a few weeks in the ICU," HUS development director Visa Honkanen told HS.
#
# 104 found Court:nsubj:ORG Halonen:dobj:ORG
# Previously, Pirkanmaa District Court found Aatu Viljami Halonen, 20, guilty of soliciting murder and Mika Markus Aleksi Hytönen ,19, guilty of carrying out the act.
#
# 105 echoed Ohisalo:nsubj:PERSON Studio:dobj:ORG
#
# Interior minister Maria Ohisalo (Green) echoed her sentiments on Thursday night’s A-Studio, saying that there would be a rush to implement the laws before Easter.
#
# 124 quotes HS:nsubj:ORG Saarikko:dobj:NORP
# Prime Minister Sanna Marin (SDP) told Yle on Sunday that the government was ready to prioritise regions with higher infection rates, but HS quotes Centre Party leader Annika Saarikko as emphasising that at-risk groups "must be vaccinated equally nationwide."
#
# 145 told Viheltäjä:nsubj:PERSON MT:dobj:ORG
# "The parasite appears to have arrived in Finland via a cargo ship's ballast tank," expert Jaakko Viheltäjä of the Finnish Museum of Natural History told MT.
#
# 152 told Tibber:nsubj:PERSON Nyheter:dobj:PERSON
#
# Swedish energy company Tibber told Dagens Nyheter that favourable wind conditions brought electricity prices into negative territory.
#
# 162 chaired MP:nsubj:ORG Committee:dobj:ORG
# The Green Party MP has chaired the Audit Committee for two years, during which time the atmosphere at the National Audit Office has become a point of discussion.
#
#
# 177 tells Hievanen:nsubj:PERSON Yle:dobj:ORG
# Jyrki Lyytikkä / Yle
# "Poor language skills make it difficult to progress in and complete studies," FINEEC's assessment specialist Raisa Hievanen tells Yle. "
#
# 184 told Tuurnala:nsubj:PERSON Sanomat:dobj:PERSON
# Local tourism is likely to be the first to return," Tiina Tuurnala, CEO of the Finnish Shipowners' Association, told Helsingin Sanomat.
#
# 191 told Heinonen:nsubj:PERSON Yle:dobj:PERSON
# Next time, we will try to be better prepared," Helsinki Police Commissioner Jarmo Heinonen told Yle after the demonstration.
#
# 195 told Voutilainen:nsubj:PERSON Uutissuomalainen:dobj:PERSON
# Tomi Voutilainen, Professor of Pubic Law at the University of Eastern Finland, told Uutissuomalainen that it is not possible to assess the legality of keeping the correspondence classified without actually seeing the content of the emails.
#
# 213 told Kaikkonen:nsubj:PERSON Uutissuomalainen:dobj:PERSON
# Kaikkonen told Uutissuomalainen it would now be presented to Parliament in May or June.
#
# 214 launched Union:nsubj:ORG Suomesta:dobj:LOC
# The Central Union of Agricultural Producers and Forest Owners (MTK) launched its Töitä Suomesta ("Work in Finland") service for seasonal agricultural workers in early 2019.
