# %% [markdown]
# # 7. Pattern matching in dependency trees
#
# Today we will practice the ways in which dependency parsing can be used to extract complex syntactic structures from texts. SpaCy's *pattern matching* engine allows us to separate the description of the structure of interest from the code that finds it. The latter is mostly done by spaCy.
#
# We will use a new dataset consisting of YLE English news from the recent weeks.

# %%
import csv
import spacy
import spacy.matcher

# %%
def read_articles(filename):
    result = []
    with open(filename, encoding='utf-8') as fp:
        reader = csv.DictReader(fp)
        for row in reader:
            result.append(row['text'])
    return result

# %%
nlp = spacy.load('en_core_web_sm')
articles = read_articles('yle_en.csv')      # TODO supply the file path if needed
docs = [nlp(a) for a in articles]

# %%
docs[30][:50]
# Out:
# The construction of a new passenger ferry terminal in Kotka which will enable service to St. Petersburg, Russia is expected to begin this spring.
# The terminal's final design is still in progress, but building work is expected to start as early as May this year

# %%
articles[5]
# Out:
# "When the phone lines opened for a new age group to book coronavirus vaccination appointments in Oulu, more than 3,500 calls flooded in a matter of hours.\nIt's a similar situation nationwide.\nIn Helsinki people often try to make vaccination appointments ahead of time, while the majority of calls to the appointment booking service in Kainuu come from individuals not yet eligible for the jabs.\nYle gathered some of the most common questions people ask when calling the vaccination appointment lines and put them to two experts, Sirkku Kaltakari, service manager at Oulu Social and Health Services, and infectious diseases doctor Jarkko Huusko.\nHere are their answers:\n1. How do I know if it's my turn to get the vaccine?\nVaccinations are given according to a nationally-agreed schedule. The website of the Finnish Institute for Health and Welfare (THL) contains information on the order of vaccinations by age and risk groups.\nIf you can't find the information you need there, you can call your own health centre.\nStory continues after the image.\nThe current vaccination schedule according to THL. THL\n2. How was the vaccination schedule decided?\nThe schedule was decided by the National Advisory Committee on Vaccines (KRAR), which is appointed by THL and is being strictly followed.\nAge is the most significant risk factor for coronavirus, which is why the elderly are being vaccinated first.\n3. I booked an appointment online. How do I know if it worked?\nYou don't need to confirm an appointment you booked online by calling. In Oulu, for example, you can choose to receive a confirmation by email when you book your time slot.\n4. Can I get the brand of vaccine I want?\nFor now, it is not possible to choose which brand of coronavirus vaccine you will receive.\nA number of different coronavirus vaccines have been approved for use by the European Medicines Agency. Jarkko Riikonen / Yle\n5. Can a carer get vaccinated at the same time as the person they care for? \nCarers living in the same household as the person they care for can be vaccinated. The appointment for both the care giver and care receiver can be reserved at the same time. People receiving regular care at home and their carers will receive the vaccine via their home care service.\n6. Can you get vaccinated if you've already had the coronavirus? What about other illnesses or medical treatments? \nIf you've had the coronavirus you can still get the vaccine, but there's no rush to get vaccinated. It's currently thought that recovering from the illness provides protection from new infection for up to six months.\nSuffering from an infectious disease is a reason to delay vaccination. You can only get vaccinated when you're healthy and have recovered from the infection.\nAfter receiving chemotherapy it's a good idea to let your body recover for a few days so your immune system can respond to the vaccine. High-dose cortisone treatment is also a barrier to getting vaccinated.\n7. Can the vaccine give you coronavirus?\nNo it can't.\nThe vaccine may cause mild and brief symptoms near the injection site in some patients. General symptoms can include hot flushes, redness, swelling, pain or swelling of the lymph nodes.\nSome people might also experience mild general symptoms like tiredness, feeling unwell or having a temperature, according to the experts."

# %%
docs[5][0].head
# Out:
# opened

# %% [markdown]
# # In-class exercises

# %% [markdown]
# # Ex 1
#
# Write a function `verb_dep(nlp, docs, tag, dep)`, that finds all **verbs** which take a dependent of type `dep` tagged as `tag`. The function should return a list of lists of pairs of `Token` objects: the verb and its dependent. We return a list of such pairs for every article (see example).
#
# Use the function to find all instances of verbs that have a proper noun (`PROPN`) as subject (`nsubj`).
#
# Use `spacy.matcher.DependencyMatcher` for implementation. You will find the necessary documentation here:
# * https://spacy.io/api/dependencymatcher
# * https://spacy.io/api/matcher

# %%
# solution without matchers
def verb_dep(nlp, docs, tag, dep):
    # find words tagged with 'tag' whose head is a verb and whose dependency type is 'dep'
    results = []
    for d in docs:
        results_doc = []
        for tok in d:
            if tok.pos_ == tag and tok.head.pos_ == 'VERB' and tok.dep_ == 'nsubj':
                results_doc.append((tok.head, tok))
        results.append(results_doc)
    return results

# %%
# this is the proper solution to the exercise
def verb_dep(nlp, docs, tag, dep):
    pattern = [
        {'RIGHT_ID': 'verb', 
         'RIGHT_ATTRS': {'POS': 'VERB'}},
        # verb > subject
        {'LEFT_ID': 'verb',
         'RIGHT_ID': 'subject',
         'REL_OP': '>',
         'RIGHT_ATTRS': {'POS': tag, 'DEP': dep}}
    ]
    matcher = spacy.matcher.DependencyMatcher(nlp.vocab)
    matcher.add('verb_with_its_dep', [pattern])
    results = []
    for d in docs:
        results_doc = []
        for m_id, toks in matcher(d):
            results_doc.append((d[toks[0]], d[toks[1]], d[toks[2]]))
        results.append(results_doc)
    return results

# %%
# what if we wanted the verb to be additionally specified by an adverb?
# -> we don't need to change much, just add another token to the pattern
def verb_dep(nlp, docs, tag, dep):
    pattern = [
        {'RIGHT_ID': 'verb', 
         'RIGHT_ATTRS': {'POS': 'VERB'}},
        # verb > subject
        {'LEFT_ID': 'verb',
         'RIGHT_ID': 'subject',
         'REL_OP': '>',
         'RIGHT_ATTRS': {'POS': tag, 'DEP': dep}},
        # verb > adverb
        {'LEFT_ID': 'verb',
         'RIGHT_ID': 'adverb',
         'REL_OP': '>',
         'RIGHT_ATTRS': {'POS': 'ADV'}}
    ]
    matcher = spacy.matcher.DependencyMatcher(nlp.vocab)
    matcher.add('verb_with_its_dep', [pattern])
    results = []
    for d in docs:
        results_doc = []
        for m_id, toks in matcher(d):
            results_doc.append((d[toks[0]], d[toks[1]], d[toks[2]]))
        results.append(results_doc)
    return results

# %%
verb_dep(nlp, docs, 'PROPN', 'nsubj')[:2]
# Out:
# [[(employs, Nokia, currently), (employs, Nokia, worldwide)],
#  [(pick, Schoolchildren, also)]]

# %% [markdown]
# ## Ex 2

# %% [markdown]
# Use `spacy.matcher.PhraseMatcher` to find the following multi-word phrases in the corpus:
# * `"municipal elections"`
# * `"coronavirus restrictions"`

# %%
# create the `matcher` object
# matcher musí mít jméno (tady 'COVID'), jinak nebude fungovat
matcher = spacy.matcher.PhraseMatcher(nlp.vocab)
matcher.add('COVID', [nlp('municipal elections'), nlp('coronavirus restrictions')])

# %%
for i, d in enumerate(docs):
    for m in matcher(d):
        print(m)
        print(d[m[1]:m[2]])
        print(d[m[1]].sent)
        print()
# Out:
# (2428025407850408099, 251, 253)
# coronavirus restrictions
# Katri Mannonen / Yle
# Municipalities scrambled to provide food to remote learning school children as most parts of the country entered a three-week period of heightened coronavirus restrictions, starting 8 March.
#
# (2428025407850408099, 631, 633)
# municipal elections
# In addition, it was decided to postpone the municipal elections due to the difficult public health situation.
#
# (2428025407850408099, 312, 314)
# coronavirus restrictions
# Rallies against coronavirus restrictions are taking place in some 40 countries around the world on Saturday.
#
# (2428025407850408099, 76, 78)
# municipal elections
# Jussi Halla-aho, chair of the Finns Party, and the party's parliamentary group leader, Ville Tavio,on Saturday claimed Justice Minister Anna-Maja Henriksson had misled citizens and instructed municipalities to break the law in the lead-up to the decision to postpone this spring's municipal elections.
#
# (2428025407850408099, 171, 173)
# municipal elections
# On Friday, Parliament's Constitutional Law Committee unanimously approved the postponement of the municipal elections from 18 April until 13 June.
#
# (2428025407850408099, 9, 11)
# coronavirus restrictions
# According to senior police, Saturday's demonstration against coronavirus restrictions in downtown Helsinki will not set a precedent for future demonstrations.
#
# (2428025407850408099, 109, 111)
# coronavirus restrictions
# Many people on social media have questioned why the police allowed demonstrators to break current coronavirus restrictions.
#
#
# (2428025407850408099, 232, 234)
# coronavirus restrictions
# The question now is whether the protest will possibly give citizens the impression that coronavirus restrictions can be freely broken.
#
# (2428025407850408099, 25, 27)
# coronavirus restrictions
# One of the top-read stories on Finland's largest daily Helsingin Sanomat on Tuesday is experts' views on whether and when tougher coronavirus restrictions should be brought in.
#
# (2428025407850408099, 46, 48)
# municipal elections
# This is despite the fact that in the last municipal elections in 2017, more women were elected into municipal councils than ever before.
#
# (2428025407850408099, 310, 312)
# municipal elections
# Last autumn, the Association of Finnish Local and Regional Authorities investigated the reasons that affect people's willingness to run for office in municipal elections.
#
# (2428025407850408099, 71, 73)
# coronavirus restrictions
# The company said that the move was prompted by the negative economic impact of tightening coronavirus restrictions.
#
# (2428025407850408099, 103, 105)
# coronavirus restrictions
# While Stockmann's online store continues to operate, the company said the aim was to reduce the number of staff working in store in anticipation of tighter coronavirus restrictions that would prevent customers from shopping in person, as well as offsetting the loss of revenue caused by the pandemic.
#
# (2428025407850408099, 65, 67)
# municipal elections
# The Finns Party had filed the no-confidence motion against Justice Minister Anna-Maja Henriksson, claiming she had misled citizens and instructed municipalities to break the law in the lead-up to the decision to postpone this spring's municipal elections.
#
# (2428025407850408099, 78, 80)
# municipal elections
# Parliament also voted to approve the postponement of the municipal elections from 18 April until 13 June.
#
# (2428025407850408099, 150, 152)
# municipal elections
# Henriksson recalled that eight of the nine parliamentary parties and the Parliamentary Constitution Committee approved the postponement of the municipal elections.
#
# (2428025407850408099, 162, 164)
# municipal elections
# "It would have been possible to hold municipal elections in April, but not responsibly," Henriksson added.
#
# (2428025407850408099, 158, 160)
# coronavirus restrictions
# Both parties enjoy higher levels of support in parts of the south and southwest which are currently under tightened coronavirus restrictions.
#
# (2428025407850408099, 20, 22)
# coronavirus restrictions
# An estimated 150 people have gathered in the city of Turku in Southwest Finland on Saturday afternoon to protest against coronavirus restrictions.
#
# (2428025407850408099, 83, 85)
# municipal elections
# The race at the top remains tight, with the three parties fighting a close battle for first place in the delayed municipal elections, set for 13 June.
#
# (2428025407850408099, 368, 370)
# municipal elections
# Improved support for the National Coalition Party bodes well for them in the municipal elections.
#
# (2428025407850408099, 636, 638)
# municipal elections
# "At the moment, it is of paramount importance for the Centre that they get their potential supporters to the ballot box if the party wants a reasonable result in the municipal elections," Turja said.
#
# (2428025407850408099, 662, 664)
# municipal elections
# At 12.5 percent, support for the Centre is currently five percentage points lower than in the last municipal elections in 2017.
#
# (2428025407850408099, 732, 734)
# municipal elections
# Support for the Swedish People's Party has not shifted at all, although its leader, Justice Minister Anna-Maja Henriksson, was heavily criticised for postponing the municipal elections.
#
# (2428025407850408099, 768, 770)
# municipal elections
# According to Turja, the approach of the municipal elections is reflected in the fact that the popularity of groups outside Parliament increased slightly in the support survey.
#
# (2428025407850408099, 36, 38)
# coronavirus restrictions
# The country is at the height of the spread of seasonal street dust, but current coronavirus restrictions may be providing some relief from this annual predicament, according to Pia Anttila, a researcher at the Finnish Meteorological Institute (FMI).
#
# (2428025407850408099, 532, 534)
# coronavirus restrictions
# In March last year, the cruise ship industry halted most passenger traffic due to coronavirus restrictions imposed by the authorities.
#
# (2428025407850408099, 19, 21)
# coronavirus restrictions
# An international comparative study of 11 countries has found people in Finland were the most committed to complying with coronavirus restrictions.
#
# (2428025407850408099, 357, 359)
# coronavirus restrictions
# "Citizens are prepared to comply with coronavirus restrictions that restrict their own fundamental rights if they are perceived to be effective.
#
# (2428025407850408099, 15, 17)
# coronavirus restrictions
# Helsinki Police suspect 46 people of violating restrictions on public gatherings during a demonstration against coronavirus restrictions held in the capital on 20 March.
#
# (2428025407850408099, 13, 15)
# coronavirus restrictions
# Due to coronavirus restrictions on travel and bars, Alko's position as an alcohol vendor was significantly improved, which was reflected in its revenues.
#
#
# (2428025407850408099, 15, 17)
# coronavirus restrictions
# Finland's government has prepared a draft plan for the gradual relaxing and removal of coronavirus restrictions, beginning this month with the end of partial shutdown.
#
# (2428025407850408099, 6, 8)
# coronavirus restrictions
# Plans for the gradual easing of coronavirus restrictions look to be on schedule, a government source has reportedly told Iltalehti.
#
# (2428025407850408099, 251, 253)
# coronavirus restrictions
# The group invited the public to join the event on its website, without any mention of coronavirus restrictions on group size.
#
# (2428025407850408099, 349, 351)
# municipal elections
# Last month Henriksson sailed through a confidence vote in Parliament, brought by opposition parties critical of her handling of the postponement of municipal elections from April to June.
#
# (2428025407850408099, 131, 133)
# coronavirus restrictions
# Police said in advance that they intended to disband a so-called "Grand March" against coronavirus restrictions planned for Saturday if an attempt was made to form a large group out of many small demonstrations in the procession.
#
# (2428025407850408099, 839, 841)
# coronavirus restrictions
# Hämeenlinna's Wanaja Festival is awaiting more detailed instructions on how coronavirus restrictions will be lifted.

# %% [markdown]
# ## Ex 3
#
# Extract all syntactic phrases headed by the word `"situation"`.
#
# In a dependency tree, such phrase corresponds to the subtree containing all descendents of the token of interest. You can get it using the field `token.subtree`.

# %%
for d in docs:
    for tok in d:
        if tok.lemma_ == 'situation':
            print(list(tok.subtree))
# Out:
# [the, situation]
# [certain, situations, we, have, to, go, to, so, -, called, virgin, areas]
# [a, similar, situation]
# [the, prevailing, pandemic, situation, and, the, necessary, safety, arrangements]
# [the, examination, situation]
# [the, disease, situation]
# [the, situation, in, Estonia, ,, where, the, infection, rate, is, now, the, second, -, highest, in, the, continent, and, around, nine, times, higher, than, it, is, in, Finland]
# [the, worst, infection, situation, outside, of, the, Helsinki, region]
# [The, coronavirus, situation]
# [the, pandemic, situation]
# [the, situation, in, the, greater, Helsinki, and, Turku, regions]
# [Finland, 's, deteriorating, Covid, situation]
# [the, situation]
# [the, coronavirus, situation]
# [an, embarrassing, situation]
# [a, completely, everyday, situation]
# [certain, situations]
# [the, current, situation]
# [situations, where, a, passenger, does, not, provide, proof, of, illness, or, a, recent, coronavirus, test]
# [the, situation]
# [The, situation]
# [the, situation]
# [the, deteriorating, coronavirus, situation]
# [the, difficult, public, health, situation]
# [the, situation]
# [these, situations]
# [a, situation, in, which, the, police, have, to, interpret, the, rules, ,, or, one, in, which, police, have, to, interrogate, citizens, about, their, comings, and, goings]
# [difficult, situations, ,, unrest, or, even, civil, war]
# [the, situation]
# [the, situation]
# [the, worsening, situation]
# [the, situation]
# [25, threatening, situations, ,, including, an, incident, where, an, angry, motorist, attempted, to, run, over, one, of, the, city, ’s, parking, attendants]
# [a, conflict, situation]
# [a, particular, situation]
# [the, current, coronavirus, situation]
# [situation]
# [the, situation]
# [the, country, 's, worsening, coronavirus, situation]
# [the, situation]
# [The, worsened, financial, situation, of, the, elderly]
# [Situation, still, serious]
# [the, situation]
# [the, city, 's, worsening, epidemic, situation]
# [the, city, 's, overall, coronavirus, situation]
# [The, situation]
# [the, situation]
# [the, current, epidemic, situation]
# [The, situation]
# [similar, situations]
# [this, situation]
# [a, situation, companies, are, allowed, where, to, decide, their, own, tailor, -, made, solutions]
# [A, calm, situation]
# [the, situation, in, other, countries, ,, including, Ireland, and, Portugal, ,, where, a, relatively, calm, situation, got, out, of, control, very, quickly, and, endangered, health, care, capacity]
# [a, relatively, calm, situation]
# [The, pandemic, situation, in, the, Helsinki, metropolitan, area]
# [such, situations]
# [The, situation]
# [indoor, situations]
# [such, situations]
# [the, worst, epidemic, situation]
# [the, situation, caused, by, the, pandemic]
# [the, unemployment, situation]
# [their, own, financial, situation]
# [the, restaurant, restriction, situation]
# [the, pandemic, situation]
# [the, deteriorating, situation]
# [the, coronavirus, situation, in, the, area]
# [the, situation]
# [the, situation, in, Finland, 's, intensive, care, units]
# [The, situation]
# [an, exceptional, situation, for, us]
# [life, situations, or, stress, at, work]
# [the, situation]
# [a, positive, situation, in]
# [the, situation]
# [the, infection, situation, in, various, parts, of, the, country]
# [the, pandemic, situation]
# [the, globally, challenging, situation]
# [the, situation]
# [a, very, difficult, situation]
# [the, coronavirus, situation, at, a, Defence, Forces, barracks]
# [the, situation]
# [the, coronavirus, situation, at, a, garrison]
# [situations, like, the, current, coronavirus, pandemic, or, other, similar, crises]
# [the, situation]
# [the, Covid-19, situation]
# [an, embarrassing, situation]
# [the, situation]
# [a, new, situation]
# [the, situation, of, rising, numbers, itself]
# [the, situation]
# [the, Covid-19, situation]
# [the, situation, and, the, pace, of, vaccination, in, Finland, ,, Estonia, and, Sweden]
# [the, situation, with, these, workers]
# [the, epidemic, situation]
# [the, coronavirus, situation]
# [the, epidemic, situation]
# [the, epidemic, situation, in, neighbouring, countries]
# [the, virus, situation]
# [the, regional, situation]
# [this, situation]
# [situation]
# [The, situation]
# [the, unusual, situation]
# [a, rare, situation, that, does, n't, happen, every, day]
# [customer, -, facing, situations]
# [The, riskier, situations]
# [the, coronavirus, situation]
# [their, economic, and, employment, situations]

# %% [markdown]
# # Homework

# %% [markdown]
# ## Ex 4 (5p.)
#
# Write a function `find_quotes(nlp, docs)` that identifies and attributes direct quotes in the text. A direct quote looks like this:
#
# "*There is no simple answer,*" **Matti Sarvimäki**, Assistant Professor of Economics at Aalto University **told** the paper.
#
# We recognize the following three identifying elements:
# * **proposition** - the text that is being quoted (e.g. "There is no simple answer"),
# * **author** - the person that is being quoted ("Matti Sarvimäki"),
# * **cue** - a verb indicating a speech act, e.g. "told".
#
# The function should output a list of triplets: `(author, cue, proposition)`, each being a `Tok` or `Span` object. You may use information gained from exercise 1 to manually create a list of speech act verbs (it does not need to be exhaustive, a couple of common examples are enough).
#
# 3 points are given for a basic working version of the function. For full points, pay attention to the following details:
# * If a name is given in the form `FirstName LastName`, output a `Span` object containing them both as author. (1p.)
# * If the proposition ends with a quote character (`"`), look for the matching character to find where it starts. It might be a different sentence! (1p.)
#
# You can restrict the solution to propositions enclosed in quotes and the speaker being named by name (rather than a pronoun).

# %%
from spacy.matcher import Matcher
from collections import defaultdict
def find_quotes(nlp, docs):
    verbs_pattern = [
            {"RIGHT_ID": 'speech_verb',
             "RIGHT_ATTRS": {"LEMMA": {"IN": ["tell", "say"]}}}
             ]

    verbs_matcher = spacy.matcher.DependencyMatcher(nlp.vocab)
    verbs_matcher.add('speech_verbs', [verbs_pattern])
    
    speech_verbs = [d[m[1][0]] for i, d in enumerate(docs) for m in verbs_matcher(d)]
    
    indexes = defaultdict(list)
    for i, par in enumerate(docs):
        for tok in par:
            if tok.norm_ == '"':
                #print(tok, tok.i, tok.head)
                indexes[i].append(tok.i)
                #print(tok.orth_, tok.i, tok.head, tok.head.i)
            #if tok.dep_ == 'nsubj' and tok.head in speech_verbs:
                #print(tok.orth_, tok.head, tok.head.i)
    
    for key, val in indexes.items():
        start = 0
        end = 0
        count = 0
        for tok in indexes[key]:
            if val.index(tok) % 2 == 0:
                start = tok
                count += 1
            else:
                end = tok
                count += 1
            if tok.i in indexes[key]:
                print(tok, tok.i, tok.head, tok.pos_)
        
        
    quotes = []
    for par in docs:
        for tok in par:
            if tok.dep_ == 'nsubj' and tok.head in speech_verbs:
                quotes.append((tok, tok.head))

    """
    quotes = []
    for verb in speech_verbs:
        quote_index = 0
        who_said = []
        quote = ()
        for tok in verb.sent:
            if tok.norm_ == '"' and tok.head.dep_ == 'ROOT':
                quote_index = tok.i
            if tok.dep_ == 'nsubj' and tok.head == verb:
                who_said.append(tok) 
                who_said.append(tok.head)
        quote = (who_said[0], who_said[1], verb.sent[:quote_index])
        quotes.append(quote)
        print(quote_indexes)
        if len(quote_indexes) == 1:
            print(quote_indexes)
            quote = (who_said[0], who_said[1], verb.sent[:quote_indexes[0]])
            quotes.append(quote)
        if len(quote_indexes) == 2:
            quote = (who_said[0], who_said[1], verb.sent[quote_indexes[0]:quote_indexes[1]])
            quotes.append(quote)
        print('Quotes', quotes)"""
    #print(quotes)

# %%
print(docs[0][32:39], docs[0][164].head, docs[1][87].head, docs[18][68].head)
# Out:
# "reset its cost base," said group said

# %%
find_quotes(nlp, docs)
# Out:
# " 32 reset PUNCT
# " 38 said PUNCT
# " 114 taken PUNCT
# " 164 said PUNCT
# " 84 group PUNCT
# " 87 group PUNCT
# " 93 praised PUNCT
# " 113 said PUNCT
# " 272 see PUNCT
# " 291 commented PUNCT
# " 321 had PUNCT
# " 343 Director PUNCT
# " 117 is PUNCT
# " 162 said PUNCT
# " 198 is PUNCT
# " 234 emphasised PUNCT
# " 294 fighting PUNCT
# " 324 said PUNCT
# " 29 are PUNCT
# " 47 writes PUNCT
# " 52 took PUNCT
# " 64 continues PUNCT
# " 245 level PUNCT
# " 247 level PUNCT
# " 264 be PUNCT
# " 281 be PUNCT
# " 391 Thinking PUNCT
# " 424 told PUNCT
# " 488 stated PUNCT
# " 512 chair PUNCT
# " 571 said PUNCT
# " 592 said PUNCT
# " 623 believe PUNCT
# " 657 told PUNCT
# " 47 transition PUNCT
# " 50 transition PUNCT
# " 254 aims PUNCT
# " 290 said PUNCT
# " 634 enable PUNCT
# " 650 are PUNCT
# " 688 changed PUNCT
# " 733 said PUNCT
# " 42 drawn PUNCT
# " 58 said PUNCT
# " 60 estimated PUNCT
# " 108 said PUNCT
# " 266 ensure PUNCT
# " 312 said PUNCT
# " 440 are PUNCT
# " 492 said PUNCT
# " 61 continue PUNCT
# " 91 said PUNCT
# " 157 be PUNCT
# " 180 said PUNCT
# " 212 waste PUNCT
# " 215 waste PUNCT
# " 383 promote PUNCT
# " 422 read PUNCT
# " 607 carried PUNCT
# " 656 stated PUNCT
# " 722 assessed PUNCT
# " 755 said PUNCT
# " 790 include PUNCT
# " 810 stated PUNCT
# " 815 benefits PUNCT
# " 836 is PUNCT
# " 912 be PUNCT
# " 919 said PUNCT
# " 923 create PUNCT
# " 954 create PUNCT
# " 1084 be PUNCT
# " 1120 said PUNCT
# " 1148 decreasing PUNCT
# " 1203 said PUNCT
# " 1227 lost PUNCT
# " 1243 explained PUNCT
# " 1247 be PUNCT
# " 1263 be PUNCT
# " 41 is PUNCT
# " 78 said PUNCT
# " 165 leave PUNCT
# " 170 leave PUNCT
# " 132 have PUNCT
# " 159 reads PUNCT
# " 43 saying PUNCT
# " 62 prompted PUNCT
# " 112 told PUNCT
# " 119 is PUNCT
# " 189 has PUNCT
# " 220 tells PUNCT
# " 231 is PUNCT
# " 241 tells PUNCT
# " 349 wave PUNCT
# " 352 wave PUNCT
# " 386 turned PUNCT
# " 403 quotes PUNCT
# " 432 country PUNCT
# " 435 country PUNCT
# " 457 worrying PUNCT
# " 460 reserves PUNCT
# " 563 fatigue PUNCT
# " 566 feeling PUNCT
# " 586 is PUNCT
# " 608 tells PUNCT
# " 638 allowed PUNCT
# " 663 said PUNCT
# " 716 shower PUNCT
# " 723 said PUNCT
# " 106 has PUNCT
# ” 123 said PUNCT
# " 145 masterpiece PUNCT
# ” 168 synthesis PUNCT
# " 213 Saariahofor PUNCT
# ” 235 praised PUNCT
# " 239 composer PUNCT
# " 243 composer PUNCT
# " 263 be PUNCT
# " 306 told PUNCT
# “ 312 is PUNCT
# ” 345 added PUNCT
# " 373 as PUNCT
# " 391 bills PUNCT
# " 217 come PUNCT
# " 261 said PUNCT
# " 414 were PUNCT
# " 492 said PUNCT
# " 645 came PUNCT
# " 671 told PUNCT
# " 848 considered PUNCT
# " 884 said PUNCT
# " 243 generalise PUNCT
# " 267 said PUNCT
# " 438 taken PUNCT
# " 458 said PUNCT
# " 545 received PUNCT
# " 575 said PUNCT
# " 657 tried PUNCT
# " 671 said PUNCT
# " 689 cancelled PUNCT
# " 710 said PUNCT
# " 746 expressed PUNCT
# " 786 said PUNCT
# " 826 feel PUNCT
# " 853 said PUNCT
# " 858 complied PUNCT
# " 882 said PUNCT
# " 220 said PUNCT
# " 235 said PUNCT
# " 47 have PUNCT
# " 68 said PUNCT
# " 181 requirement PUNCT
# " 232 said PUNCT
# " 306 is PUNCT
# " 341 said PUNCT
# " 29 been PUNCT
# " 50 said PUNCT
# " 221 been PUNCT
# " 248 said PUNCT
# " 293 book PUNCT
# " 325 said PUNCT
# " 356 noted PUNCT
# " 382 noted PUNCT
# " 133 are PUNCT
# " 155 said PUNCT
# " 159 " PUNCT
# " 184 are PUNCT
# " 297 consider PUNCT
# " 349 said PUNCT
# " 356 categorisations PUNCT
# " 430 stated PUNCT
# " 522 have PUNCT
# " 576 is PUNCT
# " 578 think PUNCT
# " 620 concluded PUNCT
# " 293 Milk PUNCT
# " 297 created PUNCT
# " 316 determine PUNCT
# " 321 was PUNCT
# " 349 be PUNCT
# " 352 told PUNCT
# " 163 had PUNCT
# " 182 explained PUNCT
# " 223 is PUNCT
# " 273 said PUNCT
# " 56 is PUNCT
# " 71 is PUNCT
# " 74 added PUNCT
# " 92 noted PUNCT
# " 168 Testing PUNCT
# " 189 told PUNCT
# " 221 is PUNCT
# " 243 explained PUNCT
# " 308 sound PUNCT
# " 324 said PUNCT
# " 187 taken PUNCT
# " 209 noted PUNCT
# " 32 action PUNCT
# " 35 action PUNCT
# " 76 magazine PUNCT
# " 79 translated PUNCT
# " 153 intended PUNCT
# " 186 said PUNCT
# " 389 am PUNCT
# " 421 told PUNCT
# " 450 perverts PUNCT
# " 452 perverts PUNCT
# " 454 fantasists PUNCT
# " 458 fantasists PUNCT
# " 26 got PUNCT
# " 38 got PUNCT
# " 91 's PUNCT
# " 132 says PUNCT
# " 173 questioned PUNCT
# " 187 Finnishness PUNCT
# " 189 Finnishness PUNCT
# " 217 are PUNCT
# " 220 are PUNCT
# " 229 says PUNCT
# " 294 expanded PUNCT
# " 323 says PUNCT
# " 481 's PUNCT
# " 531 explains PUNCT
# " 581 as PUNCT
# " 583 as PUNCT
# " 614 consider PUNCT
# " 644 says PUNCT
# " 701 Finns PUNCT
# " 704 Finns PUNCT
# " 811 homeland PUNCT
# " 813 homeland PUNCT
# " 838 felt PUNCT
# " 891 says PUNCT
# " 1108 longed PUNCT
# " 1156 says PUNCT
# " 147 convinced PUNCT
# " 150 convinced PUNCT
# " 161 caused PUNCT
# " 176 said PUNCT
# " 201 take PUNCT
# " 271 united PUNCT
# " 311 told PUNCT
# " 331 professional PUNCT
# " 338 told PUNCT
# " 340 are PUNCT
# " 358 said PUNCT
# " 157 attraction PUNCT
# " 166 featured PUNCT
# " 175 expect PUNCT
# " 227 said PUNCT
# " 282 addressed PUNCT
# " 315 said PUNCT
# " 330 require PUNCT
# " 349 added PUNCT
# " 245 Kotiintilaus PUNCT
# " 247 Kotiintilaus PUNCT
# " 294 was PUNCT
# " 326 told PUNCT
# " 355 card PUNCT
# " 358 card PUNCT
# " 387 " PUNCT
# " 417 told PUNCT
# " 494 Cube PUNCT
# " 497 Cube PUNCT
# " 565 hope PUNCT
# " 596 told PUNCT
# " 185 became PUNCT
# " 216 told PUNCT
# " 283 is PUNCT
# " 312 said PUNCT
# " 412 been PUNCT
# " 430 said PUNCT
# " 561 taken PUNCT
# " 578 explained PUNCT
# " 81 thought PUNCT
# " 98 told PUNCT
# " 203 forced PUNCT
# " 230 said PUNCT
# " 235 Information PUNCT
# " 282 explained PUNCT
# " 342 is PUNCT
# " 375 said PUNCT
# " 32 is PUNCT
# " 74 tells PUNCT
# " 236 comments PUNCT
# " 239 comments PUNCT
# " 260 's PUNCT
# " 294 were PUNCT
# " 298 messages PUNCT
# " 319 wrote PUNCT
# " 386 hear PUNCT
# " 419 says PUNCT
# " 476 took PUNCT
# " 515 points PUNCT
# " 522 Silence PUNCT
# " 526 captain PUNCT
# " 561 was PUNCT
# " 612 explains PUNCT
# " 702 ’s PUNCT
# " 758 says PUNCT
# " 868 been PUNCT
# " 906 says PUNCT
# " 937 is PUNCT
# " 959 says PUNCT
# " 963 ask PUNCT
# " 998 want PUNCT
# " 347 need PUNCT
# " 371 need PUNCT
# " 55 handed PUNCT
# " 88 said PUNCT
# " 902 said PUNCT
# " 914 said PUNCT
# " 251 be PUNCT
# " 284 stated PUNCT
# " 51 Abuse PUNCT
# " 63 ministers PUNCT
# " 93 agreements PUNCT
# " 109 production PUNCT
# " 116 pointed PUNCT
# " 166 said PUNCT
# " 312 have PUNCT
# " 329 added PUNCT
# " 59 operations PUNCT
# " 72 operations PUNCT
# " 240 investigating PUNCT
# " 268 said PUNCT
# " 278 is PUNCT
# " 313 excluded PUNCT
# " 343 understands PUNCT
# " 386 said PUNCT
# " 288 wanted PUNCT
# " 332 wrote PUNCT
# " 29 considered PUNCT
# " 45 states PUNCT
# " 92 said PUNCT
# " 98 said PUNCT
# " 164 said PUNCT
# " 184 said PUNCT
# " 231 borders PUNCT
# " 240 criticised PUNCT
# " 265 have PUNCT
# " 282 know PUNCT
# " 293 be PUNCT
# " 316 added PUNCT
# " 412 spots PUNCT
# " 415 spots PUNCT
# " 486 pointed PUNCT
# " 505 pointed PUNCT
# " 427 compiled PUNCT
# " 466 states PUNCT
# " 62 is PUNCT
# " 91 said PUNCT
# “ 342 was PUNCT
# " 388 explains PUNCT
# " 496 is PUNCT
# " 522 says PUNCT
# " 677 be PUNCT
# " 716 predicts PUNCT
# " 99 started PUNCT
# " 139 stated PUNCT
# " 396 are PUNCT
# " 416 reminds PUNCT
# " 76 expected PUNCT
# " 100 says PUNCT
# " 234 spread PUNCT
# " 280 says PUNCT
# " 323 said PUNCT
# " 350 says PUNCT
# " 355 Do PUNCT
# " 359 best PUNCT
# " 470 is PUNCT
# " 492 says PUNCT
# " 558 try PUNCT
# " 587 says PUNCT
# " 654 promised PUNCT
# " 710 says PUNCT
# " 769 be PUNCT
# " 800 increase PUNCT
# " 67 packed PUNCT
# " 98 told PUNCT
# " 213 ’re PUNCT
# " 262 said PUNCT
# " 280 has PUNCT
# " 304 told PUNCT
# " 80 held PUNCT
# " 112 said PUNCT
# " 84 language PUNCT
# " 105 said PUNCT
# " 309 get PUNCT
# " 327 explained PUNCT
# " 114 boom PUNCT
# " 117 boom PUNCT
# " 497 municipalities PUNCT
# " 501 municipalities PUNCT
# " 115 are PUNCT
# " 131 explained PUNCT
# " 177 suggest PUNCT
# " 199 explained PUNCT
# " 226 ’s PUNCT
# " 249 ’s PUNCT
# " 297 think PUNCT
# " 342 explained PUNCT
# " 414 spring PUNCT
# " 433 said PUNCT
# " 437 pointing PUNCT
# " 447 pointing PUNCT
# " 113 is PUNCT
# " 167 told PUNCT
# " 191 find PUNCT
# " 213 continued PUNCT
# " 250 set PUNCT
# " 286 said PUNCT
# " 158 is PUNCT
# " 201 wrote PUNCT
# " 388 alleviated PUNCT
# " 408 said PUNCT
# " 17 be PUNCT
# " 20 difficult PUNCT
# " 28 were PUNCT
# " 31 critical PUNCT
# " 103 hope PUNCT
# " 125 said PUNCT
# " 182 anticipate PUNCT
# " 210 said PUNCT
# " 271 long PUNCT
# " 308 said PUNCT
# " 381 going PUNCT
# " 412 said PUNCT
# " 32 received PUNCT
# " 51 said PUNCT
# " 143 taken PUNCT
# " 210 explained PUNCT
# " 314 means PUNCT
# " 330 said PUNCT
# " 387 expect PUNCT
# " 398 said PUNCT
# " 125 been PUNCT
# " 137 said PUNCT
# " 124 think PUNCT
# " 151 said PUNCT
# " 156 consists PUNCT
# " 187 consists PUNCT
# " 321 told PUNCT
# " 350 told PUNCT
# " 405 Metsävainio PUNCT
# " 416 said PUNCT
# " 420 is PUNCT
# " 450 is PUNCT
# " 89 say PUNCT
# " 161 says PUNCT
# " 187 see PUNCT
# " 220 told PUNCT
# " 277 have PUNCT
# " 301 is PUNCT
# " 633 is PUNCT
# " 646 said PUNCT
# " 183 targets PUNCT
# " 208 wrote PUNCT
# " 561 returned PUNCT
# " 599 stated PUNCT
# " 150 worrying PUNCT
# " 195 said PUNCT
# " 270 's PUNCT
# " 323 says PUNCT
# " 233 is PUNCT
# " 262 wrote PUNCT
# " 77 were PUNCT
# " 117 said PUNCT
# " 186 generated PUNCT
# " 215 stated PUNCT
# " 89 been PUNCT
# " 104 said PUNCT
# " 108 say PUNCT
# " 132 say PUNCT
# " 211 support PUNCT
# " 214 support PUNCT
# " 242 belong PUNCT
# " 253 said PUNCT
# " 263 's PUNCT
# " 296
#  PUNCT
# " 298 's PUNCT
# " 337 said PUNCT
# " 364 is PUNCT
# " 397 is PUNCT
# " 424 been PUNCT
# " 431 said PUNCT
# " 435 become PUNCT
# " 482 's PUNCT
# " 173 " PUNCT
# " 181 said PUNCT
# " 195 convinced PUNCT
# " 222 reduced PUNCT
# " 283 been PUNCT
# " 321 said PUNCT
# " 354 said PUNCT
# " 367 is PUNCT
# " 372 " PUNCT
# " 400 go PUNCT
# " 157 suggests PUNCT
# " 204 said PUNCT
# " 339 add PUNCT
# " 366 said PUNCT
# " 509 be PUNCT
# " 526 said PUNCT
# " 97 have PUNCT
# " 129 said PUNCT
# " 166 seen PUNCT
# " 185 Kääpä PUNCT
# " 85 decide PUNCT
# " 104 said PUNCT
# " 214 is PUNCT
# " 243 said PUNCT
# " 130 emerged PUNCT
# " 161 said PUNCT
# " 69 is PUNCT
# " 119 continued PUNCT
# " 186 Research PUNCT
# " 210 head PUNCT
# " 223 need PUNCT
# " 273 looking PUNCT
# " 344 are PUNCT
# " 347 are PUNCT
# " 34 spreading PUNCT
# " 40 submitted PUNCT
# " 58 is PUNCT
# " 84 is PUNCT
# " 112 bring PUNCT
# " 117 aiming PUNCT
# " 123 use PUNCT
# " 133 use PUNCT
# " 184 are PUNCT
# " 236 said PUNCT
# " 335 try PUNCT
# " 378 said PUNCT
# " 416 stopped PUNCT
# " 451 said PUNCT
# " 572 required PUNCT
# " 591 said PUNCT
# " 166 been PUNCT
# " 202 said PUNCT
# " 251 believe PUNCT
# " 285 told PUNCT
# " 406 been PUNCT
# " 429 reduces PUNCT
# " 457 realise PUNCT
# " 497 said PUNCT
# " 137 deemed PUNCT
# " 159 said PUNCT
# " 163 targeted PUNCT
# " 207 are PUNCT
# " 254 spreading PUNCT
# " 260 confirmed PUNCT
# " 403 appeal PUNCT
# " 458 said PUNCT
# " 523 are PUNCT
# " 538 said PUNCT
# " 44 be PUNCT
# " 52 said PUNCT
# " 118 was PUNCT
# " 121 tried PUNCT
# " 175 have PUNCT
# " 202 have PUNCT
# " 223 be PUNCT
# " 241 said PUNCT
# " 129 is PUNCT
# " 161 said PUNCT
# " 211 exceeded PUNCT
# " 233 said PUNCT
# " 65 tells PUNCT
# " 70 tells PUNCT
# " 80 ordered PUNCT
# " 99 ordered PUNCT
# " 216 tells PUNCT
# " 231 tells PUNCT
# " 298 be PUNCT
# " 340 is PUNCT
# " 643 been PUNCT
# " 665 told PUNCT
# " 62 is PUNCT
# " 113 said PUNCT
# " 45 section PUNCT
# " 48 section PUNCT
# " 193 get PUNCT
# " 233 said PUNCT
# " 288 said PUNCT
# " 308 said PUNCT
# " 349 be PUNCT
# " 370 said PUNCT
# " 376 be PUNCT
# " 405 is PUNCT
# " 167 relationships PUNCT
# " 170 relationships PUNCT
# " 54 need PUNCT
# " 78 said PUNCT
# " 88 are PUNCT
# " 123 said PUNCT
# " 154 been PUNCT
# " 171 added PUNCT
# " 93 is PUNCT
# " 134 said PUNCT
# " 144 have PUNCT
# " 165 added PUNCT
# " 305 based PUNCT
# " 351 said PUNCT
# " 59 weakened PUNCT
# " 62 weakened PUNCT
# " 52 seems PUNCT
# " 71 told PUNCT
# " 122 is PUNCT
# " 148 said PUNCT
# " 204 is PUNCT
# " 217 said PUNCT
# " 381 got PUNCT
# " 400 told PUNCT
# " 136 be PUNCT
# " 152 said PUNCT
# " 254 happen PUNCT
# " 264 said PUNCT
# " 57 Cool PUNCT
# " 65 made PUNCT
# " 120 is PUNCT
# " 184 writes PUNCT
# " 192 cool PUNCT
# " 195 cool PUNCT
# " 247 are PUNCT
# " 256 writes PUNCT
# “ 326 for PUNCT
# ” 362 states PUNCT
# “ 475 be PUNCT
# ” 526 wrote PUNCT
# " 187 consulted PUNCT
# " 220 said PUNCT
# " 126 is PUNCT
# " 158 said PUNCT
# " 259 offers PUNCT
# " 278 explained PUNCT
# " 308 offer PUNCT
# " 368 said PUNCT
# " 484 seen PUNCT
# " 524 said PUNCT
# " 575 is PUNCT
# " 604 said PUNCT
# " 157 heard PUNCT
# " 180 says PUNCT
# " 288 says PUNCT
# " 300 says PUNCT
# " 314 have PUNCT
# " 350 adds PUNCT
# " 233 blow PUNCT
# " 236 blow PUNCT
# " 365 understand PUNCT
# " 409 said PUNCT
# " 431 hope PUNCT
# " 460 said PUNCT
# " 501 mean PUNCT
# " 518 lamented PUNCT
# " 110 increased PUNCT
# " 144 said PUNCT
# " 221 haven PUNCT
# " 223 haven PUNCT
# " 327 shocking PUNCT
# " 329 shocking PUNCT
# " 332 caught PUNCT
# " 364 told PUNCT
# " 396 affect PUNCT
# " 429 explained PUNCT
# " 452 have PUNCT
# " 484 said PUNCT
# " 114 assess PUNCT
# " 152 said PUNCT
# " 193 begin PUNCT
# " 226 told PUNCT
# " 296 influenced PUNCT
# " 317 said PUNCT
# " 321 had PUNCT
# " 345 added PUNCT
# " 407 to PUNCT
# " 417 said PUNCT
# " 419 address PUNCT
# " 451 said PUNCT
# " 119 vaccinated PUNCT
# " 126 quotes PUNCT
# " 343 have PUNCT
# " 376 told PUNCT
# " 511 was PUNCT
# " 529 driver PUNCT
# " 304 was PUNCT
# " 317 said PUNCT
# " 273 find PUNCT
# " 302 explained PUNCT
# " 103 said PUNCT
# " 112 said PUNCT
# " 139 think PUNCT
# " 172 said PUNCT
# " 223 leaving PUNCT
# " 242 explained PUNCT
# " 543 take PUNCT
# " 567 explained PUNCT
# " 78 found PUNCT
# " 113 said PUNCT
# " 138 was PUNCT
# " 182 said PUNCT
# " 195 been PUNCT
# " 234 said PUNCT
# " 277 transmitted PUNCT
# " 306 said PUNCT
# " 93 caused PUNCT
# " 120 said PUNCT
# " 275 found PUNCT
# " 303 said PUNCT
# " 164 make PUNCT
# " 191 told PUNCT
# " 198 store PUNCT
# " 201 opens PUNCT
# " 266 store PUNCT
# " 269 opening PUNCT
# " 321 made PUNCT
# " 338 told PUNCT
# " 78 been PUNCT
# " 130 said PUNCT
# " 181 convinced PUNCT
# " 184 convinced PUNCT
# " 171 have PUNCT
# " 199 said PUNCT
# " 338 is PUNCT
# " 390 says PUNCT
# " 115 are PUNCT
# " 157 said PUNCT
# " 93 stated PUNCT
# " 144 said PUNCT
# " 194 are PUNCT
# " 202 caught PUNCT
# " 204 walked PUNCT
# " 237 told PUNCT
# " 194 becomes PUNCT
# " 210 said PUNCT
# " 279 residents PUNCT
# " 324 said PUNCT
# " 348 be PUNCT
# " 374 explained PUNCT
# " 486 make PUNCT
# " 502 said PUNCT
# " 662 take PUNCT
# " 681 said PUNCT
# " 264 aims PUNCT
# " 283 alleviate PUNCT
# " 389 remain PUNCT
# " 400 remain PUNCT
# " 436 products PUNCT
# " 444 products PUNCT
# " 450 is PUNCT
# " 458 aims PUNCT
# " 191 be PUNCT
# " 212 said PUNCT
# " 217 's PUNCT
# " 246 added PUNCT
# " 286 updated PUNCT
# " 297 said PUNCT
# " 329 saying PUNCT
# " 347 issued PUNCT
# " 365 meet PUNCT
# " 380 found PUNCT
# " 382 failed PUNCT
# " 400 wrote PUNCT
# " 309 measures PUNCT
# " 350 said PUNCT
# " 403 is PUNCT
# " 443 said PUNCT
# " 526 lost PUNCT
# " 557 said PUNCT
# " 604 is PUNCT
# " 639 said PUNCT
# " 56 raises PUNCT
# " 76 said PUNCT
# " 86 said PUNCT
# " 114 said PUNCT
# " 160 is PUNCT
# " 167 echoed PUNCT
# " 231 looks PUNCT
# " 251 said PUNCT
# " 255 was PUNCT
# " 261 was PUNCT
# " 303 appears PUNCT
# " 320 expert PUNCT
# " 335 think PUNCT
# " 360 added PUNCT
# " 501 commented PUNCT
# " 550 wrote PUNCT
# " 119 advised PUNCT
# " 133 spending PUNCT
# " 137 have PUNCT
# " 152 have PUNCT
# " 157 disproportional PUNCT
# " 160 disproportional PUNCT
# " 230 is PUNCT
# " 260 said PUNCT
# " 283 highlighted PUNCT
# " 321 said PUNCT
# “ 326 directed PUNCT
# ” 367 said PUNCT
# " 455 told PUNCT
# " 474 told PUNCT
# " 180 delayed PUNCT
# " 227 said PUNCT
# " 263 suits PUNCT
# " 276 said PUNCT
# " 361 as PUNCT
# " 369 Billed PUNCT
# " 240 shortened PUNCT
# " 260 said PUNCT
# " 311 is PUNCT
# " 358 said PUNCT
# " 93 fallen PUNCT
# " 151 said PUNCT
# " 167 willing PUNCT
# " 171 was PUNCT
# " 389 know PUNCT
# " 429 says PUNCT
# " 93 were PUNCT
# " 120 said PUNCT
# " 201 have PUNCT
# " 236 explained PUNCT
# " 38 was PUNCT
# " 50 said PUNCT
# " 128 was PUNCT
# " 151 said PUNCT
# " 89 Lapland PUNCT
# " 106 said PUNCT
# " 177 ’s PUNCT
# " 215 explained PUNCT
# " 239 continue PUNCT
# " 268 explained PUNCT
# " 287 indicate PUNCT
# " 331 said PUNCT
# " 41 's PUNCT
# " 50 said PUNCT
# " 54 declined PUNCT
# " 93 were PUNCT
# " 128 are PUNCT
# " 137 said PUNCT
# " 141 " PUNCT
# " 149 needing PUNCT
# " 220 're PUNCT
# " 230 said PUNCT
# " 234 has PUNCT
# " 246 has PUNCT
# " 313 's PUNCT
# " 338 said PUNCT
# " 343 is PUNCT
# " 353 is PUNCT
# " 378 increase PUNCT
# " 391 said PUNCT
# " 395 tell PUNCT
# " 414 tell PUNCT
# " 445 driving PUNCT
# " 477 driving PUNCT
# " 254 cost PUNCT
# " 284 said PUNCT
# " 328 save PUNCT
# " 346 said PUNCT
# " 607 are PUNCT
# " 639 said PUNCT
# " 122 exploited PUNCT
# " 158 said PUNCT
# " 169 be PUNCT
# " 190 be PUNCT
# " 217 means PUNCT
# " 242 tweeted PUNCT
# " 11 tweet PUNCT
# " 13 tweet PUNCT
# " 63 said PUNCT
# " 87 wrote PUNCT
# " 91 watch PUNCT
# " 117 Greetings PUNCT
# " 137 come PUNCT
# " 152 added PUNCT
# " 140 said PUNCT
# " 162 said PUNCT
# " 183 want PUNCT
# " 200 said PUNCT
# " 95 is PUNCT
# " 127 stated PUNCT
# " 166 make PUNCT
# " 220 said PUNCT
# " 309 come PUNCT
# " 334 said PUNCT
# " 375 is PUNCT
# " 394 said PUNCT
# " 432 became PUNCT
# " 478 said PUNCT
# " 569 be PUNCT
# " 585 said PUNCT
# " 642 said PUNCT
# " 649 said PUNCT
# " 653 been PUNCT
# " 737 generalised PUNCT
# " 787 is PUNCT
# " 803 said PUNCT
# " 127 explain PUNCT
# " 165 told PUNCT
# " 184 said PUNCT
# " 225 said PUNCT
# " 62 wrote PUNCT
# " 97 wrote PUNCT
# " 113 was PUNCT
# " 117 subject PUNCT
# " 182 assess PUNCT
# " 224 wrote PUNCT
# " 277 linked PUNCT
# " 295 linked PUNCT
# " 8 Harkimo PUNCT
# " 10 Harkimo PUNCT
# " 134 're PUNCT
# " 152 explained PUNCT
# " 167 told PUNCT
# " 217 involved PUNCT
# " 219 actor PUNCT
# " 225 actor PUNCT
# " 280 want PUNCT
# " 294 said PUNCT
# " 336 's PUNCT
# " 358 do PUNCT
# " 414 meet PUNCT
# " 429 explained PUNCT
# " 433 were PUNCT
# " 468 know PUNCT
# " 51 alarming PUNCT
# " 54 called PUNCT
# " 87 used PUNCT
# " 126 said PUNCT
# " 97 Adjustments PUNCT
# " 99 Adjustments PUNCT
# " 224 slipping PUNCT
# " 266 said PUNCT
# " 277 are PUNCT
# " 310 said PUNCT
# " 358 are PUNCT
# " 401 said PUNCT
# " 417 said PUNCT
# " 436 said PUNCT
# " 444 are PUNCT
# " 463 are PUNCT
# " 481 decide PUNCT
# " 538 said PUNCT
# " 612 want PUNCT
# " 621 cuts PUNCT
# " 664 's PUNCT
# " 705 said PUNCT
# " 713 set PUNCT
# " 727 said PUNCT
# " 763 hide PUNCT
# " 772 hide PUNCT
# " 807 needs PUNCT
# " 829 said PUNCT
# " 857 taken PUNCT
# " 902 said PUNCT
# " 930 adjusting PUNCT
# " 955 said PUNCT
# " 149 extrapolated PUNCT
# " 190 said PUNCT
# " 223 are PUNCT
# " 270 said PUNCT
# " 68 been PUNCT
# " 89 explained PUNCT
# " 116 said PUNCT
# " 137 said PUNCT
# " 156 were PUNCT
# " 175 said PUNCT
# " 65 link PUNCT
# " 67 link PUNCT
# " 88 say PUNCT
# " 121 said PUNCT
# " 262 come PUNCT
# " 315 said PUNCT
# " 418 follow PUNCT
# " 458 said PUNCT
# " 162 were PUNCT
# " 181 said PUNCT
# " 214 act PUNCT
# " 261 wrote PUNCT
# " 322 give PUNCT
# " 361 said PUNCT
# " 65 is PUNCT
# " 115 says PUNCT
# " 75 had PUNCT
# " 125 said PUNCT
# " 167 am PUNCT
# " 205 said PUNCT
# " 235 built PUNCT
# ” 268 wrote PUNCT
# " 298 understand PUNCT
# " 357 said PUNCT
# " 39 bus PUNCT
# " 42 bus PUNCT
# " 56 told PUNCT
# " 84 told PUNCT
# " 158 driven PUNCT
# " 201 told PUNCT
# " 296 reported PUNCT
# " 342 told PUNCT
# " 445 reflected PUNCT
# " 472 said PUNCT
# " 477 turning PUNCT
# " 487 added PUNCT
# " 4 Azad PUNCT
# " 6 Azad PUNCT
# " 39 seems PUNCT
# " 55 tells PUNCT
# " 70 booming PUNCT
# " 72 booming PUNCT
# " 127 had PUNCT
# " 176 says PUNCT
# " 189 Azad PUNCT
# " 191 Azad PUNCT
# " 366 myth PUNCT
# " 368 myth PUNCT
# " 382 skills PUNCT
# " 396 tells PUNCT
# " 406 tells PUNCT
# " 438 be PUNCT
# " 492 be PUNCT
# " 538 stated PUNCT
# " 672 hurt PUNCT
# " 720 adds PUNCT
# " 103 came PUNCT
# " 139 said PUNCT
# " 225 developed PUNCT
# " 259 said PUNCT
# " 411 fell PUNCT
# " 467 said PUNCT
# " 526 given PUNCT
# " 554 said PUNCT
# " 587 told PUNCT
# " 644 told PUNCT
# " 685 been PUNCT
# " 708 said PUNCT
# " 776 requires PUNCT
# " 796 said PUNCT
# " 829 came PUNCT
# " 879 worked PUNCT
# " 894 is PUNCT
# " 934 said PUNCT
# " 1022 ate PUNCT
# " 1064 said PUNCT
# " 1091 taken PUNCT
# " 1119 said PUNCT
# " 228 build PUNCT
# " 281 said PUNCT
# " 71 highlighted PUNCT
# " 92 focused PUNCT
# " 94 is PUNCT
# " 131 said PUNCT
# " 184 reunification PUNCT
# " 216 said PUNCT
# " 347 made PUNCT
# " 405 said PUNCT
# " 20 is PUNCT
# " 23 life PUNCT
# " 49 be PUNCT
# " 52 be PUNCT
# " 442 play PUNCT
# " 477 told PUNCT
# " 645 depends PUNCT
# " 673 start PUNCT
# " 780 Right PUNCT
# " 786 Right PUNCT
# " 893 register PUNCT
# " 896 register PUNCT
# " 1077 use PUNCT
# " 1106 use PUNCT
# " 94 isolated PUNCT
# " 119 adds PUNCT
# " 146 have PUNCT
# " 186 says PUNCT
# " 223 is PUNCT
# " 267 says PUNCT
# " 348 arrived PUNCT
# " 377 says PUNCT
# " 259 come PUNCT
# " 283 points PUNCT
# " 344 provide PUNCT
# " 409 explains PUNCT
# " 490 serve PUNCT
# " 514 notes PUNCT
# " 583 travel PUNCT
# " 622 says PUNCT
# " 682 Fish PUNCT
# " 685 Trap PUNCT
# " 82 is PUNCT
# " 123 says PUNCT
# " 280 is PUNCT
# " 314 said PUNCT
# " 334 believe PUNCT
# " 371 added PUNCT
# " 62 been PUNCT
# " 120 concluded PUNCT
# " 152 came PUNCT
# " 182 wrote PUNCT
# " 350 are PUNCT
# " 396 said PUNCT
# " 237 be PUNCT
# " 256 said PUNCT
# " 260 " PUNCT
# " 279 's PUNCT
# " 281 heard PUNCT
# " 288 heard PUNCT
# " 320 think PUNCT
# " 345 said PUNCT
# " 349 lived PUNCT
# " 405 need PUNCT
# " 456 know PUNCT
# " 486 said PUNCT
# " 490 heard PUNCT
# " 520 are PUNCT
# " 87 fined PUNCT
# " 122 wrote PUNCT
# " 134 proceed PUNCT
# " 167 proceed PUNCT
# " 434 managed PUNCT
# " 476 told PUNCT
# " 245 satisfy PUNCT
# " 265 said PUNCT
# " 285 played PUNCT
# " 300 said PUNCT
# " 81 seek PUNCT
# " 114 said PUNCT
# " 120 used PUNCT
# " 122 used PUNCT
# " 126 certificate PUNCT
# " 129 is PUNCT
# " 152 passport PUNCT
# " 155 passport PUNCT
# " 174 assume PUNCT
# " 230 said PUNCT
# " 318 remain PUNCT
# " 379 said PUNCT
# " 437 number PUNCT
# ” 471 told PUNCT
# " 659 agreed PUNCT
# " 667 study PUNCT
# " 687 on PUNCT
# " 690 carried PUNCT
# " 701 are PUNCT
# ” 711 documents PUNCT
# “ 713 correspondence PUNCT
# " 719 correspondence PUNCT
# " 546 cautious PUNCT
# " 548 as PUNCT
# " 867 passport PUNCT
# " 870 passport PUNCT
# " 986 consider PUNCT
# " 1012 consider PUNCT
# " 1129 described PUNCT
# " 1134 fades PUNCT
# " 1462 hold PUNCT
# " 1465 events PUNCT
# " 114 thrilled PUNCT
# " 185 said PUNCT
# " 114 was PUNCT
# " 121 was PUNCT
# " 166 stated PUNCT
# " 185 stated PUNCT
# " 205 are PUNCT
# " 220 said PUNCT
# " 255 was PUNCT
# " 283 said PUNCT
# " 380 welcome PUNCT
# " 420 said PUNCT
# " 204 are PUNCT
# " 218 economics PUNCT
# " 329 is PUNCT
# " 360 said PUNCT
# " 61 were PUNCT
# " 89 said PUNCT
# " 23 level PUNCT
# " 25 level PUNCT
# " 60 developing PUNCT
# " 81 told PUNCT
# " 111 reopen PUNCT
# " 136 told PUNCT
# " 276 gap PUNCT
# " 305 nurse PUNCT
# " 346 said PUNCT
# " 368 said PUNCT
# " 402 transcended PUNCT
# " 409 speaking PUNCT
# " 475 Come PUNCT
# " 511 told PUNCT
# " 129 went PUNCT
# " 157 was PUNCT
# " 269 allow PUNCT
# " 277 maintaining PUNCT
# " 280 is PUNCT
# " 297 is PUNCT
# “ 164 be PUNCT
# ” 199 said PUNCT
# " 296 had PUNCT
# " 335 said PUNCT
# " 117 is PUNCT
# " 144 said PUNCT
# " 268 said PUNCT
# " 279 said PUNCT
# " 283 was PUNCT
# " 316 went PUNCT
# " 352 was PUNCT
# " 391 told PUNCT
# " 420 talked PUNCT
# " 456 said PUNCT
# " 461 wolf PUNCT
# " 470 wolf PUNCT
# " 492 growled PUNCT
# " 522 said PUNCT
# " 557 view PUNCT
# " 617 added PUNCT
# " 85 continue PUNCT
# " 130 said PUNCT
# " 126 March PUNCT
# " 129 March PUNCT
# " 336 were PUNCT
# " 351 told PUNCT
# " 208 concern PUNCT
# " 251 told PUNCT
# " 257 are PUNCT
# " 299 said PUNCT
# " 368 made PUNCT
# " 398 said PUNCT
# " 445 's PUNCT
# " 468 said PUNCT
# " 505 be PUNCT
# " 542 said PUNCT
# " 547 have PUNCT
# " 575 said PUNCT
# " 648 need PUNCT
# " 696 said PUNCT
# " 765 said PUNCT
# " 785 said PUNCT
# " 1097 believe PUNCT
# " 1133 said PUNCT
# " 175 be PUNCT
# " 230 specialist PUNCT
# " 336 was PUNCT
# " 409 said PUNCT
# " 49 assess PUNCT
# " 65 assess PUNCT
# " 68 is PUNCT
# " 99 said PUNCT
# " 117 assess PUNCT
# " 139 told PUNCT
# " 450 be PUNCT
# " 471 suggests PUNCT
# " 482 mean PUNCT
# " 537 said PUNCT
# " 564 improved PUNCT
# " 594 said PUNCT
# " 636 reformed PUNCT
# " 672 said PUNCT
# " 713 given PUNCT
# " 752 said PUNCT
# " 879 is PUNCT
# " 927 said PUNCT
# " 122 growing PUNCT
# " 167 told PUNCT
# " 78 guaranteed PUNCT
# " 123 says PUNCT
# " 151 Suomesta PUNCT
# " 155 Work PUNCT
# " 201 arrived PUNCT
# " 219 said PUNCT
# " 265 transported PUNCT
# " 291 explained PUNCT
# " 366 have PUNCT
# " 403 says PUNCT
# " 107 made PUNCT
# " 140 said PUNCT
# " 370 grew PUNCT
# " 414 predicted PUNCT
# " 419 start PUNCT
# " 433 noted PUNCT
# " 594 get PUNCT
# " 655 said PUNCT
# " 31 come PUNCT
# " 59 said PUNCT
# " 152 is PUNCT
# " 186 said PUNCT
# " 445 estimated PUNCT
# " 492 explained PUNCT
# " 610 assessed PUNCT
# " 638 said PUNCT
# " 694 decrease PUNCT
# " 711 noted PUNCT
# " 137 was PUNCT
# " 171 said PUNCT
# " 328 invest PUNCT
# " 362 said PUNCT
# " 276 'm PUNCT
# " 291 said PUNCT
# " 420 read PUNCT
# " 430 was PUNCT
# " 586 taken PUNCT
# " 607 said PUNCT
# " 194 think PUNCT
# " 247 said PUNCT
# " 348 need PUNCT
# " 386 said PUNCT
# " 432 deserve PUNCT
# " 445 said PUNCT
# " 600 be PUNCT
# " 613 said PUNCT
# " 618 is PUNCT
# " 656 said PUNCT

# %%
docs[0][164].head
# Out:
# said

# %%
spacy.displacy.render(docs[0][165].sent, style='dep', options={'distance': 100, 'compact':True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="49f98ecaab2f426a93f245cf2e525e6c-0" class="displacy" width="2150" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">priority</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">ensure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">everyone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">impacted</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">supported</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">through</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">process,&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">CEO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">Pekka</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">Lundmark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">statement.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49f98ecaab2f426a93f245cf2e525e6c-0-0" stroke-width="2px" d="M62,302.0 62,285.3333333333333 135.0,285.3333333333333 135.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49f98ecaab2f426a93f245cf2e525e6c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49f98ecaab2f426a93f245cf2e525e6c-0-1" stroke-width="2px" d="M162,302.0 162,285.3333333333333 235.0,285.3333333333333 235.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49f98ecaab2f426a93f245cf2e525e6c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,304.0 L158,296.0 166,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49f98ecaab2f426a93f245cf2e525e6c-0-2" stroke-width="2px" d="M262,302.0 262,202.0 1350.0,202.0 1350.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49f98ecaab2f426a93f245cf2e525e6c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,304.0 L258,296.0 266,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-49f98ecaab2f426a93f245cf2e525e6c-0-3" stroke-width="2px" d="M362,302.0 362,285.3333333333333 435.0,285.3333333333333 435.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-49f98ecaab2f426a93f245cf2e525e6c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,304.0 L358,296.0 366,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arr

# %%
q = find_quotes(nlp, docs)
# Out:
# 0 28
# 0 57
# 0 165
# 1 103
# 1 114
# 1 311
# 1 352
# 2 33
# 2 62
# 2 173
# 2 257
# 2 326
# 3 111
# 3 173
# 3 207
# 3 228
# 3 360
# 3 429
# 3 527
# 3 543
# 3 594
# 3 659
# 4 175
# 4 237
# 4 292
# 4 333
# 4 431
# 4 516
# 4 592
# 4 735
# 5 83
# 6 37
# 6 157
# 6 176
# 7 35
# 7 109
# 7 160
# 7 236
# 7 263
# 7 314
# 7 358
# 7 493
# 8 38
# 8 93
# 8 182
# 8 293
# 8 703
# 8 757
# 8 921
# 8 1122
# 8 1206
# 9 22
# 9 83
# 9 161
# 9 208
# 10 199
# 11 197
# 12 13
# 12 42
# 12 130
# 12 222
# 12 253
# 12 361
# 12 384
# 12 442
# 12 505
# 12 605
# 12 612
# 12 667
# 12 703
# 12 725
# 13 102
# 13 128
# 14 71
# 14 165
# 14 238
# 14 308
# 15 93
# 15 263
# 15 301
# 15 338
# 15 366
# 15 377
# 15 494
# 15 578
# 15 626
# 15 673
# 15 779
# 15 885
# 16 202
# 16 237
# 16 268
# 16 313
# 16 366
# 16 435
# 16 460
# 16 576
# 16 633
# 16 673
# 16 677
# 16 711
# 16 787
# 16 854
# 16 883
# 17 240
# 17 246
# 17 291
# 18 37
# 18 71
# 18 108
# 18 124
# 18 170
# 18 234
# 18 245
# 18 288
# 18 343
# 19 51
# 19 250
# 19 258
# 19 327
# 20 79
# 21 85
# 21 176
# 22 83
# 22 156
# 22 194
# 22 353
# 23 1
# 23 65
# 23 118
# 23 147
# 23 198
# 23 228
# 24 102
# 25 4
# 25 34
# 25 47
# 25 84
# 25 211
# 25 308
# 25 428
# 25 454
# 25 468
# 26 44
# 26 214
# 26 233
# 26 256
# 26 295
# 26 337
# 27 77
# 27 83
# 27 104
# 27 160
# 27 210
# 27 275
# 27 313
# 28 8
# 28 33
# 28 191
# 28 208
# 28 261
# 28 327
# 29 78
# 29 237
# 30 119
# 30 184
# 30 231
# 31 189
# 31 424
# 32 31
# 32 41
# 32 111
# 32 134
# 32 230
# 32 280
# 32 325
# 32 356
# 32 646
# 32 895
# 32 963
# 32 1158
# 32 1338
# 33 28
# 33 36
# 33 73
# 33 119
# 33 178
# 33 229
# 33 255
# 33 432
# 34 268
# 34 318
# 34 360
# 35 228
# 35 316
# 36 58
# 36 75
# 36 103
# 36 131
# 36 144
# 36 157
# 36 328
# 36 347
# 36 419
# 36 547
# 36 601
# 37 226
# 37 272
# 37 314
# 37 432
# 38 15
# 38 29
# 38 100
# 38 139
# 38 153
# 38 187
# 38 232
# 38 298
# 38 326
# 38 377
# 39 76
# 39 361
# 39 421
# 39 531
# 39 641
# 39 760
# 39 854
# 39 908
# 39 961
# 39 966
# 40 34
# 40 73
# 40 182
# 41 67
# 42 117
# 42 325
# 43 34
# 43 90
# 44 129
# 45 125
# 45 396
# 45 783
# 45 851
# 45 915
# 46 210
# 48 48
# 48 168
# 48 246
# 48 298
# 48 392
# 49 52
# 49 94
# 49 170
# 49 276
# 49 323
# 49 388
# 49 446
# 51 63
# 51 100
# 51 186
# 51 190
# 51 244
# 52 81
# 52 194
# 52 255
# 52 877
# 53 62
# 53 235
# 53 285
# 53 338
# 53 389
# 54 53
# 54 93
# 54 152
# 54 524
# 56 59
# 56 124
# 57 101
# 57 281
# 57 291
# 57 328
# 57 351
# 57 494
# 57 507
# 57 589
# 57 628
# 57 711
# 58 20
# 58 35
# 58 103
# 58 106
# 58 161
# 58 170
# 58 200
# 58 264
# 58 269
# 58 306
# 59 4
# 59 116
# 59 183
# 60 66
# 60 71
# 60 116
# 60 123
# 60 142
# 60 178
# 60 190
# 60 259
# 60 295
# 60 319
# 61 6
# 61 51
# 61 89
# 62 60
# 62 183
# 63 108
# 64 122
# 64 153
# 64 205
# 65 33
# 66 32
# 67 131
# 67 246
# 67 282
# 67 391
# 67 435
# 68 28
# 68 169
# 68 288
# 68 293
# 69 410
# 70 106
# 71 7
# 71 127
# 71 212
# 71 219
# 71 260
# 71 310
# 71 314
# 71 351
# 71 414
# 71 430
# 71 445
# 71 523
# 71 540
# 72 42
# 72 52
# 72 108
# 72 296
# 72 332
# 72 336
# 72 400
# 73 139
# 73 230
# 73 314
# 73 348
# 74 153
# 74 237
# 74 352
# 74 418
# 75 92
# 75 162
# 75 226
# 75 488
# 75 647
# 76 499
# 77 196
# 77 324
# 78 284
# 79 118
# 80 4
# 80 72
# 80 105
# 80 112
# 80 135
# 80 254
# 80 294
# 80 338
# 80 346
# 80 402
# 80 432
# 81 88
# 81 182
# 81 322
# 81 342
# 81 369
# 82 131
# 82 205
# 82 367
# 82 458
# 82 528
# 83 76
# 83 131
# 83 180
# 83 245
# 84 190
# 85 62
# 85 106
# 85 245
# 88 166
# 88 184
# 89 141
# 89 174
# 89 219
# 89 278
# 90 298
# 90 351
# 90 544
# 90 621
# 91 92
# 92 37
# 92 62
# 92 243
# 92 380
# 92 453
# 92 488
# 92 510
# 92 593
# 93 209
# 93 298
# 95 261
# 95 327
# 95 400
# 95 499
# 96 115
# 96 161
# 96 353
# 96 460
# 96 488
# 96 540
# 97 9
# 97 54
# 97 163
# 97 206
# 97 243
# 98 163
# 98 235
# 98 533
# 99 38
# 99 76
# 99 241
# 99 346
# 99 667
# 100 114
# 100 132
# 100 209
# 100 214
# 101 172
# 101 235
# 101 310
# 101 333
# 101 374
# 102 58
# 102 86
# 103 214
# 104 182
# 104 232
# 104 283
# 105 44
# 105 79
# 105 205
# 105 245
# 105 301
# 105 334
# 106 124
# 107 135
# 107 282
# 107 353
# 108 66
# 108 156
# 110 81
# 110 149
# 110 173
# 110 192
# 110 219
# 111 95
# 111 280
# 111 405
# 113 21
# 113 56
# 113 101
# 113 154
# 113 163
# 113 181
# 113 266
# 113 300
# 114 105
# 115 25
# 115 171
# 115 295
# 116 107
# 116 173
# 116 223
# 117 160
# 117 370
# 117 526
# 117 606
# 118 181
# 118 301
# 119 123
# 119 411
# 119 462
# 120 327
# 121 145
# 122 366
# 122 486
# 123 58
# 123 101
# 123 154
# 123 190
# 123 228
# 123 273
# 123 319
# 123 352
# 123 401
# 123 453
# 124 43
# 124 51
# 124 87
# 124 378
# 124 384
# 124 537
# 125 6
# 125 289
# 125 422
# 125 466
# 125 499
# 126 27
# 126 186
# 127 114
# 127 174
# 127 184
# 127 204
# 127 644
# 129 63
# 129 115
# 129 135
# 129 184
# 129 236
# 129 309
# 129 345
# 130 260
# 132 122
# 132 305
# 133 70
# 133 149
# 133 193
# 133 344
# 133 435
# 133 470
# 133 500
# 134 132
# 135 67
# 135 115
# 135 140
# 135 175
# 135 201
# 135 227
# 135 251
# 135 319
# 135 392
# 136 158
# 137 49
# 137 104
# 137 125
# 137 167
# 137 188
# 137 229
# 137 256
# 137 336
# 137 368
# 137 386
# 137 442
# 138 79
# 138 149
# 138 181
# 138 193
# 138 239
# 139 66
# 139 160
# 139 183
# 139 212
# 139 232
# 139 326
# 139 392
# 139 504
# 139 569
# 139 606
# 139 683
# 142 188
# 143 176
# 143 214
# 143 267
# 143 299
# 143 328
# 144 352
# 144 445
# 144 559
# 144 579
# 144 641
# 145 23
# 145 77
# 145 127
# 145 155
# 145 206
# 145 253
# 145 331
# 145 527
# 146 27
# 147 65
# 147 79
# 147 100
# 147 261
# 147 323
# 147 368
# 147 415
# 147 461
# 147 476
# 148 32
# 148 165
# 148 228
# 148 254
# 148 277
# 148 334
# 149 261
# 149 360
# 150 152
# 150 292
# 151 161
# 151 187
# 151 334
# 151 373
# 151 431
# 151 439
# 151 538
# 152 35
# 152 77
# 152 122
# 152 188
# 153 38
# 153 65
# 153 220
# 153 278
# 153 333
# 154 51
# 154 153
# 155 39
# 155 73
# 155 108
# 155 139
# 155 225
# 155 333
# 156 27
# 156 51
# 156 124
# 156 138
# 156 231
# 156 268
# 156 339
# 156 392
# 156 404
# 157 137
# 157 285
# 157 290
# 157 347
# 157 587
# 157 640
# 158 89
# 158 159
# 158 195
# 159 21
# 159 44
# 159 66
# 160 101
# 160 149
# 161 68
# 161 166
# 161 191
# 161 202
# 162 92
# 162 224
# 162 294
# 162 336
# 162 398
# 162 482
# 162 587
# 162 631
# 162 651
# 162 760
# 162 805
# 162 820
# 163 167
# 163 202
# 163 227
# 164 45
# 166 113
# 166 165
# 166 255
# 166 296
# 166 315
# 167 202
# 168 34
# 168 69
# 168 128
# 168 282
# 169 29
# 169 209
# 169 267
# 169 311
# 169 341
# 169 351
# 169 402
# 169 437
# 169 469
# 169 539
# 169 632
# 169 706
# 169 728
# 169 749
# 169 792
# 169 831
# 169 837
# 169 903
# 169 915
# 169 956
# 170 134
# 170 192
# 170 203
# 170 271
# 171 139
# 171 177
# 172 53
# 172 95
# 172 123
# 172 250
# 172 317
# 172 460
# 173 68
# 173 183
# 173 363
# 173 431
# 174 117
# 174 382
# 174 564
# 175 127
# 175 207
# 175 284
# 175 359
# 176 93
# 176 203
# 176 283
# 176 331
# 176 344
# 176 421
# 176 474
# 177 57
# 177 75
# 177 178
# 177 362
# 177 403
# 179 79
# 179 141
# 179 190
# 179 213
# 179 261
# 179 275
# 179 314
# 179 341
# 179 469
# 179 475
# 179 556
# 179 564
# 179 590
# 179 646
# 179 674
# 179 710
# 179 720
# 179 773
# 179 798
# 179 805
# 179 886
# 179 936
# 179 949
# 179 999
# 179 1066
# 179 1121
# 180 282
# 182 68
# 182 137
# 182 218
# 182 417
# 184 17
# 184 489
# 184 632
# 184 981
# 184 1129
# 185 187
# 185 268
# 185 319
# 185 378
# 186 151
# 186 334
# 186 623
# 188 124
# 188 130
# 188 316
# 189 398
# 190 82
# 190 213
# 190 246
# 190 257
# 190 346
# 190 408
# 190 420
# 190 487
# 191 60
# 191 482
# 192 152
# 192 267
# 192 302
# 193 118
# 193 517
# 195 146
# 195 231
# 195 250
# 195 380
# 195 473
# 195 531
# 195 672
# 195 758
# 195 868
# 197 191
# 197 199
# 197 242
# 198 130
# 198 222
# 198 233
# 198 285
# 198 422
# 199 96
# 199 120
# 199 227
# 199 241
# 199 310
# 199 362
# 199 498
# 200 31
# 200 155
# 201 96
# 202 38
# 203 41
# 203 55
# 204 19
# 204 84
# 204 139
# 204 201
# 204 311
# 204 323
# 204 370
# 204 391
# 204 421
# 204 462
# 204 502
# 204 513
# 205 167
# 205 265
# 206 61
# 206 201
# 206 337
# 207 2
# 207 99
# 207 146
# 207 149
# 207 272
# 207 281
# 207 329
# 207 393
# 207 458
# 207 473
# 207 524
# 207 545
# 208 24
# 208 132
# 208 142
# 209 114
# 209 200
# 209 258
# 209 325
# 210 253
# 210 301
# 210 339
# 210 400
# 210 470
# 210 544
# 210 577
# 210 610
# 210 698
# 210 768
# 210 787
# 210 850
# 210 928
# 210 1142
# 211 239
# 211 413
# 212 28
# 212 46
# 212 100
# 212 141
# 212 255
# 212 370
# 212 539
# 212 561
# 212 596
# 212 673
# 212 754
# 212 929
# 213 24
# 213 78
# 213 94
# 213 119
# 213 155
# 213 169
# 213 184
# 214 16
# 214 124
# 214 220
# 214 233
# 214 404
# 214 435
# 215 142
# 215 470
# 215 557
# 215 657
# 216 271
# 216 304
# 216 346
# 216 397
# 217 61
# 217 96
# 217 149
# 217 188
# 217 227
# 217 332
# 217 520
# 217 578
# 217 640
# 217 677
# 219 40
# 219 214
# 220 29
# 220 95
# 220 244
# 220 270
# 220 328
# 221 9
# 221 173
# 221 233
# 221 300
# 221 364
# 222 62
# 222 76
# 222 116
# 222 176
# 222 197
# 222 219
# 223 76
# 223 144
# 223 265
# 223 293
# 223 515
# 223 611
# 224 191
# 224 249
# 224 255
# 224 279
# 224 317
# 224 388
# 224 408
# 224 420
# 224 447
# 224 509
# 224 581
# 224 615
# 224 658
# the

# %%
q = find_quotes(nlp, docs)

# %%
# This might not show *all* quotes. My solution is not perfect either.
print(q[3])
# Out:
# [(told, Hanna Nohynek, "Thinking about it, it could probably be a way to increase the number of people protected, if the quantity of vaccines available in Finland is much less than promised,), (said, Puhakka, "Oulu is a growing city and in certain situations we have to go to so-called virgin areas), (told, Puhakka, "We believe that Oulu's forest nature conservation decisions compensate for the decisions that have to be made in different parts of the city, due to the city's natural growth)]

# %%
print(q[207])
# Out:
# [(said, Simola, "My husband immediately said that it was a wolf), (told, Simola, "It was a really touching, amazing moment. Seeing such a wild animal inside the Ring I beltway really made you rub your eyes. It was a rare situation that doesn't happen every day), (said, Simola, "We've talked today about our relationship with wildlife and how even though the wolf may look nice, it is still an unpredictable wild animal that needs to be given its own space), (said, Hallamaa, "The wolf has not growled or shown its teeth. On the contrary, it has apparently tried to escape from humans with its tail between its legs)]

# %% [markdown]
# # Further reading
#
# * https://spacy.io/usage/rule-based-matching
# * https://applied-language-technology.readthedocs.io/en/latest/notebooks/part_iii/02_pattern_matching.html
