# %% [markdown]
# <h1 id="The-perceptron-algorithm-in-NLP">The perceptron algorithm in NLP<a class="anchor-link" href="#The-perceptron-algorithm-in-NLP">¶</a></h1>

# %% [markdown]
# Homework exercise 05.02 based on a tutorial by **Robert Östling**

# %% [markdown]
# <p>Convert train and test sets into a list of tuples. First element of a tuple is a word, second element of a tuple is a language of that word.</p>

# %%
def read_file(file):
    words = []
    with open(file) as f:
        for line in f:
            line = line.rstrip("\n")
            line = line.split("\t")
            words.append((line[0], line[1]))
    return words

# %%
train_set = read_file('train.txt')
test_set = read_file('test.txt')

# %% [markdown]
# <p>The relevant morphological information is contained in (at most) the last two letters of a word. So, we write a function that can create features based on this observation:</p>

# %%
def get_features(word): return { 'first' : word[:1], 'first_two' : word[:2], 
                                 'last' : word[-1:], 'last_two': word[-2:], 'last_three': word[-3:] }

# %% [markdown]
# <p>We can now use this to create a list of features and their corresponding tag:</p>

# %%
[(get_features(word), tag) for word, tag in train_set]
# Out:
# [({'first': 'a',
#    'first_two': 'ac',
#    'last': 'e',
#    'last_two': 'ge',
#    'last_three': 'dge'},
#   'en'),
#  ({'first': 'a',
#    'first_two': 'aq',
#    'last': 'e',
#    'last_two': 'fe',
#    'last_three': 'afe'},
#   'en'),
#  ({'first': 'a',
#    'first_two': 'ar',
#    'last': 'd',
#    'last_two': 'ld',
#    'last_three': 'ald'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'ba',
#    'last': 'y',
#    'last_two': 'by',
#    'last_three': 'aby'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'ba',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'sed'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 'y',
#    'last_two': 'ry',
#    'last_three': 'ary'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 'n',
#    'last_two': 'gn',
#    'last_three': 'ign'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'bo',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ces'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'br',
#    'last': 'y',
#    'last_two': 'ay',
#    'last_three': 'way'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'br',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ing'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'br',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ant'},
#   'en'),
#  ({'first': 'b',
#    'first_two': 'bu',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ies'},
#   'en'),
#  ({'first': 'c',
#    'first_two': 'ca',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'ean'},
#   'en'),
#  ({'first': 'c',
#    'first_two': 'ch',
#    'last': 'd',
#    'last_two': 'id',
#    'last_three': 'aid'},
#   'en'),
#  ({'first': 'c',
#    'first_two': 'ch',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'ged'},
#   'en'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 'e',
#    'last_two': 'ke',
#    'last_three': 'oke'},
#   'en'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 'r',
#    'last_two': 'ar',
#    'last_three': 'lar'},
#   'en'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ing'},
#   'en'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ies'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 's',
#    'last_two': 'ls',
#    'last_three': 'als'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 'i',
#    'last_two': 'hi',
#    'last_three': 'lhi'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 'e',
#    'last_two': 're',
#    'last_three': 'ure'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'ted'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 't',
#    'last_two': 'rt',
#    'last_three': 'ert'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'di',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ent'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'di',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'ted'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'di',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ing'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'do',
#    'last': 's',
#    'last_two': 'ts',
#    'last_three': 'bts'},
#   'en'),
#  ({'first': 'd',
#    'first_two': 'dr',
#    'last': 'g',
#    'last_two': 'ag',
#    'last_three': 'rag'},
#   'en'),
#  ({'first': 'e',
#    'first_two': 'en',
#    'last': 'c',
#    'last_two': 'ic',
#    'last_three': 'dic'},
#   'en'),
#  ({'first': 'e',
#    'first_two': 'en',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ies'},
#   'en'),
#  ({'first': 'e',
#    'first_two': 'eq',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ent'},
#   'en'),
#  ({'first': 'e',
#    'first_two': 'ex',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'sed'},
#   'en'),
#  ({'first': 'e',
#    'first_two': 'ex',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'ion'},
#   'en'),
#  ({'first': 'f',
#    'first_two': 'fe',
#    'last': 'r',
#    'last_two': 'or',
#    'last_three': 'vor'},
#   'en'),
#  ({'first': 'f',
#    'first_two': 'fi',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'ded'},
#   'en'),
#  ({'first': 'f',
#    'first_two': 'fo',
#    'last': 'm',
#    'last_two': 'rm',
#    'last_three': 'orm'},
#   'en'),
#  ({'first': 'f',
#    'first_two': 'fr',
#    'last': 'p',
#    'last_two': 'ip',
#    'last_three': 'hip'},
#   'en'),
#  ({'first': 'f',
#    'first_two': 'fu',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'ion'},
#   'en'),
#  ({'first': 'g',
#    'first_two': 'gl',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ier'},
#   'en'),
#  ({'first': 'g',
#    'first_two': 'gr',
#    'last': 'o',
#    'last_two': 'ro',
#    'last_three': 'oro'},
#   'en'),
#  ({'first': 'g',
#    'first_two': 'gr',
#    'last': 'f',
#    'last_two': 'rf',
#    'last_three': 'orf'},
#   'en'),
#  ({'first': 'h',
#    'first_two': 'ha',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'unt'},
#   'en'),
#  ({'first': 'i',
#    'first_two': 'im',
#    'last': 's',
#    'last_two': 'ts',
#    'last_three': 'nts'},
#   'en'),
#  ({'first': 'i',
#    'first_two': 'im',
#    'last': 'e',
#    'last_two': 've',
#    'last_three': 'ive'},
#   'en'),
#  ({'first': 'i',
#    'first_two': 'in',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ent'},
#   'en'),
#  ({'first': 'i',
#    'first_two': 'in',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ble'},
#   'en'),
#  ({'first': 'i',
#    'first_two': 'is',
#    'last': 'a',
#    'last_two': 'ia',
#    'last_three': 'bia'},
#   'en'),
#  ({'first': 'j',
#    'first_two': 'ja',
#    'last': 'o',
#    'last_two': 'no',
#    'last_three': 'eno'},
#   'en'),
#  ({'first': 'l',
#    'first_two': 'la',
#    'last': 'e',
#    'last_two': 'ne',
#    'last_three': 'ane'},
#   'en'),
#  ({'first': 'l',
#    'first_two': 'la',
#    'last': 'a',
#    'last_two': 'ka',
#    'last_three': 'nka'},
#   'en'),
#  ({'first': 'l',
#    'first_two': 'le',
#    'last': 'e',
#    'last_two': 'ge',
#    'last_three': 'age'},
#   'en'),
#  ({'first': 'l',
#    'first_two': 'li',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'ted'},
#   'en'),
#  ({'first': 'l',
#    'first_two': 'lu',
#    'last': 'y',
#    'last_two': 'cy',
#    'last_three': 'ucy'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 'e',
#    'last_two': 'ne',
#    'last_three': 'ine'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 'e',
#    'last_two': 'ne',
#    'last_three': 'ine'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 't',
#    'last_two': 'rt',
#    'last_three': 'art'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'zed'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'mc',
#    'last': 's',
#    'last_two': 'is',
#    'last_three': 'nis'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'me',
#    'last': 't',
#    'last_two': 'st',
#    'last_three': 'est'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'me',
#    'last': 'm',
#    'last_two': 'um',
#    'last_three': 'ium'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'mi',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ele'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'mi',
#    'last': 'o',
#    'last_two': 'to',
#    'last_three': 'sto'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'mo',
#    'last': 's',
#    'last_two': 'us',
#    'last_three': 'dus'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'mo',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ale'},
#   'en'),
#  ({'first': 'm',
#    'first_two': 'mo',
#    'last': 'l',
#    'last_two': 'al',
#    'last_three': 'ral'},
#   'en'),
#  ({'first': 'n',
#    'first_two': 'ne',
#    'last': 'k',
#    'last_two': 'rk',
#    'last_three': 'ork'},
#   'en'),
#  ({'first': 'o',
#    'first_two': 'ob',
#    'last': 's',
#    'last_two': 'us',
#    'last_three': 'ous'},
#   'en'),
#  ({'first': 'o',
#    'first_two': 'or',
#    'last': 'e',
#    'last_two': 'ge',
#    'last_three': 'nge'},
#   'en'),
#  ({'first': 'p',
#    'first_two': 'pa',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ing'},
#   'en'),
#  ({'first': 'p',
#    'first_two': 'pa',
#    'last': 'y',
#    'last_two': 'ly',
#    'last_three': 'lly'},
#   'en'),
#  ({'first': 'p',
#    'first_two': 'pe',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'gon'},
#   'en'),
#  ({'first': 'p',
#    'first_two': 'ph',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'nes'},
#   'en'),
#  ({'first': 'p',
#    'first_two': 'pi',
#    'last': 'y',
#    'last_two': 'ky',
#    'last_three': 'nky'},
#   'en'),
#  ({'first': 'p',
#    'first_two': 'pl',
#    'last': 's',
#    'last_two': 'ms',
#    'last_three': 'rms'},
#   'en'),
#  ({'first': 'p',
#    'first_two': 'pr',
#    'last': 'e',
#    'last_two': 'se',
#    'last_three': 'ose'},
#   'en'),
#  ({'first': 'p',
#    'first_two': 'pu',
#    'last': 's',
#    'last_two': 'ts',
#    'last_three': 'ets'},
#   'en'),
#  ({'first': 'r',
#    'first_two': 're',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ing'},
#   'en'),
#  ({'first': 'r',
#    'first_two': 'ri',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ing'},
#   'en'),
#  ({'first': 'r',
#    'first_two': 'ro',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ies'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'sk',
#    'last': 's',
#    'last_two': 'ls',
#    'last_three': 'lls'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'sl',
#    'last': 't',
#    'last_two': 'pt',
#    'last_three': 'ept'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'sm',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ler'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'sp',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'son'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'sp',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ang'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'st',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'res'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'su',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'eed'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'su',
#    'last': 'y',
#    'last_two': 'ly',
#    'last_three': 'tly'},
#   'en'),
#  ({'first': 's',
#    'first_two': 'sy',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'zes'},
#   'en'),
#  ({'first': 't',
#    'first_two': 'ta',
#    'last': 'k',
#    'last_two': 'lk',
#    'last_three': 'alk'},
#   'en'),
#  ({'first': 't',
#    'first_two': 'ta',
#    'last': 's',
#    'last_two': 'ls',
#    'last_three': 'ils'},
#   'en'),
#  ({'first': 't',
#    'first_two': 'te',
#    'last': 'r',
#    'last_two': 'ar',
#    'last_three': 'ear'},
#   'en'),
#  ({'first': 't',
#    'first_two': 'te',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ger'},
#   'en'),
#  ({'first': 't',
#    'first_two': 'ti',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'tle'},
#   'en'),
#  ({'first': 't',
#    'first_two': 'to',
#    'last': 'h',
#    'last_two': 'ch',
#    'last_three': 'uch'},
#   'en'),
#  ({'first': 't',
#    'first_two': 'tu',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ver'},
#   'en'),
#  ({'first': 'u',
#    'first_two': 'un',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ble'},
#   'en'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ant'},
#   'en'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'y',
#    'last_two': 'ly',
#    'last_three': 'tly'},
#   'en'),
#  ({'first': 'w',
#    'first_two': 'we',
#    'last': 'y',
#    'last_two': 'hy',
#    'last_three': 'thy'},
#   'en'),
#  ({'first': 'a',
#    'first_two': 'al',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'lla'},
#   'fi'),
#  ({'first': 'a',
#    'first_two': 'as',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'ain'},
#   'fi'),
#  ({'first': 'e',
#    'first_two': 'ed',
#    'last': 'ä',
#    'last_two': 'tä',
#    'last_three': 'stä'},
#   'fi'),
#  ({'first': 'e',
#    'first_two': 'el',
#    'last': 'e',
#    'last_two': 'me',
#    'last_three': 'mme'},
#   'fi'),
#  ({'first': 'e',
#    'first_two': 'el',
#    'last': 'n',
#    'last_two': 'ön',
#    'last_three': 'tön'},
#   'fi'),
#  ({'first': 'e',
#    'first_two': 'ep',
#    'last': 'a',
#    'last_two': 'ia',
#    'last_three': 'tia'},
#   'fi'),
#  ({'first': 'g',
#    'first_two': 'ge',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'sen'},
#   'fi'),
#  ({'first': 'h',
#    'first_two': 'ha',
#    'last': 'i',
#    'last_two': 'si',
#    'last_three': 'isi'},
#   'fi'),
#  ({'first': 'h',
#    'first_two': 'he',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'son'},
#   'fi'),
#  ({'first': 'h',
#    'first_two': 'hu',
#    'last': 't',
#    'last_two': 'it',
#    'last_three': 'sit'},
#   'fi'),
#  ({'first': 'h',
#    'first_two': 'hu',
#    'last': 'i',
#    'last_two': 'vi',
#    'last_three': 'svi'},
#   'fi'),
#  ({'first': 'i',
#    'first_two': 'it',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'set'},
#   'fi'),
#  ({'first': 'i',
#    'first_two': 'it',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'nen'},
#   'fi'),
#  ({'first': 'j',
#    'first_two': 'ja',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'ien'},
#   'fi'),
#  ({'first': 'j',
#    'first_two': 'ja',
#    'last': 'a',
#    'last_two': 'oa',
#    'last_three': 'koa'},
#   'fi'),
#  ({'first': 'j',
#    'first_two': 'jo',
#    'last': 't',
#    'last_two': 'at',
#    'last_three': 'vat'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ka',
#    'last': 'a',
#    'last_two': 'ta',
#    'last_three': 'tta'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ka',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'lla'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ka',
#    'last': 't',
#    'last_two': 'at',
#    'last_three': 'vat'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ka',
#    'last': 't',
#    'last_two': 'ut',
#    'last_three': 'nut'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ka',
#    'last': 'a',
#    'last_two': 'sa',
#    'last_three': 'nsa'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'kä',
#    'last': 't',
#    'last_two': 'ät',
#    'last_three': 'tät'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ke',
#    'last': 'ä',
#    'last_two': 'tä',
#    'last_three': 'itä'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ke',
#    'last': 'n',
#    'last_two': 'än',
#    'last_three': 'ään'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ki',
#    'last': 't',
#    'last_two': 'ät',
#    'last_three': 'vät'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ki',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'aan'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ki',
#    'last': 'ä',
#    'last_two': 'iä',
#    'last_three': 'viä'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ki',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'een'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ko',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'eet'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ko',
#    'last': 't',
#    'last_two': 'ot',
#    'last_three': 'rot'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'kö',
#    'last': 'ä',
#    'last_two': 'tä',
#    'last_three': 'ttä'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ku',
#    'last': 'a',
#    'last_two': 'va',
#    'last_three': 'eva'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ku',
#    'last': 'a',
#    'last_two': 'ja',
#    'last_three': 'ija'},
#   'fi'),
#  ({'first': 'k',
#    'first_two': 'ku',
#    'last': 't',
#    'last_two': 'at',
#    'last_three': 'aat'},
#   'fi'),
#  ({'first': 'l',
#    'first_two': 'lä',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'sen'},
#   'fi'),
#  ({'first': 'l',
#    'first_two': 'la',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'lla'},
#   'fi'),
#  ({'first': 'l',
#    'first_two': 'le',
#    'last': 's',
#    'last_two': 'ys',
#    'last_three': 'yys'},
#   'fi'),
#  ({'first': 'l',
#    'first_two': 'li',
#    'last': 'a',
#    'last_two': 'sa',
#    'last_three': 'nsa'},
#   'fi'),
#  ({'first': 'l',
#    'first_two': 'li',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'kin'},
#   'fi'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'sen'},
#   'fi'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'ken'},
#   'fi'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'ton'},
#   'fi'),
#  ({'first': 'm',
#    'first_two': 'mi',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'lin'},
#   'fi'),
#  ({'first': 'm',
#    'first_two': 'mu',
#    'last': 'a',
#    'last_two': 'aa',
#    'last_three': 'vaa'},
#   'fi'),
#  ({'first': 'n',
#    'first_two': 'ne',
#    'last': 'a',
#    'last_two': 'ja',
#    'last_three': 'oja'},
#   'fi'),
#  ({'first': 'n',
#    'first_two': 'no',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'lle'},
#   'fi'),
#  ({'first': 'n',
#    'first_two': 'no',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'aan'},
#   'fi'),
#  ({'first': 'n',
#    'first_two': 'nu',
#    'last': 'i',
#    'last_two': 'ni',
#    'last_three': 'ani'},
#   'fi'),
#  ({'first': 'n',
#    'first_two': 'nu',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'kan'},
#   'fi'),
#  ({'first': 'n',
#    'first_two': 'ny',
#    'last': 'n',
#    'last_two': 'än',
#    'last_three': 'ään'},
#   'fi'),
#  ({'first': 'o',
#    'first_two': 'ob',
#    'last': 'a',
#    'last_two': 'ta',
#    'last_three': 'sta'},
#   'fi'),
#  ({'first': 'ö',
#    'first_two': 'öl',
#    'last': 'a',
#    'last_two': 'ma',
#    'last_three': 'ama'},
#   'fi'),
#  ({'first': 'o',
#    'first_two': 'om',
#    'last': 'a',
#    'last_two': 'aa',
#    'last_three': 'maa'},
#   'fi'),
#  ({'first': 'o',
#    'first_two': 'op',
#    'last': 'o',
#    'last_two': 'jo',
#    'last_three': 'hjo'},
#   'fi'),
#  ({'first': 'o',
#    'first_two': 'op',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'kan'},
#   'fi'),
#  ({'first': 'o',
#    'first_two': 'os',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'een'},
#   'fi'),
#  ({'first': 'p',
#    'first_two': 'pä',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'oin'},
#   'fi'),
#  ({'first': 'p',
#    'first_two': 'pe',
#    'last': 'a',
#    'last_two': 'sa',
#    'last_three': 'nsa'},
#   'fi'),
#  ({'first': 'p',
#    'first_two': 'pe',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'lla'},
#   'fi'),
#  ({'first': 'p',
#    'first_two': 'pe',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'vin'},
#   'fi'),
#  ({'first': 'p',
#    'first_two': 'pu',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'men'},
#   'fi'),
#  ({'first': 'p',
#    'first_two': 'pu',
#    'last': 'a',
#    'last_two': 'ja',
#    'last_three': 'eja'},
#   'fi'),
#  ({'first': 'r',
#    'first_two': 'ra',
#    'last': 't',
#    'last_two': 'ut',
#    'last_three': 'nut'},
#   'fi'),
#  ({'first': 'r',
#    'first_two': 'ro',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'son'},
#   'fi'),
#  ({'first': 'r',
#    'first_two': 'ro',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'ian'},
#   'fi'),
#  ({'first': 'r',
#    'first_two': 'ru',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'lla'},
#   'fi'),
#  ({'first': 'r',
#    'first_two': 'ry',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'nen'},
#   'fi'),
#  ({'first': 's',
#    'first_two': 'sa',
#    'last': 'i',
#    'last_two': 'ti',
#    'last_three': 'tti'},
#   'fi'),
#  ({'first': 's',
#    'first_two': 'se',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'jen'},
#   'fi'),
#  ({'first': 's',
#    'first_two': 'se',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'kin'},
#   'fi'),
#  ({'first': 's',
#    'first_two': 'st',
#    'last': 'i',
#    'last_two': 'ni',
#    'last_three': 'ani'},
#   'fi'),
#  ({'first': 's',
#    'first_two': 'su',
#    'last': 'd',
#    'last_two': 'nd',
#    'last_three': 'und'},
#   'fi'),
#  ({'first': 's',
#    'first_two': 'su',
#    'last': 'a',
#    'last_two': 'ia',
#    'last_three': 'sia'},
#   'fi'),
#  ({'first': 's',
#    'first_two': 'su',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'aan'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'ta',
#    'last': 'a',
#    'last_two': 'ja',
#    'last_three': 'oja'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'ta',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'hin'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'ta',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'lla'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'to',
#    'last': 'a',
#    'last_two': 'aa',
#    'last_three': 'paa'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'to',
#    'last': 'a',
#    'last_two': 'ta',
#    'last_three': 'sta'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'to',
#    'last': 'a',
#    'last_two': 'ia',
#    'last_three': 'pia'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'to',
#    'last': 'i',
#    'last_two': 'si',
#    'last_three': 'osi'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'tr',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'iin'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'tr',
#    'last': 'i',
#    'last_two': 'ri',
#    'last_three': 'eri'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'tu',
#    'last': 'e',
#    'last_two': 'te',
#    'last_three': 'tte'},
#   'fi'),
#  ({'first': 't',
#    'first_two': 'tu',
#    'last': 'i',
#    'last_two': 'si',
#    'last_three': 'ksi'},
#   'fi'),
#  ({'first': 'u',
#    'first_two': 'uh',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'aan'},
#   'fi'),
#  ({'first': 'u',
#    'first_two': 'uu',
#    'last': 'a',
#    'last_two': 'ia',
#    'last_three': 'sia'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'a',
#    'last_two': 'aa',
#    'last_three': 'taa'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'aan'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'oan'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'sen'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'lla'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'i',
#    'last_two': 'si',
#    'last_three': 'ksi'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'sin'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 've',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'kan'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 've',
#    'last': 'n',
#    'last_two': 'in',
#    'last_three': 'iin'},
#   'fi'),
#  ({'first': 'v',
#    'first_two': 'vi',
#    'last': 't',
#    'last_two': 'it',
#    'last_three': 'sit'},
#   'fi'),
#  ({'first': 'y',
#    'first_two': 'yh',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'set'},
#   'fi'),
#  ({'first': 'y',
#    'first_two': 'yk',
#    'last': 'n',
#    'last_two': 'än',
#    'last_three': 'ään'},
#   'fi'),
#  ({'first': 'y',
#    'first_two': 'yl',
#    'last': 'ä',
#    'last_two': 'ää',
#    'last_three': 'tää'},
#   'fi'),
#  ({'first': 'a',
#    'first_two': 'ac',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'ion'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'ad',
#    'last': 's',
#    'last_two': 'ns',
#    'last_three': 'ons'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'ai',
#    'last': 'e',
#    'last_two': 're',
#    'last_three': 'ire'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'al',
#    'last': 'e',
#    'last_two': 'te',
#    'last_three': 'nte'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'al',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ent'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'al',
#    'last': 'e',
#    'last_two': 'ée',
#    'last_three': 'rée'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'an',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'lle'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'ar',
#    'last': 'e',
#    'last_two': 'ie',
#    'last_three': 'mie'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'as',
#    'last': 'e',
#    'last_two': 're',
#    'last_three': 'ire'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'at',
#    'last': 'e',
#    'last_two': 'ue',
#    'last_three': 'que'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'au',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ant'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'av',
#    'last': 'r',
#    'last_two': 'ir',
#    'last_three': 'oir'},
#   'fr'),
#  ({'first': 'b',
#    'first_two': 'ba',
#    'last': 'i',
#    'last_two': 'si',
#    'last_three': 'asi'},
#   'fr'),
#  ({'first': 'b',
#    'first_two': 'ba',
#    'last': 'é',
#    'last_two': 'lé',
#    'last_three': 'ulé'},
#   'fr'),
#  ({'first': 'b',
#    'first_two': 'bl',
#    'last': 'e',
#    'last_two': 'me',
#    'last_three': 'ème'},
#   'fr'),
#  ({'first': 'b',
#    'first_two': 'bo',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ier'},
#   'fr'),
#  ({'first': 'c',
#    'first_two': 'ca',
#    'last': 'e',
#    'last_two': 'ne',
#    'last_three': 'nne'},
#   'fr'),
#  ({'first': 'c',
#    'first_two': 'ca',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'rer'},
#   'fr'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ale'},
#   'fr'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 'é',
#    'last_two': 'ré',
#    'last_three': 'aré'},
#   'fr'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 'f',
#    'last_two': 'if',
#    'last_three': 'tif'},
#   'fr'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 'i',
#    'last_two': 'ni',
#    'last_three': 'ini'},
#   'fr'),
#  ({'first': 'd',
#    'first_two': 'dé',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ont'},
#   'fr'),
#  ({'first': 'd',
#    'first_two': 'dé',
#    'last': 'p',
#    'last_two': 'ap',
#    'last_three': 'fap'},
#   'fr'),
#  ({'first': 'd',
#    'first_two': 'dé',
#    'last': 'x',
#    'last_two': 'ux',
#    'last_three': 'eux'},
#   'fr'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 's',
#    'last_two': 'os',
#    'last_three': 'ros'},
#   'fr'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ées'},
#   'fr'),
#  ({'first': 'd',
#    'first_two': 'di',
#    'last': 'd',
#    'last_two': 'nd',
#    'last_three': 'ond'},
#   'fr'),
#  ({'first': 'd',
#    'first_two': 'di',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'jon'},
#   'fr'),
#  ({'first': 'd',
#    'first_two': 'do',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ées'},
#   'fr'),
#  ({'first': 'e',
#    'first_two': 'ec',
#    'last': 't',
#    'last_two': 'rt',
#    'last_three': 'art'},
#   'fr'),
#  ({'first': 'e',
#    'first_two': 'el',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'lla'},
#   'fr'),
#  ({'first': 'e',
#    'first_two': 'em',
#    'last': 'e',
#    'last_two': 'se',
#    'last_three': 'ise'},
#   'fr'),
#  ({'first': 'e',
#    'first_two': 'en',
#    'last': 'e',
#    'last_two': 'pe',
#    'last_three': 'ppe'},
#   'fr'),
#  ({'first': 'e',
#    'first_two': 'ex',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'tes'},
#   'fr'),
#  ({'first': 'e',
#    'first_two': 'ex',
#    'last': 't',
#    'last_two': 'it',
#    'last_three': 'oit'},
#   'fr'),
#  ({'first': 'f',
#    'first_two': 'fe',
#    'last': 'm',
#    'last_two': 'im',
#    'last_three': 'eim'},
#   'fr'),
#  ({'first': 'f',
#    'first_two': 'fl',
#    'last': 'é',
#    'last_two': 'té',
#    'last_three': 'ité'},
#   'fr'),
#  ({'first': 'f',
#    'first_two': 'fo',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ant'},
#   'fr'),
#  ({'first': 'f',
#    'first_two': 'fo',
#    'last': 'r',
#    'last_two': 'ur',
#    'last_three': 'eur'},
#   'fr'),
#  ({'first': 'g',
#    'first_two': 'ga',
#    'last': 's',
#    'last_two': 'ns',
#    'last_three': 'ons'},
#   'fr'),
#  ({'first': 'g',
#    'first_two': 'ga',
#    'last': 's',
#    'last_two': 'rs',
#    'last_three': 'ars'},
#   'fr'),
#  ({'first': 'g',
#    'first_two': 'gu',
#    'last': 't',
#    'last_two': 'at',
#    'last_three': 'rat'},
#   'fr'),
#  ({'first': 'h',
#    'first_two': 'hé',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ger'},
#   'fr'),
#  ({'first': 'h',
#    'first_two': 'ho',
#    'last': 'é',
#    'last_two': 'té',
#    'last_three': 'ité'},
#   'fr'),
#  ({'first': 'i',
#    'first_two': 'in',
#    'last': 's',
#    'last_two': 'és',
#    'last_three': 'tés'},
#   'fr'),
#  ({'first': 'i',
#    'first_two': 'in',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ées'},
#   'fr'),
#  ({'first': 'l',
#    'first_two': 'lo',
#    'last': 's',
#    'last_two': 'rs',
#    'last_three': 'irs'},
#   'fr'),
#  ({'first': 'l',
#    'first_two': 'lo',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'zer'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'mé',
#    'last': 'l',
#    'last_two': 'al',
#    'last_three': 'ial'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'me',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'lle'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'mi',
#    'last': 'd',
#    'last_two': 'ed',
#    'last_three': 'red'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'mi',
#    'last': 'e',
#    'last_two': 'me',
#    'last_three': 'sme'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'mi',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ile'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'mo',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ent'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'mo',
#    'last': 'o',
#    'last_two': 'io',
#    'last_three': 'sio'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'mu',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ier'},
#   'fr'),
#  ({'first': 'm',
#    'first_two': 'mu',
#    'last': 'a',
#    'last_two': 'oa',
#    'last_three': 'loa'},
#   'fr'),
#  ({'first': 'n',
#    'first_two': 'na',
#    'last': 'e',
#    'last_two': 'ée',
#    'last_three': 'gée'},
#   'fr'),
#  ({'first': 'n',
#    'first_two': 'na',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ale'},
#   'fr'),
#  ({'first': 'n',
#    'first_two': 'né',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ent'},
#   'fr'),
#  ({'first': 'o',
#    'first_two': 'oe',
#    'last': 'e',
#    'last_two': 'ne',
#    'last_three': 'ène'},
#   'fr'),
#  ({'first': 'o',
#    'first_two': 'om',
#    'last': 'a',
#    'last_two': 'ga',
#    'last_three': 'éga'},
#   'fr'),
#  ({'first': 'o',
#    'first_two': 'op',
#    'last': 'e',
#    'last_two': 'ue',
#    'last_three': 'que'},
#   'fr'),
#  ({'first': 'o',
#    'first_two': 'or',
#    'last': 'x',
#    'last_two': 'ux',
#    'last_three': 'aux'},
#   'fr'),
#  ({'first': 'o',
#    'first_two': 'os',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'ion'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pa',
#    'last': 'e',
#    'last_two': 'ne',
#    'last_three': 'ine'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pa',
#    'last': 'e',
#    'last_two': 'ée',
#    'last_three': 'lée'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pa',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ser'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pa',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'res'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pl',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ent'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pl',
#    'last': 'e',
#    'last_two': 'me',
#    'last_three': 'ume'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'po',
#    'last': 's',
#    'last_two': 'rs',
#    'last_three': 'ers'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pr',
#    'last': 't',
#    'last_two': 'it',
#    'last_three': 'ait'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pr',
#    'last': 't',
#    'last_two': 'it',
#    'last_three': 'ait'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pr',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'jet'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pr',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'ues'},
#   'fr'),
#  ({'first': 'p',
#    'first_two': 'pr',
#    'last': 's',
#    'last_two': 'ns',
#    'last_three': 'ons'},
#   'fr'),
#  ({'first': 'r',
#    'first_two': 're',
#    'last': 'o',
#    'last_two': 'no',
#    'last_three': 'ino'},
#   'fr'),
#  ({'first': 'r',
#    'first_two': 'ré',
#    'last': 't',
#    'last_two': 'it',
#    'last_three': 'dit'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'sa',
#    'last': 'e',
#    'last_two': 'ye',
#    'last_three': 'aye'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'se',
#    'last': 's',
#    'last_two': 'ns',
#    'last_three': 'ons'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'se',
#    'last': 'z',
#    'last_two': 'ez',
#    'last_three': 'rez'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'se',
#    'last': 's',
#    'last_two': 'os',
#    'last_three': 'ros'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'si',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ant'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'si',
#    'last': 'e',
#    'last_two': 'ée',
#    'last_three': 'née'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'sl',
#    'last': 'e',
#    'last_two': 'ne',
#    'last_three': 'ane'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'so',
#    'last': 'o',
#    'last_two': 'no',
#    'last_three': 'ino'},
#   'fr'),
#  ({'first': 's',
#    'first_two': 'su',
#    'last': 's',
#    'last_two': 'ns',
#    'last_three': 'ons'},
#   'fr'),
#  ({'first': 't',
#    'first_two': 'tc',
#    'last': 'u',
#    'last_two': 'eu',
#    'last_three': 'heu'},
#   'fr'),
#  ({'first': 't',
#    'first_two': 'to',
#    'last': 't',
#    'last_two': 'st',
#    'last_three': 'ast'},
#   'fr'),
#  ({'first': 't',
#    'first_two': 'to',
#    'last': 'a',
#    'last_two': 'ta',
#    'last_three': 'ota'},
#   'fr'),
#  ({'first': 't',
#    'first_two': 'tr',
#    'last': 'r',
#    'last_two': 'ar',
#    'last_three': 'gar'},
#   'fr'),
#  ({'first': 't',
#    'first_two': 'tu',
#    'last': 'l',
#    'last_two': 'el',
#    'last_three': 'nel'},
#   'fr'),
#  ({'first': 'u',
#    'first_two': 'uc',
#    'last': 'r',
#    'last_two': 'ar',
#    'last_three': 'car'},
#   'fr'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 'o',
#    'last_two': 'ro',
#    'last_three': 'ero'},
#   'fr'),
#  ({'first': 'v',
#    'first_two': 'vo',
#    'last': 'e',
#    'last_two': 'te',
#    'last_three': 'ste'},
#   'fr'),
#  ({'first': 'v',
#    'first_two': 'vo',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ile'},
#   'fr'),
#  ({'first': 'w',
#    'first_two': 'wa',
#    'last': 'e',
#    'last_two': 'ce',
#    'last_three': 'ace'},
#   'fr'),
#  ({'first': 'y',
#    'first_two': 'ya',
#    'last': 'e',
#    'last_two': 'te',
#    'last_three': 'ate'},
#   'fr'),
#  ({'first': 'a',
#    'first_two': 'ab',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'det'},
#   'de'),
#  ({'first': 'A',
#    'first_two': 'Ad',
#    'last': 's',
#    'last_two': 'ms',
#    'last_three': 'ams'},
#   'de'),
#  ({'first': 'A',
#    'first_two': 'Ag',
#    'last': 'v',
#    'last_two': 'iv',
#    'last_three': 'giv'},
#   'de'),
#  ({'first': 'a',
#    'first_two': 'an',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'men'},
#   'de'),
#  ({'first': 'a',
#    'first_two': 'au',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'den'},
#   'de'),
#  ({'first': 'A',
#    'first_two': 'Au',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'gen'},
#   'de'),
#  ({'first': 'B',
#    'first_two': 'Be',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ung'},
#   'de'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'nnt'},
#   'de'),
#  ({'first': 'B',
#    'first_two': 'Bu',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'gen'},
#   'de'),
#  ({'first': 'C',
#    'first_two': 'Ca',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'men'},
#   'de'),
#  ({'first': 'C',
#    'first_two': 'Ca',
#    'last': 'a',
#    'last_two': 'ca',
#    'last_three': 'uca'},
#   'de'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 'e',
#    'last_two': 'ge',
#    'last_three': 'ige'},
#   'de'),
#  ({'first': 'D',
#    'first_two': 'Di',
#    'last': 'e',
#    'last_two': 'me',
#    'last_three': 'ome'},
#   'de'),
#  ({'first': 'd',
#    'first_two': 'du',
#    'last': 't',
#    'last_two': 'rt',
#    'last_three': 'ert'},
#   'de'),
#  ({'first': 'd',
#    'first_two': 'du',
#    'last': 't',
#    'last_two': 'ht',
#    'last_three': 'eht'},
#   'de'),
#  ({'first': 'e',
#    'first_two': 'ef',
#    'last': 'y',
#    'last_two': 'cy',
#    'last_three': 'ncy'},
#   'de'),
#  ({'first': 'e',
#    'first_two': 'el',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'hen'},
#   'de'),
#  ({'first': 'E',
#    'first_two': 'Em',
#    'last': 'a',
#    'last_two': 'ia',
#    'last_three': 'lia'},
#   'de'),
#  ({'first': 'E',
#    'first_two': 'En',
#    'last': 'e',
#    'last_two': 'ie',
#    'last_three': 'mie'},
#   'de'),
#  ({'first': 'E',
#    'first_two': 'En',
#    'last': 'm',
#    'last_two': 'um',
#    'last_three': 'rum'},
#   'de'),
#  ({'first': 'E',
#    'first_two': 'Er',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'hes'},
#   'de'),
#  ({'first': 'E',
#    'first_two': 'Es',
#    'last': 'h',
#    'last_two': 'ch',
#    'last_three': 'ach'},
#   'de'),
#  ({'first': 'E',
#    'first_two': 'Ex',
#    'last': 'e',
#    'last_two': 'ce',
#    'last_three': 'nce'},
#   'de'),
#  ({'first': 'F',
#    'first_two': 'Fa',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'per'},
#   'de'),
#  ({'first': 'F',
#    'first_two': 'Fe',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'nen'},
#   'de'),
#  ({'first': 'F',
#    'first_two': 'Fö',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'gen'},
#   'de'),
#  ({'first': 'G',
#    'first_two': 'Ga',
#    'last': 'y',
#    'last_two': 'ay',
#    'last_three': 'ray'},
#   'de'),
#  ({'first': 'g',
#    'first_two': 'ga',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'hen'},
#   'de'),
#  ({'first': 'g',
#    'first_two': 'ge',
#    'last': 'g',
#    'last_two': 'ig',
#    'last_three': 'hig'},
#   'de'),
#  ({'first': 'G',
#    'first_two': 'Ge',
#    'last': 'p',
#    'last_two': 'op',
#    'last_three': 'top'},
#   'de'),
#  ({'first': 'G',
#    'first_two': 'Gl',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ung'},
#   'de'),
#  ({'first': 'G',
#    'first_two': 'Gr',
#    'last': 'e',
#    'last_two': 'he',
#    'last_three': 'che'},
#   'de'),
#  ({'first': 'h',
#    'first_two': 'hö',
#    'last': 'e',
#    'last_two': 'he',
#    'last_three': 'che'},
#   'de'),
#  ({'first': 'i',
#    'first_two': 'in',
#    'last': 't',
#    'last_two': 'rt',
#    'last_three': 'ert'},
#   'de'),
#  ({'first': 'k',
#    'first_two': 'ka',
#    'last': 'm',
#    'last_two': 'em',
#    'last_three': 'hem'},
#   'de'),
#  ({'first': 'K',
#    'first_two': 'Ku',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'tan'},
#   'de'),
#  ({'first': 'L',
#    'first_two': 'La',
#    'last': 'p',
#    'last_two': 'pp',
#    'last_three': 'upp'},
#   'de'),
#  ({'first': 'L',
#    'first_two': 'La',
#    'last': 'b',
#    'last_two': 'eb',
#    'last_three': 'ieb'},
#   'de'),
#  ({'first': 'l',
#    'first_two': 'la',
#    'last': 't',
#    'last_two': 'ßt',
#    'last_three': 'aßt'},
#   'de'),
#  ({'first': 'L',
#    'first_two': 'Le',
#    'last': 'd',
#    'last_two': 'nd',
#    'last_three': 'and'},
#   'de'),
#  ({'first': 'L',
#    'first_two': 'Le',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'kon'},
#   'de'),
#  ({'first': 'L',
#    'first_two': 'Li',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'hen'},
#   'de'),
#  ({'first': 'L',
#    'first_two': 'Lo',
#    'last': 't',
#    'last_two': 'ät',
#    'last_three': 'tät'},
#   'de'),
#  ({'first': 'L',
#    'first_two': 'Lo',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'wer'},
#   'de'),
#  ({'first': 'l',
#    'first_two': 'lu',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'den'},
#   'de'),
#  ({'first': 'L',
#    'first_two': 'Lu',
#    'last': 'n',
#    'last_two': 'rn',
#    'last_three': 'ern'},
#   'de'),
#  ({'first': 'M',
#    'first_two': 'Ma',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ger'},
#   'de'),
#  ({'first': 'M',
#    'first_two': 'Ma',
#    'last': 's',
#    'last_two': 'ms',
#    'last_three': 'lms'},
#   'de'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 'h',
#    'last_two': 'ch',
#    'last_three': 'sch'},
#   'de'),
#  ({'first': 'm',
#    'first_two': 'me',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'den'},
#   'de'),
#  ({'first': 'M',
#    'first_two': 'Me',
#    'last': 'l',
#    'last_two': 'ol',
#    'last_three': 'nol'},
#   'de'),
#  ({'first': 'M',
#    'first_two': 'Mi',
#    'last': 'e',
#    'last_two': 'he',
#    'last_three': 'öhe'},
#   'de'),
#  ({'first': 'M',
#    'first_two': 'Mo',
#    'last': 's',
#    'last_two': 'ts',
#    'last_three': 'ats'},
#   'de'),
#  ({'first': 'm',
#    'first_two': 'mu',
#    'last': 't',
#    'last_two': 'rt',
#    'last_three': 'ert'},
#   'de'),
#  ({'first': 'N',
#    'first_two': 'Na',
#    'last': 'i',
#    'last_two': 'ni',
#    'last_three': 'ini'},
#   'de'),
#  ({'first': 'N',
#    'first_two': 'No',
#    'last': 'e',
#    'last_two': 'ge',
#    'last_three': 'age'},
#   'de'),
#  ({'first': 'N',
#    'first_two': 'Nu',
#    'last': 'f',
#    'last_two': 'nf',
#    'last_three': 'anf'},
#   'de'),
#  ({'first': 'O',
#    'first_two': 'Ob',
#    'last': 'u',
#    'last_two': 'au',
#    'last_three': 'gau'},
#   'de'),
#  ({'first': 'O',
#    'first_two': 'Oh',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ung'},
#   'de'),
#  ({'first': 'o',
#    'first_two': 'op',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'hen'},
#   'de'),
#  ({'first': 'P',
#    'first_two': 'Pa',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'den'},
#   'de'),
#  ({'first': 'P',
#    'first_two': 'Ph',
#    'last': 's',
#    'last_two': 'ys',
#    'last_three': 'hys'},
#   'de'),
#  ({'first': 'r',
#    'first_two': 're',
#    'last': 'e',
#    'last_two': 'te',
#    'last_three': 'lte'},
#   'de'),
#  ({'first': 'R',
#    'first_two': 'Re',
#    'last': 'e',
#    'last_two': 'ue',
#    'last_three': 'eue'},
#   'de'),
#  ({'first': 'r',
#    'first_two': 'ro',
#    'last': 'e',
#    'last_two': 'se',
#    'last_three': 'sse'},
#   'de'),
#  ({'first': 'R',
#    'first_two': 'Rü',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'den'},
#   'de'),
#  ({'first': 'R',
#    'first_two': 'Ru',
#    'last': 's',
#    'last_two': 'ss',
#    'last_three': 'uss'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'Sa',
#    'last': 'e',
#    'last_two': 'me',
#    'last_three': 'ome'},
#   'de'),
#  ({'first': 's',
#    'first_two': 'sc',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'tes'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'Si',
#    'last': 'e',
#    'last_two': 'ne',
#    'last_three': 'üne'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'So',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'gen'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'Sp',
#    'last': 'f',
#    'last_two': 'rf',
#    'last_three': 'orf'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'St',
#    'last': 'd',
#    'last_two': 'nd',
#    'last_three': 'and'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'St',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'fen'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'St',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'ten'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'St',
#    'last': 's',
#    'last_two': 'ms',
#    'last_three': 'ums'},
#   'de'),
#  ({'first': 'S',
#    'first_two': 'Sü',
#    'last': 'd',
#    'last_two': 'nd',
#    'last_three': 'and'},
#   'de'),
#  ({'first': 'T',
#    'first_two': 'Te',
#    'last': 'd',
#    'last_two': 'nd',
#    'last_three': 'and'},
#   'de'),
#  ({'first': 'T',
#    'first_two': 'Th',
#    'last': 'l',
#    'last_two': 'il',
#    'last_three': 'eil'},
#   'de'),
#  ({'first': 'T',
#    'first_two': 'Th',
#    'last': 'a',
#    'last_two': 'ra',
#    'last_three': 'yra'},
#   'de'),
#  ({'first': 'T',
#    'first_two': 'To',
#    'last': 'e',
#    'last_two': 'ze',
#    'last_three': 'tze'},
#   'de'),
#  ({'first': 't',
#    'first_two': 'to',
#    'last': 'e',
#    'last_two': 'le',
#    'last_three': 'ale'},
#   'de'),
#  ({'first': 'T',
#    'first_two': 'To',
#    'last': 'l',
#    'last_two': 'el',
#    'last_three': 'kel'},
#   'de'),
#  ({'first': 'ü',
#    'first_two': 'üb',
#    'last': 't',
#    'last_two': 'mt',
#    'last_three': 'rmt'},
#   'de'),
#  ({'first': 'u',
#    'first_two': 'um',
#    'last': 'e',
#    'last_two': 'de',
#    'last_three': 'nde'},
#   'de'),
#  ({'first': 'u',
#    'first_two': 'un',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'det'},
#   'de'),
#  ({'first': 'u',
#    'first_two': 'un',
#    'last': 'g',
#    'last_two': 'ig',
#    'last_three': 'dig'},
#   'de'),
#  ({'first': 'V',
#    'first_two': 'Va',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'ion'},
#   'de'),
#  ({'first': 'v',
#    'first_two': 've',
#    'last': 't',
#    'last_two': 'rt',
#    'last_three': 'ert'},
#   'de'),
#  ({'first': 'v',
#    'first_two': 've',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'det'},
#   'de'),
#  ({'first': 'v',
#    'first_two': 've',
#    'last': 't',
#    'last_two': 'ut',
#    'last_three': 'eut'},
#   'de'),
#  ({'first': 'V',
#    'first_two': 'Vo',
#    'last': 't',
#    'last_two': 'st',
#    'last_three': 'ist'},
#   'de'),
#  ({'first': 'v',
#    'first_two': 'vo',
#    'last': 'm',
#    'last_two': 'em',
#    'last_three': 'tem'},
#   'de'),
#  ({'first': 'w',
#    'first_two': 'we',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'der'},
#   'de'),
#  ({'first': 'W',
#    'first_two': 'We',
#    'last': 't',
#    'last_two': 'ot',
#    'last_three': 'pot'},
#   'de'),
#  ({'first': 'W',
#    'first_two': 'We',
#    'last': 'k',
#    'last_two': 'rk',
#    'last_three': 'erk'},
#   'de'),
#  ({'first': 'w',
#    'first_two': 'we',
#    'last': 'h',
#    'last_two': 'ch',
#    'last_three': 'ich'},
#   'de'),
#  ({'first': 'W',
#    'first_two': 'Wi',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'gen'},
#   'de'),
#  ({'first': 'z',
#    'first_two': 'za',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'hen'},
#   'de'),
#  ({'first': 'Z',
#    'first_two': 'Ze',
#    'last': 't',
#    'last_two': 'ht',
#    'last_three': 'cht'},
#   'de'),
#  ({'first': 'a',
#    'first_two': 'al',
#    'last': 'a',
#    'last_two': 'ga',
#    'last_three': 'iga'},
#   'sv'),
#  ({'first': 'ä',
#    'first_two': 'äm',
#    'last': 'l',
#    'last_two': 'll',
#    'last_three': 'åll'},
#   'sv'),
#  ({'first': 'a',
#    'first_two': 'an',
#    'last': 'a',
#    'last_two': 'sa',
#    'last_three': 'ssa'},
#   'sv'),
#  ({'first': 'a',
#    'first_two': 'ar',
#    'last': 'a',
#    'last_two': 'ka',
#    'last_three': 'ska'},
#   'sv'),
#  ({'first': 'a',
#    'first_two': 'av',
#    'last': 'v',
#    'last_two': 'av',
#    'last_three': 'gav'},
#   'sv'),
#  ({'first': 'a',
#    'first_two': 'av',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ler'},
#   'sv'),
#  ({'first': 'a',
#    'first_two': 'av',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'het'},
#   'sv'),
#  ({'first': 'a',
#    'first_two': 'av',
#    'last': 'l',
#    'last_two': 'al',
#    'last_three': 'tal'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'ba',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'det'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'ba',
#    'last': 'a',
#    'last_two': 'na',
#    'last_three': 'rna'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'sen'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 'd',
#    'last_two': 'ad',
#    'last_three': 'sad'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'het'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 'r',
#    'last_two': 'ör',
#    'last_three': 'rör'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'den'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'be',
#    'last': 'r',
#    'last_two': 'ar',
#    'last_three': 'tar'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'bi',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'len'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'bo',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'det'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'br',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'het'},
#   'sv'),
#  ({'first': 'b',
#    'first_two': 'by',
#    'last': 't',
#    'last_two': 'gt',
#    'last_three': 'ggt'},
#   'sv'),
#  ({'first': 'c',
#    'first_two': 'ce',
#    'last': 't',
#    'last_two': 'st',
#    'last_three': 'ast'},
#   'sv'),
#  ({'first': 'c',
#    'first_two': 'co',
#    'last': 'n',
#    'last_two': 'rn',
#    'last_three': 'orn'},
#   'sv'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 'a',
#    'last_two': 'ta',
#    'last_three': 'lta'},
#   'sv'),
#  ({'first': 'd',
#    'first_two': 'de',
#    'last': 'e',
#    'last_two': 'de',
#    'last_three': 'ade'},
#   'sv'),
#  ({'first': 'd',
#    'first_two': 'di',
#    'last': 's',
#    'last_two': 'ls',
#    'last_three': 'lls'},
#   'sv'),
#  ({'first': 'd',
#    'first_two': 'di',
#    'last': 'e',
#    'last_two': 'se',
#    'last_three': 'rse'},
#   'sv'),
#  ({'first': 'd',
#    'first_two': 'du',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ger'},
#   'sv'),
#  ({'first': 'd',
#    'first_two': 'dy',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'der'},
#   'sv'),
#  ({'first': 'e',
#    'first_two': 'ef',
#    'last': 'd',
#    'last_two': 'nd',
#    'last_three': 'and'},
#   'sv'),
#  ({'first': 'e',
#    'first_two': 'ef',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'gen'},
#   'sv'),
#  ({'first': 'e',
#    'first_two': 'eg',
#    'last': 'p',
#    'last_two': 'ap',
#    'last_three': 'kap'},
#   'sv'),
#  ({'first': 'e',
#    'first_two': 'el',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'ten'},
#   'sv'),
#  ({'first': 'e',
#    'first_two': 'en',
#    'last': 'n',
#    'last_two': 'on',
#    'last_three': 'ion'},
#   'sv'),
#  ({'first': 'e',
#    'first_two': 'en',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'ren'},
#   'sv'),
#  ({'first': 'e',
#    'first_two': 'er',
#    'last': 'a',
#    'last_two': 'da',
#    'last_three': 'uda'},
#   'sv'),
#  ({'first': 'e',
#    'first_two': 'ex',
#    'last': 'e',
#    'last_two': 'de',
#    'last_three': 'nde'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fä',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'tet'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fä',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'gen'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fl',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'kes'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fl',
#    'last': 'a',
#    'last_two': 'ta',
#    'last_three': 'tta'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fö',
#    'last': 's',
#    'last_two': 'as',
#    'last_three': 'jas'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fö',
#    'last': 'r',
#    'last_two': 'ar',
#    'last_three': 'rar'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fö',
#    'last': 'e',
#    'last_two': 're',
#    'last_three': 'are'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fo',
#    'last': 'g',
#    'last_two': 'ng',
#    'last_three': 'ing'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fö',
#    'last': 't',
#    'last_two': 'tt',
#    'last_three': 'ått'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fö',
#    'last': 'g',
#    'last_two': 'ag',
#    'last_three': 'lag'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fr',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ver'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fr',
#    'last': 'g',
#    'last_two': 'eg',
#    'last_three': 'teg'},
#   'sv'),
#  ({'first': 'f',
#    'first_two': 'fr',
#    'last': 't',
#    'last_two': 'tt',
#    'last_three': 'itt'},
#   'sv'),
#  ({'first': 'g',
#    'first_two': 'gl',
#    'last': 'a',
#    'last_two': 'na',
#    'last_three': 'rna'},
#   'sv'),
#  ({'first': 'h',
#    'first_two': 'ha',
#    'last': 's',
#    'last_two': 'gs',
#    'last_three': 'ägs'},
#   'sv'),
#  ({'first': 'i',
#    'first_two': 'ia',
#    'last': 's',
#    'last_two': 'as',
#    'last_three': 'tas'},
#   'sv'),
#  ({'first': 'i',
#    'first_two': 'in',
#    'last': 'd',
#    'last_two': 'ld',
#    'last_three': 'öld'},
#   'sv'),
#  ({'first': 'i',
#    'first_two': 'in',
#    'last': 's',
#    'last_two': 'as',
#    'last_three': 'gas'},
#   'sv'),
#  ({'first': 'j',
#    'first_two': 'ja',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'den'},
#   'sv'),
#  ({'first': 'k',
#    'first_two': 'kv',
#    'last': 't',
#    'last_two': 'gt',
#    'last_three': 'igt'},
#   'sv'),
#  ({'first': 'k',
#    'first_two': 'kv',
#    'last': 'r',
#    'last_two': 'or',
#    'last_three': 'nor'},
#   'sv'),
#  ({'first': 'l',
#    'first_two': 'li',
#    'last': 'r',
#    'last_two': 'ur',
#    'last_three': 'tur'},
#   'sv'),
#  ({'first': 'l',
#    'first_two': 'lu',
#    'last': 'r',
#    'last_two': 'or',
#    'last_three': 'nor'},
#   'sv'),
#  ({'first': 'm',
#    'first_two': 'mä',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'ten'},
#   'sv'),
#  ({'first': 'm',
#    'first_two': 'ma',
#    'last': 't',
#    'last_two': 'kt',
#    'last_three': 'ikt'},
#   'sv'),
#  ({'first': 'm',
#    'first_two': 'mi',
#    'last': 't',
#    'last_two': 'st',
#    'last_three': 'nst'},
#   'sv'),
#  ({'first': 'n',
#    'first_two': 'ne',
#    'last': 's',
#    'last_two': 'vs',
#    'last_three': 'rvs'},
#   'sv'),
#  ({'first': 'o',
#    'first_two': 'oa',
#    'last': 'g',
#    'last_two': 'ig',
#    'last_three': 'lig'},
#   'sv'),
#  ({'first': 'o',
#    'first_two': 'oe',
#    'last': 'd',
#    'last_two': 'rd',
#    'last_three': 'örd'},
#   'sv'),
#  ({'first': 'ö',
#    'first_two': 'ök',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'des'},
#   'sv'),
#  ({'first': 'ö',
#    'first_two': 'ök',
#    'last': 's',
#    'last_two': 'ts',
#    'last_three': 'ats'},
#   'sv'),
#  ({'first': 'o',
#    'first_two': 'or',
#    'last': 't',
#    'last_two': 'at',
#    'last_three': 'nat'},
#   'sv'),
#  ({'first': 'ö',
#    'first_two': 'öv',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'sen'},
#   'sv'),
#  ({'first': 'ö',
#    'first_two': 'öv',
#    'last': 's',
#    'last_two': 'ds',
#    'last_three': 'ids'},
#   'sv'),
#  ({'first': 'ö',
#    'first_two': 'öv',
#    'last': 't',
#    'last_two': 'st',
#    'last_three': 'rst'},
#   'sv'),
#  ({'first': 'p',
#    'first_two': 'pe',
#    'last': 't',
#    'last_two': 'nt',
#    'last_three': 'ent'},
#   'sv'),
#  ({'first': 'p',
#    'first_two': 'pl',
#    'last': 'r',
#    'last_two': 'ar',
#    'last_three': 'dar'},
#   'sv'),
#  ({'first': 'p',
#    'first_two': 'po',
#    'last': 's',
#    'last_two': 'ns',
#    'last_three': 'ens'},
#   'sv'),
#  ({'first': 'p',
#    'first_two': 'po',
#    'last': 's',
#    'last_two': 'is',
#    'last_three': 'tis'},
#   'sv'),
#  ({'first': 'p',
#    'first_two': 'pr',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'des'},
#   'sv'),
#  ({'first': 'r',
#    'first_two': 'ra',
#    'last': 't',
#    'last_two': 'at',
#    'last_three': 'rat'},
#   'sv'),
#  ({'first': 'r',
#    'first_two': 'ru',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'nen'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'sä',
#    'last': 'a',
#    'last_two': 'ta',
#    'last_three': 'sta'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'sä',
#    'last': 'a',
#    'last_two': 'sa',
#    'last_three': 'ösa'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'sj',
#    'last': 'a',
#    'last_two': 'ga',
#    'last_three': 'iga'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'sj',
#    'last': 'e',
#    'last_two': 'de',
#    'last_three': 'nde'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'sk',
#    'last': 'e',
#    'last_two': 'se',
#    'last_three': 'lse'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'sl',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ger'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'sp',
#    'last': 'n',
#    'last_two': 'an',
#    'last_three': 'gan'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'st',
#    'last': 'e',
#    'last_two': 'ge',
#    'last_three': 'ige'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'st',
#    'last': 't',
#    'last_two': 'at',
#    'last_three': 'vat'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'st',
#    'last': 's',
#    'last_two': 'ts',
#    'last_three': 'ats'},
#   'sv'),
#  ({'first': 's',
#    'first_two': 'sy',
#    'last': 'i',
#    'last_two': 'ti',
#    'last_three': 'ati'},
#   'sv'),
#  ({'first': 't',
#    'first_two': 'tä',
#    'last': 'a',
#    'last_two': 'na',
#    'last_three': 'rna'},
#   'sv'),
#  ({'first': 't',
#    'first_two': 'ti',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'les'},
#   'sv'),
#  ({'first': 't',
#    'first_two': 'ti',
#    'last': 'e',
#    'last_two': 're',
#    'last_three': 'are'},
#   'sv'),
#  ({'first': 't',
#    'first_two': 'tr',
#    'last': 'n',
#    'last_two': 'ln',
#    'last_three': 'eln'},
#   'sv'),
#  ({'first': 'u',
#    'first_two': 'up',
#    'last': 't',
#    'last_two': 'rt',
#    'last_three': 'ört'},
#   'sv'),
#  ({'first': 'u',
#    'first_two': 'up',
#    'last': 'n',
#    'last_two': 'en',
#    'last_three': 'gen'},
#   'sv'),
#  ({'first': 'u',
#    'first_two': 'ur',
#    'last': 'a',
#    'last_two': 'la',
#    'last_three': 'mla'},
#   'sv'),
#  ({'first': 'u',
#    'first_two': 'ut',
#    'last': 's',
#    'last_two': 'es',
#    'last_three': 'kes'},
#   'sv'),
#  ({'first': 'v',
#    'first_two': 'vä',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'ger'},
#   'sv'),
#  ({'first': 'v',
#    'first_two': 'va',
#    'last': 't',
#    'last_two': 'et',
#    'last_three': 'set'},
#   'sv'),
#  ({'first': 'v',
#    'first_two': 'vä',
#    'last': 'r',
#    'last_two': 'er',
#    'last_three': 'der'},
#   'sv')]

# %% [markdown]
# <p>The perceptron assigns a weight to each combination of a feature and a tag.</p>

# %%
from collections import Counter
weights = Counter()

# %% [markdown]
# <p>To obtain the score of a given category for a set of features, we simply sum the corresponding weights:</p>

# %%
def score(features, category): return sum(weights[feature, category] for feature in features.items())

# %% [markdown]
# <h2 id="Training-the-perceptron">Training the perceptron<a class="anchor-link" href="#Training-the-perceptron">¶</a></h2>

# %% [markdown]
# <p>Assign weights to each word automatically based on training data.</p>

# %%
# These are the possible tags in our example
tags = ('en', 'de', 'fi', 'fr', 'sv')

def update(word, correct_tag):
    # First we compute what the algorithm currently says would be the best tag for this word
    predicted_tag = max(tags, key=lambda tag: score(get_features(word), tag))
    if correct_tag == predicted_tag:
        # If the predicted tag is correct, do nothing
        print('This example is already predicted correctly')
        pass
    else:
        print('This example was incorrectly predicted to be %s' % predicted_tag)
        # Otherwise, we need to do two things:
        # First, add 1 to the weight of every (feature,correct_tag) pair
        #   this will make each feature more strongly associated with the correct tag
        for feature in get_features(word).items():
            print('Increasing association of %-20s with %s' % (feature, correct_tag))
            weights[feature,correct_tag] += 1
        # Second, remove 1 from the weight of every (feature,predicted_tag) pair
        #   this will make each feature less strongly associated with the incorrect tag
        for feature in get_features(word).items():
            print('Reducing association of   %-20s with %s' % (feature, predicted_tag))
            weights[feature,predicted_tag] -= 1

# %% [markdown]
# <p>And that's it! Now let's reset the weights to zero, and see what happens when we pass through the words in our little data set.</p>
# <p>Run 10 epochs in total, after each epoch shuffle the training set randomly to get better results.</p>

# %%
import random

weights.clear()

for i in range(1, 11):
    print('\n---- Running epoch #{} ----\n'.format(i))
    random.shuffle(train_set)
    for word, tag in train_set:
        print('  -- Training example: %s %s --' % (word, tag))
        update(word, tag)
        print()
# Out:
# ---- Running epoch #1 ----
#
#   -- Training example: slept en --
# This example is already predicted correctly
#
#   -- Training example: vajoan fi --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'v')       with fi
# Increasing association of ('first_two', 'va')  with fi
# Increasing association of ('last', 'n')        with fi
# Increasing association of ('last_two', 'an')   with fi
# Increasing association of ('last_three', 'oan') with fi
# Reducing association of   ('first', 'v')       with en
# Reducing association of   ('first_two', 'va')  with en
# Reducing association of   ('last', 'n')        with en
# Reducing association of   ('last_two', 'an')   with en
# Reducing association of   ('last_three', 'oan') with en
#
#   -- Training example: optischen de --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'o')       with de
# Increasing association of ('first_two', 'op')  with de
# Increasing association of ('last', 'n')        with de
# Increasing association of ('last_two', 'en')   with de
# Increasing association of ('last_three', 'hen') with de
# Reducing association of   ('first', 'o')       with fi
# Reducing association of   ('first_two', 'op')  with fi
# Reducing association of   ('last', 'n')        with fi
# Reducing association of   ('last_two', 'en')   with fi
# Reducing association of   ('last_three', 'hen') with fi
#
#   -- Training example: mitalitilin fi --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'm')       with fi
# Increasing association of ('first_two', 'mi')  with fi
# Increasing association of ('last', 'n')        with fi
# Increasing association of ('last_two', 'in')   with fi
# Increasing association of ('last_three', 'lin') with fi
# Reducing association of   ('first', 'm')       with de
# Reducing association of   ('first_two', 'mi')  with de
# Reducing association of   ('last', 'n')        with de
# Reducing association of   ('last_two', 'in')   with de
# Reducing association of   ('last_three', 'lin') with de
#
#   -- Training example: serbijoukkojen fi --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 's')       with fi
# Increasing association of ('first_two', 'se')  with fi
# Increasing association of ('last', 'n')        with fi
# Increasing association of ('last_two', 'en')   with fi
# Increasing association of ('last_three', 'jen') with fi
# Reducing association of   ('first', 's')       with de
# Reducing association of   ('first_two', 'se')  with de
# Reducing association of   ('last', 'n')        with de
# Reducing association of   ('last_two', 'en')   with de
# Reducing association of   ('last_three', 'jen') with de
#
#   -- Training example: gujarat fr --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'g')       with fr
# Increasing association of ('first_two', 'gu')  with fr
# Increasing association of ('last', 't')        with fr
# Increasing association of ('last_two', 'at')   with fr
# Increasing association of ('last_three', 'rat') with fr
# Reducing association of   ('first', 'g')       with en
# Reducing association of   ('first_two', 'gu')  with en
# Reducing association of   ('last', 't')        with en
# Reducing association of   ('last_two', 'at')   with en
# Reducing association of   ('last_three', 'rat') with en
#
#   -- Training example: Thyra de --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'T')       with de
# Increasing association of ('first_two', 'Th')  with de
# Increasing association of ('last', 'a')        with de
# Increasing association of ('last_two', 'ra')   with de
# Increasing association of ('last_three', 'yra') with de
# Reducing association of   ('first', 'T')       with en
# Reducing association of   ('first_two', 'Th')  with en
# Reducing association of   ('last', 'a')        with en
# Reducing association of   ('last_two', 'ra')   with en
# Reducing association of   ('last_three', 'yra') with en
#
#   -- Training example: sections fr --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 's')       with fr
# Increasing association of ('first_two', 'se')  with fr
# Increasing association of ('last', 's')        with fr
# Increasing association of ('last_two', 'ns')   with fr
# Increasing association of ('last_three', 'ons') with fr
# Reducing association of   ('first', 's')       with fi
# Reducing association of   ('first_two', 'se')  with fi
# Reducing association of   ('last', 's')        with fi
# Reducing association of   ('last_two', 'ns')   with fi
# Reducing association of   ('last_three', 'ons') with fi
#
#   -- Training example: specialorgan sv --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 's')       with sv
# Increasing association of ('first_two', 'sp')  with sv
# Increasing association of ('last', 'n')        with sv
# Increasing association of ('last_two', 'an')   with sv
# Increasing association of ('last_three', 'gan') with sv
# Reducing association of   ('first', 's')       with fi
# Reducing association of   ('first_two', 'sp')  with fi
# Reducing association of   ('last', 'n')        with fi
# Reducing association of   ('last_two', 'an')   with fi
# Reducing association of   ('last_three', 'gan') with fi
#
#   -- Training example: bilen sv --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'b')       with sv
# Increasing association of ('first_two', 'bi')  with sv
# Increasing association of ('last', 'n')        with sv
# Increasing association of ('last_two', 'en')   with sv
# Increasing association of ('last_three', 'len') with sv
# Reducing association of   ('first', 'b')       with fi
# Reducing association of   ('first_two', 'bi')  with fi
# Reducing association of   ('last', 'n')        with fi
# Reducing association of   ('last_two', 'en')   with fi
# Reducing association of   ('last_three', 'len') with fi
#
#   -- Training example: signant fr --
# This example is already predicted correctly
#
#   -- Training example: valbåset sv --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'v')       with sv
# Increasing association of ('first_two', 'va')  with sv
# Increasing association of ('last', 't')        with sv
# Increasing association of ('last_two', 'et')   with sv
# Increasing association of ('last_three', 'set') with sv
# Reducing association of   ('first', 'v')       with fi
# Reducing association of   ('first_two', 'va')  with fi
# Reducing association of   ('last', 't')        with fi
# Reducing association of   ('last_two', 'et')   with fi
# Reducing association of   ('last_three', 'set') with fi
#
#   -- Training example: angenehmen de --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'a')       with de
# Increasing association of ('first_two', 'an')  with de
# Increasing association of ('last', 'n')        with de
# Increasing association of ('last_two', 'en')   with de
# Increasing association of ('last_three', 'men') with de
# Reducing association of   ('first', 'a')       with sv
# Reducing association of   ('first_two', 'an')  with sv
# Reducing association of   ('last', 'n')        with sv
# Reducing association of   ('last_two', 'en')   with sv
# Reducing association of   ('last_three', 'men') with sv
#
#   -- Training example: durchlöchert de --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'd')       with de
# Increasing association of ('first_two', 'du')  with de
# Increasing association of ('last', 't')        with de
# Increasing association of ('last_two', 'rt')   with de
# Increasing association of ('last_three', 'ert') with de
# Reducing association of   ('first', 'd')       with fr
# Reducing association of   ('first_two', 'du')  with fr
# Reducing association of   ('last', 't')        with fr
# Reducing association of   ('last_two', 'rt')   with fr
# Reducing association of   ('last_three', 'ert') with fr
#
#   -- Training example: tamils en --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 't')       with en
# Increasing association of ('first_two', 'ta')  with en
# Increasing association of ('last', 's')        with en
# Increasing association of ('last_two', 'ls')   with en
# Increasing association of ('last_three', 'ils') with en
# Reducing association of   ('first', 't')       with fr
# Reducing association of   ('first_two', 'ta')  with fr
# Reducing association of   ('last', 's')        with fr
# Reducing association of   ('last_two', 'ls')   with fr
# Reducing association of   ('last_three', 'ils') with fr
#
#   -- Training example: schnellstes de --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 's')       with de
# Increasing association of ('first_two', 'sc')  with de
# Increasing association of ('last', 's')        with de
# Increasing association of ('last_two', 'es')   with de
# Increasing association of ('last_three', 'tes') with de
# Reducing association of   ('first', 's')       with en
# Reducing association of   ('first_two', 'sc')  with en
# Reducing association of   ('last', 's')        with en
# Reducing association of   ('last_two', 'es')   with en
# Reducing association of   ('last_three', 'tes') with en
#
#   -- Training example: existantes fr --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'e')       with fr
# Increasing association of ('first_two', 'ex')  with fr
# Increasing association of ('last', 's')        with fr
# Increasing association of ('last_two', 'es')   with fr
# Increasing association of ('last_three', 'tes') with fr
# Reducing association of   ('first', 'e')       with de
# Reducing association of   ('first_two', 'ex')  with de
# Reducing association of   ('last', 's')        with de
# Reducing association of   ('last_two', 'es')   with de
# Reducing association of   ('last_three', 'tes') with de
#
#   -- Training example: avhållsamhet sv --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'a')       with sv
# Increasing association of ('first_two', 'av')  with sv
# Increasing association of ('last', 't')        with sv
# Increasing association of ('last_two', 'et')   with sv
# Increasing association of ('last_three', 'het') with sv
# Reducing association of   ('first', 'a')       with de
# Reducing association of   ('first_two', 'av')  with de
# Reducing association of   ('last', 't')        with de
# Reducing association of   ('last_two', 'et')   with de
# Reducing association of   ('last_three', 'het') with de
#
#   -- Training example: immigrants en --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'i')       with en
# Increasing association of ('first_two', 'im')  with en
# Increasing association of ('last', 's')        with en
# Increasing association of ('last_two', 'ts')   with en
# Increasing association of ('last_three', 'nts') with en
# Reducing association of   ('first', 'i')       with fr
# Reducing association of   ('first_two', 'im')  with fr
# Reducing association of   ('last', 's')        with fr
# Reducing association of   ('last_two', 'ts')   with fr
# Reducing association of   ('last_three', 'nts') with fr
#
#   -- Training example: contini fr --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'c')       with fr
# Increasing association of ('first_two', 'co')  with fr
# Increasing association of ('last', 'i')        with fr
# Increasing association of ('last_two', 'ni')   with fr
# Increasing association of ('last_three', 'ini') with fr
# Reducing association of   ('first', 'c')       with en
# Reducing association of   ('first_two', 'co')  with en
# Reducing association of   ('last', 'i')        with en
# Reducing association of   ('last_two', 'ni')   with en
# Reducing association of   ('last_three', 'ini') with en
#
#   -- Training example: nécessitent fr --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'n')       with fr
# Increasing association of ('first_two', 'né')  with fr
# Increasing association of ('last', 't')        with fr
# Increasing association of ('last_two', 'nt')   with fr
# Increasing association of ('last_three', 'ent') with fr
# Reducing association of   ('first', 'n')       with sv
# Reducing association of   ('first_two', 'né')  with sv
# Reducing association of   ('last', 't')        with sv
# Reducing association of   ('last_two', 'nt')   with sv
# Reducing association of   ('last_three', 'ent') with sv
#
#   -- Training example: précisait fr --
# This example is already predicted correctly
#
#   -- Training example: jatkoa fi --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'j')       with fi
# Increasing association of ('first_two', 'ja')  with fi
# Increasing association of ('last', 'a')        with fi
# Increasing association of ('last_two', 'oa')   with fi
# Increasing association of ('last_three', 'koa') with fi
# Reducing association of   ('first', 'j')       with de
# Reducing association of   ('first_two', 'ja')  with de
# Reducing association of   ('last', 'a')        with de
# Reducing association of   ('last_two', 'oa')   with de
# Reducing association of   ('last_three', 'koa') with de
#
#   -- Training example: avoir fr --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'a')       with fr
# Increasing association of ('first_two', 'av')  with fr
# Increasing association of ('last', 'r')        with fr
# Increasing association of ('last_two', 'ir')   with fr
# Increasing association of ('last_three', 'oir') with fr
# Reducing association of   ('first', 'a')       with sv
# Reducing association of   ('first_two', 'av')  with sv
# Reducing association of   ('last', 'r')        with sv
# Reducing association of   ('last_two', 'ir')   with sv
# Reducing association of   ('last_three', 'oir') with sv
#
#   -- Training example: based en --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'b')       with en
# Increasing association of ('first_two', 'ba')  with en
# Increasing association of ('last', 'd')        with en
# Increasing association of ('last_two', 'ed')   with en
# Increasing association of ('last_three', 'sed') with en
# Reducing association of   ('first', 'b')       with sv
# Reducing association of   ('first_two', 'ba')  with sv
# Reducing association of   ('last', 'd')        with sv
# Reducing association of   ('last_two', 'ed')   with sv
# Reducing association of   ('last_three', 'sed') with sv
#
#   -- Training example: nazionale fr --
# This example is already predicted correctly
#
#   -- Training example: consécutif fr --
# This example is already predicted correctly
#
#   -- Training example: counterparties en --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'c')       with en
# Increasing association of ('first_two', 'co')  with en
# Increasing association of ('last', 's')        with en
# Increasing association of ('last_two', 'es')   with en
# Increasing association of ('last_three', 'ies') with en
# Reducing association of   ('first', 'c')       with fr
# Reducing association of   ('first_two', 'co')  with fr
# Reducing association of   ('last', 's')        with fr
# Reducing association of   ('last_two', 'es')   with fr
# Reducing association of   ('last_three', 'ies') with fr
#
#   -- Training example: rakapparat sv --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'r')       with sv
# Increasing association of ('first_two', 'ra')  with sv
# Increasing association of ('last', 't')        with sv
# Increasing association of ('last_two', 'at')   with sv
# Increasing association of ('last_three', 'rat') with sv
# Reducing association of   ('first', 'r')       with fr
# Reducing association of   ('first_two', 'ra')  with fr
# Reducing association of   ('last', 't')        with fr
# Reducing association of   ('last_two', 'at')   with fr
# Reducing association of   ('last_three', 'rat') with fr
#
#   -- Training example: stores en --
# This example is already predicted correctly
#
#   -- Training example: berör sv --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'b')       with sv
# Increasing association of ('first_two', 'be')  with sv
# Increasing association of ('last', 'r')        with sv
# Increasing association of ('last_two', 'ör')   with sv
# Increasing association of ('last_three', 'rör') with sv
# Reducing association of   ('first', 'b')       with en
# Reducing association of   ('first_two', 'be')  with en
# Reducing association of   ('last', 'r')        with en
# Reducing association of   ('last_two', 'ör')   with en
# Reducing association of   ('last_three', 'rör') with en
#
#   -- Training example: Studiums de --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'S')       with de
# Increasing association of ('first_two', 'St')  with de
# Increasing association of ('last', 's')        with de
# Increasing association of ('last_two', 'ms')   with de
# Increasing association of ('last_three', 'ums') with de
# Reducing association of   ('first', 'S')       with en
# Reducing association of   ('first_two', 'St')  with en
# Reducing association of   ('last', 's')        with en
# Reducing association of   ('last_two', 'ms')   with en
# Reducing association of   ('last_three', 'ums') with en
#
#   -- Training example: directed en --
# This example is already predicted correctly
#
#   -- Training example: expulsion en --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'e')       with en
# Increasing association of ('first_two', 'ex')  with en
# Increasing association of ('last', 'n')        with en
# Increasing association of ('last_two', 'on')   with en
# Increasing association of ('last_three', 'ion') with en
# Reducing association of   ('first', 'e')       with fr
# Reducing association of   ('first_two', 'ex')  with fr
# Reducing association of   ('last', 'n')        with fr
# Reducing association of   ('last_two', 'on')   with fr
# Reducing association of   ('last_three', 'ion') with fr
#
#   -- Training example: säsongarbetslösa sv --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 's')       with sv
# Increasing association of ('first_two', 'sä')  with sv
# Increasing association of ('last', 'a')        with sv
# Increasing association of ('last_two', 'sa')   with sv
# Increasing association of ('last_three', 'ösa') with sv
# Reducing association of   ('first', 's')       with fr
# Reducing association of   ('first_two', 'sä')  with fr
# Reducing association of   ('last', 'a')        with fr
# Reducing association of   ('last_two', 'sa')   with fr
# Reducing association of   ('last_three', 'ösa') with fr
#
#   -- Training example: omaa fi --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'o')       with fi
# Increasing association of ('first_two', 'om')  with fi
# Increasing association of ('last', 'a')        with fi
# Increasing association of ('last_two', 'aa')   with fi
# Increasing association of ('last_three', 'maa') with fi
# Reducing association of   ('first', 'o')       with de
# Reducing association of   ('first_two', 'om')  with de
# Reducing association of   ('last', 'a')        with de
# Reducing association of   ('last_two', 'aa')   with de
# Reducing association of   ('last_three', 'maa') with de
#
#   -- Training example: orientaux fr --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'o')       with fr
# Increasing association of ('first_two', 'or')  with fr
# Increasing association of ('last', 'x')        with fr
# Increasing association of ('last_two', 'ux')   with fr
# Increasing association of ('last_three', 'aux') with fr
# Reducing association of   ('first', 'o')       with en
# Reducing association of   ('first_two', 'or')  with en
# Reducing association of   ('last', 'x')        with en
# Reducing association of   ('last_two', 'ux')   with en
# Reducing association of   ('last_three', 'aux') with en
#
#   -- Training example: bankasi fr --
# This example is already predicted correctly
#
#   -- Training example: revealing en --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'r')       with en
# Increasing association of ('first_two', 're')  with en
# Increasing association of ('last', 'g')        with en
# Increasing association of ('last_two', 'ng')   with en
# Increasing association of ('last_three', 'ing') with en
# Reducing association of   ('first', 'r')       with sv
# Reducing association of   ('first_two', 're')  with sv
# Reducing association of   ('last', 'g')        with sv
# Reducing association of   ('last_two', 'ng')   with sv
# Reducing association of   ('last_three', 'ing') with sv
#
#   -- Training example: kvinnligt sv --
# This example is already predicted correctly
#
#   -- Training example: gars fr --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'g')       with fr
# Increasing association of ('first_two', 'ga')  with fr
# Increasing association of ('last', 's')        with fr
# Increasing association of ('last_two', 'rs')   with fr
# Increasing association of ('last_three', 'ars') with fr
# Reducing association of   ('first', 'g')       with de
# Reducing association of   ('first_two', 'ga')  with de
# Reducing association of   ('last', 's')        with de
# Reducing association of   ('last_two', 'rs')   with de
# Reducing association of   ('last_three', 'ars') with de
#
#   -- Training example: potatis sv --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'p')       with sv
# Increasing association of ('first_two', 'po')  with sv
# Increasing association of ('last', 's')        with sv
# Increasing association of ('last_two', 'is')   with sv
# Increasing association of ('last_three', 'tis') with sv
# Reducing association of   ('first', 'p')       with en
# Reducing association of   ('first_two', 'po')  with en
# Reducing association of   ('last', 's')        with en
# Reducing association of   ('last_two', 'is')   with en
# Reducing association of   ('last_three', 'tis') with en
#
#   -- Training example: collégiale fr --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'c')       with fr
# Increasing association of ('first_two', 'co')  with fr
# Increasing association of ('last', 'e')        with fr
# Increasing association of ('last_two', 'le')   with fr
# Increasing association of ('last_three', 'ale') with fr
# Reducing association of   ('first', 'c')       with en
# Reducing association of   ('first_two', 'co')  with en
# Reducing association of   ('last', 'e')        with en
# Reducing association of   ('last_two', 'le')   with en
# Reducing association of   ('last_three', 'ale') with en
#
#   -- Training example: Parteifreunden de --
# This example is already predicted correctly
#
#   -- Training example: tosi fi --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 't')       with fi
# Increasing association of ('first_two', 'to')  with fi
# Increasing association of ('last', 'i')        with fi
# Increasing association of ('last_two', 'si')   with fi
# Increasing association of ('last_three', 'osi') with fi
# Reducing association of   ('first', 't')       with en
# Reducing association of   ('first_two', 'to')  with en
# Reducing association of   ('last', 'i')        with en
# Reducing association of   ('last_two', 'si')   with en
# Reducing association of   ('last_three', 'osi') with en
#
#   -- Training example: Experience de --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'E')       with de
# Increasing association of ('first_two', 'Ex')  with de
# Increasing association of ('last', 'e')        with de
# Increasing association of ('last_two', 'ce')   with de
# Increasing association of ('last_three', 'nce') with de
# Reducing association of   ('first', 'E')       with fr
# Reducing association of   ('first_two', 'Ex')  with fr
# Reducing association of   ('last', 'e')        with fr
# Reducing association of   ('last_two', 'ce')   with fr
# Reducing association of   ('last_three', 'nce') with fr
#
#   -- Training example: yhteiset fi --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'y')       with fi
# Increasing association of ('first_two', 'yh')  with fi
# Increasing association of ('last', 't')        with fi
# Increasing association of ('last_two', 'et')   with fi
# Increasing association of ('last_three', 'set') with fi
# Reducing association of   ('first', 'y')       with sv
# Reducing association of   ('first_two', 'yh')  with sv
# Reducing association of   ('last', 't')        with sv
# Reducing association of   ('last_two', 'et')   with sv
# Reducing association of   ('last_three', 'set') with sv
#
#   -- Training example: yksistään fi --
# This example is already predicted correctly
#
#   -- Training example: urgamla sv --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'u')       with sv
# Increasing association of ('first_two', 'ur')  with sv
# Increasing association of ('last', 'a')        with sv
# Increasing association of ('last_two', 'la')   with sv
# Increasing association of ('last_three', 'mla') with sv
# Reducing association of   ('first', 'u')       with fi
# Reducing association of   ('first_two', 'ur')  with fi
# Reducing association of   ('last', 'a')        with fi
# Reducing association of   ('last_two', 'la')   with fi
# Reducing association of   ('last_three', 'mla') with fi
#
#   -- Training example: maken fi --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'm')       with fi
# Increasing association of ('first_two', 'ma')  with fi
# Increasing association of ('last', 'n')        with fi
# Increasing association of ('last_two', 'en')   with fi
# Increasing association of ('last_three', 'ken') with fi
# Reducing association of   ('first', 'm')       with sv
# Reducing association of   ('first_two', 'ma')  with sv
# Reducing association of   ('last', 'n')        with sv
# Reducing association of   ('last_two', 'en')   with sv
# Reducing association of   ('last_three', 'ken') with sv
#
#   -- Training example: inbrottsstöld sv --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'i')       with sv
# Increasing association of ('first_two', 'in')  with sv
# Increasing association of ('last', 'd')        with sv
# Increasing association of ('last_two', 'ld')   with sv
# Increasing association of ('last_three', 'öld') with sv
# Reducing association of   ('first', 'i')       with en
# Reducing association of   ('first_two', 'in')  with en
# Reducing association of   ('last', 'd')        with en
# Reducing association of   ('last_two', 'ld')   with en
# Reducing association of   ('last_three', 'öld') with en
#
#   -- Training example: simultanée fr --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 's')       with fr
# Increasing association of ('first_two', 'si')  with fr
# Increasing association of ('last', 'e')        with fr
# Increasing association of ('last_two', 'ée')   with fr
# Increasing association of ('last_three', 'née') with fr
# Reducing association of   ('first', 's')       with sv
# Reducing association of   ('first_two', 'si')  with sv
# Reducing association of   ('last', 'e')        with sv
# Reducing association of   ('last_two', 'ée')   with sv
# Reducing association of   ('last_three', 'née') with sv
#
#   -- Training example: hunksit fi --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'h')       with fi
# Increasing association of ('first_two', 'hu')  with fi
# Increasing association of ('last', 't')        with fi
# Increasing association of ('last_two', 'it')   with fi
# Increasing association of ('last_three', 'sit') with fi
# Reducing association of   ('first', 'h')       with sv
# Reducing association of   ('first_two', 'hu')  with sv
# Reducing association of   ('last', 't')        with sv
# Reducing association of   ('last_two', 'it')   with sv
# Reducing association of   ('last_three', 'sit') with sv
#
#   -- Training example: veräußert de --
# This example is already predicted correctly
#
#   -- Training example: Salome de --
# This example is already predicted correctly
#
#   -- Training example: huonekasvi fi --
# This example is already predicted correctly
#
#   -- Training example: nytkään fi --
# This example is already predicted correctly
#
#   -- Training example: elinympäristön fi --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'e')       with fi
# Increasing association of ('first_two', 'el')  with fi
# Increasing association of ('last', 'n')        with fi
# Increasing association of ('last_two', 'ön')   with fi
# Increasing association of ('last_three', 'tön') with fi
# Reducing association of   ('first', 'e')       with en
# Reducing association of   ('first_two', 'el')  with en
# Reducing association of   ('last', 'n')        with en
# Reducing association of   ('last_two', 'ön')   with en
# Reducing association of   ('last_three', 'tön') with en
#
#   -- Training example: encyclopedic en --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'e')       with en
# Increasing association of ('first_two', 'en')  with en
# Increasing association of ('last', 'c')        with en
# Increasing association of ('last_two', 'ic')   with en
# Increasing association of ('last_three', 'dic') with en
# Reducing association of   ('first', 'e')       with fi
# Reducing association of   ('first_two', 'en')  with fi
# Reducing association of   ('last', 'c')        with fi
# Reducing association of   ('last_two', 'ic')   with fi
# Reducing association of   ('last_three', 'dic') with fi
#
#   -- Training example: avtal sv --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'a')       with sv
# Increasing association of ('first_two', 'av')  with sv
# Increasing association of ('last', 'l')        with sv
# Increasing association of ('last_two', 'al')   with sv
# Increasing association of ('last_three', 'tal') with sv
# Reducing association of   ('first', 'a')       with fr
# Reducing association of   ('first_two', 'av')  with fr
# Reducing association of   ('last', 'l')        with fr
# Reducing association of   ('last_two', 'al')   with fr
# Reducing association of   ('last_three', 'tal') with fr
#
#   -- Training example: litteratur sv --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'l')       with sv
# Increasing association of ('first_two', 'li')  with sv
# Increasing association of ('last', 'r')        with sv
# Increasing association of ('last_two', 'ur')   with sv
# Increasing association of ('last_three', 'tur') with sv
# Reducing association of   ('first', 'l')       with fr
# Reducing association of   ('first_two', 'li')  with fr
# Reducing association of   ('last', 'r')        with fr
# Reducing association of   ('last_two', 'ur')   with fr
# Reducing association of   ('last_three', 'tur') with fr
#
#   -- Training example: Winterregen de --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'W')       with de
# Increasing association of ('first_two', 'Wi')  with de
# Increasing association of ('last', 'n')        with de
# Increasing association of ('last_two', 'en')   with de
# Increasing association of ('last_three', 'gen') with de
# Reducing association of   ('first', 'W')       with fi
# Reducing association of   ('first_two', 'Wi')  with fi
# Reducing association of   ('last', 'n')        with fi
# Reducing association of   ('last_two', 'en')   with fi
# Reducing association of   ('last_three', 'gen') with fi
#
#   -- Training example: vorbekanntem de --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'v')       with de
# Increasing association of ('first_two', 'vo')  with de
# Increasing association of ('last', 'm')        with de
# Increasing association of ('last_two', 'em')   with de
# Increasing association of ('last_three', 'tem') with de
# Reducing association of   ('first', 'v')       with sv
# Reducing association of   ('first_two', 'vo')  with sv
# Reducing association of   ('last', 'm')        with sv
# Reducing association of   ('last_two', 'em')   with sv
# Reducing association of   ('last_three', 'tem') with sv
#
#   -- Training example: Buchbeiträgen de --
# This example is already predicted correctly
#
#   -- Training example: katkennut fi --
# This example is already predicted correctly
#
#   -- Training example: changed en --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'c')       with en
# Increasing association of ('first_two', 'ch')  with en
# Increasing association of ('last', 'd')        with en
# Increasing association of ('last_two', 'ed')   with en
# Increasing association of ('last_three', 'ged') with en
# Reducing association of   ('first', 'c')       with fr
# Reducing association of   ('first_two', 'ch')  with fr
# Reducing association of   ('last', 'd')        with fr
# Reducing association of   ('last_two', 'ed')   with fr
# Reducing association of   ('last_three', 'ged') with fr
#
#   -- Training example: edellisistä fi --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'e')       with fi
# Increasing association of ('first_two', 'ed')  with fi
# Increasing association of ('last', 'ä')        with fi
# Increasing association of ('last_two', 'tä')   with fi
# Increasing association of ('last_three', 'stä') with fi
# Reducing association of   ('first', 'e')       with en
# Reducing association of   ('first_two', 'ed')  with en
# Reducing association of   ('last', 'ä')        with en
# Reducing association of   ('last_two', 'tä')   with en
# Reducing association of   ('last_three', 'stä') with en
#
#   -- Training example: elkraften sv --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'e')       with sv
# Increasing association of ('first_two', 'el')  with sv
# Increasing association of ('last', 'n')        with sv
# Increasing association of ('last_two', 'en')   with sv
# Increasing association of ('last_three', 'ten') with sv
# Reducing association of   ('first', 'e')       with de
# Reducing association of   ('first_two', 'el')  with de
# Reducing association of   ('last', 'n')        with de
# Reducing association of   ('last_two', 'en')   with de
# Reducing association of   ('last_three', 'ten') with de
#
#   -- Training example: succeed en --
# This example is already predicted correctly
#
#   -- Training example: tillverkare sv --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 't')       with sv
# Increasing association of ('first_two', 'ti')  with sv
# Increasing association of ('last', 'e')        with sv
# Increasing association of ('last_two', 're')   with sv
# Increasing association of ('last_three', 'are') with sv
# Reducing association of   ('first', 't')       with de
# Reducing association of   ('first_two', 'ti')  with de
# Reducing association of   ('last', 'e')        with de
# Reducing association of   ('last_two', 're')   with de
# Reducing association of   ('last_three', 'are') with de
#
#   -- Training example: Millionenhöhe de --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'M')       with de
# Increasing association of ('first_two', 'Mi')  with de
# Increasing association of ('last', 'e')        with de
# Increasing association of ('last_two', 'he')   with de
# Increasing association of ('last_three', 'öhe') with de
# Reducing association of   ('first', 'M')       with fr
# Reducing association of   ('first_two', 'Mi')  with fr
# Reducing association of   ('last', 'e')        with fr
# Reducing association of   ('last_two', 'he')   with fr
# Reducing association of   ('last_three', 'öhe') with fr
#
#   -- Training example: überformt de --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'ü')       with de
# Increasing association of ('first_two', 'üb')  with de
# Increasing association of ('last', 't')        with de
# Increasing association of ('last_two', 'mt')   with de
# Increasing association of ('last_three', 'rmt') with de
# Reducing association of   ('first', 'ü')       with fi
# Reducing association of   ('first_two', 'üb')  with fi
# Reducing association of   ('last', 't')        with fi
# Reducing association of   ('last_two', 'mt')   with fi
# Reducing association of   ('last_three', 'rmt') with fi
#
#   -- Training example: nurmikollani fi --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'n')       with fi
# Increasing association of ('first_two', 'nu')  with fi
# Increasing association of ('last', 'i')        with fi
# Increasing association of ('last_two', 'ni')   with fi
# Increasing association of ('last_three', 'ani') with fi
# Reducing association of   ('first', 'n')       with fr
# Reducing association of   ('first_two', 'nu')  with fr
# Reducing association of   ('last', 'i')        with fr
# Reducing association of   ('last_two', 'ni')   with fr
# Reducing association of   ('last_three', 'ani') with fr
#
#   -- Training example: dessert en --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'd')       with en
# Increasing association of ('first_two', 'de')  with en
# Increasing association of ('last', 't')        with en
# Increasing association of ('last_two', 'rt')   with en
# Increasing association of ('last_three', 'ert') with en
# Reducing association of   ('first', 'd')       with de
# Reducing association of   ('first_two', 'de')  with de
# Reducing association of   ('last', 't')        with de
# Reducing association of   ('last_two', 'rt')   with de
# Reducing association of   ('last_three', 'ert') with de
#
#   -- Training example: oerhörd sv --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'o')       with sv
# Increasing association of ('first_two', 'oe')  with sv
# Increasing association of ('last', 'd')        with sv
# Increasing association of ('last_two', 'rd')   with sv
# Increasing association of ('last_three', 'örd') with sv
# Reducing association of   ('first', 'o')       with en
# Reducing association of   ('first_two', 'oe')  with en
# Reducing association of   ('last', 'd')        with en
# Reducing association of   ('last_two', 'rd')   with en
# Reducing association of   ('last_three', 'örd') with en
#
#   -- Training example: framsteg sv --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'f')       with sv
# Increasing association of ('first_two', 'fr')  with sv
# Increasing association of ('last', 'g')        with sv
# Increasing association of ('last_two', 'eg')   with sv
# Increasing association of ('last_three', 'teg') with sv
# Reducing association of   ('first', 'f')       with en
# Reducing association of   ('first_two', 'fr')  with en
# Reducing association of   ('last', 'g')        with en
# Reducing association of   ('last_two', 'eg')   with en
# Reducing association of   ('last_three', 'teg') with en
#
#   -- Training example: malton fi --
# This example is already predicted correctly
#
#   -- Training example: strävat sv --
# This example is already predicted correctly
#
#   -- Training example: russinen sv --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'r')       with sv
# Increasing association of ('first_two', 'ru')  with sv
# Increasing association of ('last', 'n')        with sv
# Increasing association of ('last_two', 'en')   with sv
# Increasing association of ('last_three', 'nen') with sv
# Reducing association of   ('first', 'r')       with de
# Reducing association of   ('first_two', 'ru')  with de
# Reducing association of   ('last', 'n')        with de
# Reducing association of   ('last_two', 'en')   with de
# Reducing association of   ('last_three', 'nen') with de
#
#   -- Training example: lifted en --
# This example is already predicted correctly
#
#   -- Training example: sund fi --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 's')       with fi
# Increasing association of ('first_two', 'su')  with fi
# Increasing association of ('last', 'd')        with fi
# Increasing association of ('last_two', 'nd')   with fi
# Increasing association of ('last_three', 'und') with fi
# Reducing association of   ('first', 's')       with sv
# Reducing association of   ('first_two', 'su')  with sv
# Reducing association of   ('last', 'd')        with sv
# Reducing association of   ('last_two', 'nd')   with sv
# Reducing association of   ('last_three', 'und') with sv
#
#   -- Training example: kulkeva fi --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'k')       with fi
# Increasing association of ('first_two', 'ku')  with fi
# Increasing association of ('last', 'a')        with fi
# Increasing association of ('last_two', 'va')   with fi
# Increasing association of ('last_three', 'eva') with fi
# Reducing association of   ('first', 'k')       with sv
# Reducing association of   ('first_two', 'ku')  with sv
# Reducing association of   ('last', 'a')        with sv
# Reducing association of   ('last_two', 'va')   with sv
# Reducing association of   ('last_three', 'eva') with sv
#
#   -- Training example: mart en --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'm')       with en
# Increasing association of ('first_two', 'ma')  with en
# Increasing association of ('last', 't')        with en
# Increasing association of ('last_two', 'rt')   with en
# Increasing association of ('last_three', 'art') with en
# Reducing association of   ('first', 'm')       with fi
# Reducing association of   ('first_two', 'ma')  with fi
# Reducing association of   ('last', 't')        with fi
# Reducing association of   ('last_two', 'rt')   with fi
# Reducing association of   ('last_three', 'art') with fi
#
#   -- Training example: Carmen de --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'C')       with de
# Increasing association of ('first_two', 'Ca')  with de
# Increasing association of ('last', 'n')        with de
# Increasing association of ('last_two', 'en')   with de
# Increasing association of ('last_three', 'men') with de
# Reducing association of   ('first', 'C')       with sv
# Reducing association of   ('first_two', 'Ca')  with sv
# Reducing association of   ('last', 'n')        with sv
# Reducing association of   ('last_two', 'en')   with sv
# Reducing association of   ('last_three', 'men') with sv
#
#   -- Training example: friendship en --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'f')       with en
# Increasing association of ('first_two', 'fr')  with en
# Increasing association of ('last', 'p')        with en
# Increasing association of ('last_two', 'ip')   with en
# Increasing association of ('last_three', 'hip') with en
# Reducing association of   ('first', 'f')       with sv
# Reducing association of   ('first_two', 'fr')  with sv
# Reducing association of   ('last', 'p')        with sv
# Reducing association of   ('last_two', 'ip')   with sv
# Reducing association of   ('last_three', 'hip') with sv
#
#   -- Training example: rockies en --
# This example is already predicted correctly
#
#   -- Training example: neuvoja fi --
# This example is already predicted correctly
#
#   -- Training example: tear en --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 't')       with en
# Increasing association of ('first_two', 'te')  with en
# Increasing association of ('last', 'r')        with en
# Increasing association of ('last_two', 'ar')   with en
# Increasing association of ('last_three', 'ear') with en
# Reducing association of   ('first', 't')       with sv
# Reducing association of   ('first_two', 'te')  with sv
# Reducing association of   ('last', 'r')        with sv
# Reducing association of   ('last_two', 'ar')   with sv
# Reducing association of   ('last_three', 'ear') with sv
#
#   -- Training example: dentelées fr --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'd')       with fr
# Increasing association of ('first_two', 'de')  with fr
# Increasing association of ('last', 's')        with fr
# Increasing association of ('last_two', 'es')   with fr
# Increasing association of ('last_three', 'ées') with fr
# Reducing association of   ('first', 'd')       with en
# Reducing association of   ('first_two', 'de')  with en
# Reducing association of   ('last', 's')        with en
# Reducing association of   ('last_two', 'es')   with en
# Reducing association of   ('last_three', 'ées') with en
#
#   -- Training example: misto en --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'm')       with en
# Increasing association of ('first_two', 'mi')  with en
# Increasing association of ('last', 'o')        with en
# Increasing association of ('last_two', 'to')   with en
# Increasing association of ('last_three', 'sto') with en
# Reducing association of   ('first', 'm')       with fi
# Reducing association of   ('first_two', 'mi')  with fi
# Reducing association of   ('last', 'o')        with fi
# Reducing association of   ('last_two', 'to')   with fi
# Reducing association of   ('last_three', 'sto') with fi
#
#   -- Training example: itsenäinen fi --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'i')       with fi
# Increasing association of ('first_two', 'it')  with fi
# Increasing association of ('last', 'n')        with fi
# Increasing association of ('last_two', 'en')   with fi
# Increasing association of ('last_three', 'nen') with fi
# Reducing association of   ('first', 'i')       with sv
# Reducing association of   ('first_two', 'it')  with sv
# Reducing association of   ('last', 'n')        with sv
# Reducing association of   ('last_two', 'en')   with sv
# Reducing association of   ('last_three', 'nen') with sv
#
#   -- Training example: saint-germain-en-laye fr --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 's')       with fr
# Increasing association of ('first_two', 'sa')  with fr
# Increasing association of ('last', 'e')        with fr
# Increasing association of ('last_two', 'ye')   with fr
# Increasing association of ('last_three', 'aye') with fr
# Reducing association of   ('first', 's')       with de
# Reducing association of   ('first_two', 'sa')  with de
# Reducing association of   ('last', 'e')        with de
# Reducing association of   ('last_two', 'ye')   with de
# Reducing association of   ('last_three', 'aye') with de
#
#   -- Training example: överskrids sv --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'ö')       with sv
# Increasing association of ('first_two', 'öv')  with sv
# Increasing association of ('last', 's')        with sv
# Increasing association of ('last_two', 'ds')   with sv
# Increasing association of ('last_three', 'ids') with sv
# Reducing association of   ('first', 'ö')       with fr
# Reducing association of   ('first_two', 'öv')  with fr
# Reducing association of   ('last', 's')        with fr
# Reducing association of   ('last_two', 'ds')   with fr
# Reducing association of   ('last_three', 'ids') with fr
#
#   -- Training example: Magdeburger de --
# This example is already predicted correctly
#
#   -- Training example: Förderungen de --
# This example is already predicted correctly
#
#   -- Training example: energiproduktion sv --
# This example was incorrectly predicted to be en
# Increasing association of ('first', 'e')       with sv
# Increasing association of ('first_two', 'en')  with sv
# Increasing association of ('last', 'n')        with sv
# Increasing association of ('last_two', 'on')   with sv
# Increasing association of ('last_three', 'ion') with sv
# Reducing association of   ('first', 'e')       with en
# Reducing association of   ('first_two', 'en')  with en
# Reducing association of   ('last', 'n')        with en
# Reducing association of   ('last_two', 'on')   with en
# Reducing association of   ('last_three', 'ion') with en
#
#   -- Training example: elektronischen de --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'e')       with de
# Increasing association of ('first_two', 'el')  with de
# Increasing association of ('last', 'n')        with de
# Increasing association of ('last_two', 'en')   with de
# Increasing association of ('last_three', 'hen') with de
# Reducing association of   ('first', 'e')       with fi
# ...
# This example is already predicted correctly
#
#   -- Training example: eftermiddagen sv --
# This example is already predicted correctly
#
#   -- Training example: russinen sv --
# This example is already predicted correctly
#
#   -- Training example: självförsörjande sv --
# This example is already predicted correctly
#
#   -- Training example: energiproduktion sv --
# This example is already predicted correctly
#
#   -- Training example: kestämään fi --
# This example is already predicted correctly
#
#   -- Training example: symbolizes en --
# This example is already predicted correctly
#
#   -- Training example: lucy en --
# This example is already predicted correctly
#
#   -- Training example: nazionale fr --
# This example is already predicted correctly
#
#   -- Training example: Litauischen de --
# This example is already predicted correctly
#
#   -- Training example: mcginnis en --
# This example is already predicted correctly
#
#   -- Training example: enemies en --
# This example is already predicted correctly
#
#   -- Training example: optischen de --
# This example is already predicted correctly
#
#   -- Training example: sprang en --
# This example is already predicted correctly
#
#   -- Training example: blasphème fr --
# This example is already predicted correctly
#
#   -- Training example: maximized en --
# This example is already predicted correctly
#
#   -- Training example: Agiv de --
# This example is already predicted correctly
#
#   -- Training example: exploit fr --
# This example is already predicted correctly
#
#   -- Training example: rakapparat sv --
# This example is already predicted correctly
#
#   -- Training example: Förderungen de --
# This example is already predicted correctly
#
#   -- Training example: volatile fr --
# This example is already predicted correctly
#
#   -- Training example: läheisen fi --
# This example is already predicted correctly
#
#   -- Training example: oansenlig sv --
# This example is already predicted correctly
#
#   -- Training example: tarkoitettuihin fi --
# This example is already predicted correctly
#
#   -- Training example: calonne fr --
# This example is already predicted correctly
#
#   -- Training example: trilleri fi --
# This example is already predicted correctly
#
#   -- Training example: toimenpidevapaa fi --
# This example is already predicted correctly
#
#   -- Training example: vajoan fi --
# This example is already predicted correctly
#
#   -- Training example: buddies en --
# This example is already predicted correctly
#
#   -- Training example: avtal sv --
# This example is already predicted correctly
#
#   -- Training example: oestrogène fr --
# This example is already predicted correctly
#
#   -- Training example: greensboro en --
# This example is already predicted correctly
#
#   -- Training example: baby en --
# This example is already predicted correctly
#
#   -- Training example: avgav sv --
# This example is already predicted correctly
#
#   -- Training example: adaptations fr --
# This example is already predicted correctly
#
#   -- Training example: wealthy en --
# This example is already predicted correctly
#
#   -- Training example: kieltävät fi --
# This example is already predicted correctly
#
#   -- Training example: encyclopedic en --
# This example is already predicted correctly
#
#   -- Training example: vorbekanntem de --
# This example is already predicted correctly
#
#   -- Training example: micro-organisme fr --
# This example is already predicted correctly
#
#   -- Training example: trivseln sv --
# This example is already predicted correctly
#
#   -- Training example: efterhand sv --
# This example is already predicted correctly
#
#   -- Training example: ring en --
# This example is already predicted correctly
#
#   -- Training example: infångas sv --
# This example is already predicted correctly
#
#   -- Training example: barnafödandet sv --
# This example was incorrectly predicted to be de
# Increasing association of ('first', 'b')       with sv
# Increasing association of ('first_two', 'ba')  with sv
# Increasing association of ('last', 't')        with sv
# Increasing association of ('last_two', 'et')   with sv
# Increasing association of ('last_three', 'det') with sv
# Reducing association of   ('first', 'b')       with de
# Reducing association of   ('first_two', 'ba')  with de
# Reducing association of   ('last', 't')        with de
# Reducing association of   ('last_two', 'et')   with de
# Reducing association of   ('last_three', 'det') with de
#
#   -- Training example: Russ de --
# This example is already predicted correctly
#
#   -- Training example: vastly en --
# This example is already predicted correctly
#
#   -- Training example: vocaliste fr --
# This example is already predicted correctly
#
#   -- Training example: tahoja fi --
# This example is already predicted correctly
#
#   -- Training example: deponerade sv --
# This example is already predicted correctly
#
#   -- Training example: iakttas sv --
# This example is already predicted correctly
#
#   -- Training example: directed en --
# This example is already predicted correctly
#
#   -- Training example: joutuvat fi --
# This example is already predicted correctly
#
#   -- Training example: imperative en --
# This example is already predicted correctly
#
#   -- Training example: luktslemhinnor sv --
# This example is already predicted correctly
#
#   -- Training example: bilen sv --
# This example is already predicted correctly
#
#   -- Training example: populationens sv --
# This example is already predicted correctly
#
#   -- Training example: répondit fr --
# This example is already predicted correctly
#
#   -- Training example: maakohtaisen fi --
# This example is already predicted correctly
#
#   -- Training example: kulkija fi --
# This example is already predicted correctly
#
#   -- Training example: jatkoa fi --
# This example is already predicted correctly
#
#   -- Training example: georgialaisen fi --
# This example is already predicted correctly
#
#   -- Training example: brottslighet sv --
# This example is already predicted correctly
#
#   -- Training example: michele en --
# This example is already predicted correctly
#
#   -- Training example: bekvämlighet sv --
# This example is already predicted correctly
#
#   -- Training example: katsomansa fi --
# This example is already predicted correctly
#
#   -- Training example: misto en --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'm')       with en
# Increasing association of ('first_two', 'mi')  with en
# Increasing association of ('last', 'o')        with en
# Increasing association of ('last_two', 'to')   with en
# Increasing association of ('last_three', 'sto') with en
# Reducing association of   ('first', 'm')       with fr
# Reducing association of   ('first_two', 'mi')  with fr
# Reducing association of   ('last', 'o')        with fr
# Reducing association of   ('last_two', 'to')   with fr
# Reducing association of   ('last_three', 'sto') with fr
#
#   -- Training example: ella fr --
# This example was incorrectly predicted to be fi
# Increasing association of ('first', 'e')       with fr
# Increasing association of ('first_two', 'el')  with fr
# Increasing association of ('last', 'a')        with fr
# Increasing association of ('last_two', 'la')   with fr
# Increasing association of ('last_three', 'lla') with fr
# Reducing association of   ('first', 'e')       with fi
# Reducing association of   ('first_two', 'el')  with fi
# Reducing association of   ('last', 'a')        with fi
# Reducing association of   ('last_two', 'la')   with fi
# Reducing association of   ('last_three', 'lla') with fi
#
#   -- Training example: ordnat sv --
# This example is already predicted correctly
#
#   -- Training example: tunnukseksi fi --
# This example is already predicted correctly
#
#   -- Training example: desisted en --
# This example is already predicted correctly
#
#   -- Training example: title en --
# This example is already predicted correctly
#
#   -- Training example: Experience de --
# This example is already predicted correctly
#
#   -- Training example: bostadsbeståndet sv --
# This example is already predicted correctly
#
#   -- Training example: unvollständig de --
# This example is already predicted correctly
#
#   -- Training example: tarkoitetuilla fi --
# This example is already predicted correctly
#
#   -- Training example: verschwändet de --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'v')       with de
# Increasing association of ('first_two', 've')  with de
# Increasing association of ('last', 't')        with de
# Increasing association of ('last_two', 'et')   with de
# Increasing association of ('last_three', 'det') with de
# Reducing association of   ('first', 'v')       with sv
# Reducing association of   ('first_two', 've')  with sv
# Reducing association of   ('last', 't')        with sv
# Reducing association of   ('last_two', 'et')   with sv
# Reducing association of   ('last_three', 'det') with sv
#
#   -- Training example: vauhkosin fi --
# This example is already predicted correctly
#
#   -- Training example: Lower de --
# This example is already predicted correctly
#
#   -- Training example: Rübennematoden de --
# This example is already predicted correctly
#
#   -- Training example: Todesschütze de --
# This example is already predicted correctly
#
#   -- Training example: kiviä fi --
# This example is already predicted correctly
#
#   -- Training example: itsenäinen fi --
# This example is already predicted correctly
#
#   -- Training example: machine en --
# This example is already predicted correctly
#
#   -- Training example: delhi en --
# This example is already predicted correctly
#
#   -- Training example: talk en --
# This example is already predicted correctly
#
#   -- Training example: succinctly en --
# This example is already predicted correctly
#
#   -- Training example: changed en --
# This example is already predicted correctly
#
#   -- Training example: Thyra de --
# This example is already predicted correctly
#
#   -- Training example: formulering sv --
# This example is already predicted correctly
#
#   -- Training example: meanest en --
# This example is already predicted correctly
#
#   -- Training example: mutiloa fr --
# This example is already predicted correctly
#
#   -- Training example: saint-germain-en-laye fr --
# This example is already predicted correctly
#
#   -- Training example: bebyggelsen sv --
# This example is already predicted correctly
#
#   -- Training example: demporos fr --
# This example is already predicted correctly
#
#   -- Training example: följas sv --
# This example is already predicted correctly
#
#   -- Training example: existerande sv --
# This example is already predicted correctly
#
#   -- Training example: grusendorf en --
# This example is already predicted correctly
#
#   -- Training example: lifted en --
# This example is already predicted correctly
#
#   -- Training example: wesentlich de --
# This example is already predicted correctly
#
#   -- Training example: rosablasse de --
# This example is already predicted correctly
#
#   -- Training example: Fallenstopper de --
# This example is already predicted correctly
#
#   -- Training example: kvinnligt sv --
# This example is already predicted correctly
#
#   -- Training example: network en --
# This example was incorrectly predicted to be fr
# Increasing association of ('first', 'n')       with en
# Increasing association of ('first_two', 'ne')  with en
# Increasing association of ('last', 'k')        with en
# Increasing association of ('last_two', 'rk')   with en
# Increasing association of ('last_three', 'ork') with en
# Reducing association of   ('first', 'n')       with fr
# Reducing association of   ('first_two', 'ne')  with fr
# Reducing association of   ('last', 'k')        with fr
# Reducing association of   ('last_two', 'rk')   with fr
# Reducing association of   ('last_three', 'ork') with fr
#
#   -- Training example: gallischen de --
# This example is already predicted correctly
#
#   -- Training example: Diplome de --
# This example is already predicted correctly
#
#   -- Training example: författare sv --
# This example is already predicted correctly
#
#   -- Training example: ylistää fi --
# This example is already predicted correctly
#
#   -- Training example: Nutzhanf de --
# This example is already predicted correctly
#
#   -- Training example: archibald en --
# This example is already predicted correctly
#
#   -- Training example: sämsta sv --
# This example is already predicted correctly
#
#   -- Training example: leakage en --
# This example is already predicted correctly
#
#   -- Training example: multipliziert de --
# This example is already predicted correctly
#
#   -- Training example: bespannt de --
# This example is already predicted correctly
#
#   -- Training example: valiant en --
# This example is already predicted correctly
#
#   -- Training example: assé-le-riboulle-au-maire fr --
# This example is already predicted correctly
#
#   -- Training example: inconvenient en --
# This example is already predicted correctly
#
#   -- Training example: duger sv --
# This example is already predicted correctly
#
#   -- Training example: bryant en --
# This example is already predicted correctly
#
#   -- Training example: Emilia de --
# This example is already predicted correctly
#
#   -- Training example: kaidetta fi --
# This example was incorrectly predicted to be sv
# Increasing association of ('first', 'k')       with fi
# Increasing association of ('first_two', 'ka')  with fi
# Increasing association of ('last', 'a')        with fi
# Increasing association of ('last_two', 'ta')   with fi
# Increasing association of ('last_three', 'tta') with fi
# Reducing association of   ('first', 'k')       with sv
# Reducing association of   ('first_two', 'ka')  with sv
# Reducing association of   ('last', 'a')        with sv
# Reducing association of   ('last_two', 'ta')   with sv
# Reducing association of   ('last_three', 'tta') with sv
#
#   -- Training example: Kurdistan de --
# This example is already predicted correctly
#
#   -- Training example: departure en --
# This example is already predicted correctly
#
#   -- Training example: überformt de --
# This example is already predicted correctly
#
#   -- Training example: plastfoliekuddar sv --
# This example is already predicted correctly
#
#   -- Training example: touch en --
# This example is already predicted correctly
#
#   -- Training example: suomalaisia fi --
# This example is already predicted correctly
#
#   -- Training example: fritt sv --
# This example is already predicted correctly
#
#   -- Training example: vaikutukseltaan fi --
# This example is already predicted correctly
#
#   -- Training example: Nannini de --
# This example is already predicted correctly
#
#   -- Training example: kiinnostumaan fi --
# This example is already predicted correctly
#
#   -- Training example: chambermaid en --
# This example is already predicted correctly
#
#   -- Training example: fournisseur fr --
# This example is already predicted correctly
#
#   -- Training example: katkennut fi --
# This example is already predicted correctly
#
#   -- Training example: kivimiehineen fi --
# This example is already predicted correctly
#
#   -- Training example: eckhart fr --
# This example is already predicted correctly
#
#   -- Training example: Entomogamie de --
# This example is already predicted correctly
#
#   -- Training example: yksistään fi --
# This example is already predicted correctly
#
#   -- Training example: Totenorakel de --
# This example is already predicted correctly
#
#   -- Training example: based en --
# This example is already predicted correctly
#
#   -- Training example: modus en --
# This example is already predicted correctly
#
#   -- Training example: counterparties en --
# This example is already predicted correctly
#
#   -- Training example: rappeutunut fi --
# This example is already predicted correctly
#
#   -- Training example: teenager en --
# This example is already predicted correctly
#
#   -- Training example: Teutschland de --
# This example is already predicted correctly
#
#   -- Training example: toyota fr --
# This example is already predicted correctly
#
#   -- Training example: laßt de --
# This example is already predicted correctly
#
#   -- Training example: berör sv --
# This example is already predicted correctly
#
#   -- Training example: kantavat fi --
# This example is already predicted correctly
#
#   -- Training example: stadsfullmäktige sv --
# This example is already predicted correctly
#
#   -- Training example: dentelées fr --
# This example is already predicted correctly

# %% [markdown]
# <p>Some of the training examples were incorrectly classified and resulted in weight updates.</p>
# <p>So what are the weights now?</p>

# %%
from pprint import pprint
pprint(weights)
# Out:
# Counter({(('last_three', 'des'), 'sv'): 6,
#          (('last_three', 'ies'), 'en'): 5,
#          (('first', 'k'), 'fi'): 5,
#          (('last_three', 'ées'), 'fr'): 5,
#          (('last_three', 'lse'), 'sv'): 5,
#          (('last_three', 'gon'), 'en'): 5,
#          (('last_three', 'hen'), 'de'): 4,
#          (('last_three', 'ons'), 'fr'): 4,
#          (('first_two', 'av'), 'sv'): 4,
#          (('first_two', 'ex'), 'en'): 4,
#          (('first', 'M'), 'de'): 4,
#          (('last_three', 'ose'), 'en'): 4,
#          (('last_three', 'ige'), 'de'): 4,
#          (('last_three', 'nnt'), 'de'): 4,
#          (('last_three', 'nor'), 'sv'): 4,
#          (('first_two', 'fu'), 'en'): 4,
#          (('last_three', 'ble'), 'en'): 4,
#          (('last_three', 'ota'), 'fr'): 4,
#          (('last_three', 'dar'), 'sv'): 4,
#          (('last_three', 'ean'), 'en'): 4,
#          (('last_three', 'nsa'), 'fi'): 4,
#          (('last_three', 'red'), 'fr'): 4,
#          (('last_three', 'mme'), 'fi'): 4,
#          (('last_three', 'est'), 'en'): 4,
#          (('first_two', 'eq'), 'en'): 4,
#          (('last', 'n'), 'fi'): 3,
#          (('first', 'T'), 'de'): 3,
#          (('first_two', 'se'), 'fr'): 3,
#          (('last_three', 'gan'), 'sv'): 3,
#          (('first', 'b'), 'sv'): 3,
#          (('last_three', 'ert'), 'de'): 3,
#          (('first_two', 'sc'), 'de'): 3,
#          (('first_two', 'né'), 'fr'): 3,
#          (('first', 'S'), 'de'): 3,
#          (('first_two', 'sä'), 'sv'): 3,
#          (('last_two', 'aa'), 'fi'): 3,
#          (('last_two', 'rs'), 'fr'): 3,
#          (('last_two', 'le'), 'en'): 3,
#          (('last', 'i'), 'fi'): 3,
#          (('first', 'E'), 'de'): 3,
#          (('first_two', 'si'), 'fr'): 3,
#          (('last_two', 'ée'), 'fr'): 3,
#          (('last_three', 'sit'), 'fi'): 3,
#          (('last', 'c'), 'en'): 3,
#          (('last_two', 'ic'), 'en'): 3,
#          (('last_three', 'dic'), 'en'): 3,
#          (('last_three', 'ten'), 'sv'): 3,
#          (('first_two', 'ti'), 'sv'): 3,
#          (('last_three', 'are'), 'sv'): 3,
#          (('first', 'f'), 'sv'): 3,
#          (('first_two', 'ru'), 'sv'): 3,
#          (('last_three', 'und'), 'fi'): 3,
#          (('first_two', 'te'), 'en'): 3,
#          (('last_two', 'to'), 'en'): 3,
#          (('last_three', 'sto'), 'en'): 3,
#          (('first_two', 'it'), 'fi'): 3,
#          (('first', 'ö'), 'sv'): 3,
#          (('first_two', 'öv'), 'sv'): 3,
#          (('first_two', 'en'), 'sv'): 3,
#          (('first', 'V'), 'de'): 3,
#          (('last_three', 'ncy'), 'de'): 3,
#          (('first_two', 'el'), 'fr'): 3,
#          (('last_three', 'ond'), 'fr'): 3,
#          (('last_three', 'ero'), 'fr'): 3,
#          (('first_two', 'br'), 'en'): 3,
#          (('last', 'y'), 'en'): 3,
#          (('last_two', 'rm'), 'en'): 3,
#          (('last_three', 'orm'), 'en'): 3,
#          (('first_two', 'ec'), 'fr'): 3,
#          (('last_three', 'art'), 'fr'): 3,
#          (('last_two', 'se'), 'sv'): 3,
#          (('first_two', 'pa'), 'fr'): 3,
#          (('first_two', 'fo'), 'fr'): 3,
#          (('first_two', 'lo'), 'fr'): 3,
#          (('last_two', 'it'), 'fr'): 3,
#          (('first_two', 'no'), 'fi'): 3,
#          (('last_three', 'lle'), 'fr'): 3,
#          (('last_three', 'son'), 'fi'): 3,
#          (('last_two', 'de'), 'sv'): 3,
#          (('last_two', 'as'), 'sv'): 3,
#          (('first_two', 'st'), 'sv'): 3,
#          (('first_two', 'to'), 'fr'): 3,
#          (('last_three', 'tte'), 'fi'): 3,
#          (('first', 'L'), 'de'): 3,
#          (('last_three', 'ele'), 'en'): 3,
#          (('first_two', 'pl'), 'fr'): 3,
#          (('last_three', 'ier'), 'fr'): 3,
#          (('first_two', 've'), 'de'): 3,
#          (('first_two', 'pe'), 'sv'): 3,
#          (('first_two', 'ac'), 'fr'): 3,
#          (('last_three', 'vor'), 'en'): 3,
#          (('first_two', 'em'), 'fr'): 3,
#          (('last_three', 'ise'), 'fr'): 3,
#          (('last_three', 'jet'), 'fr'): 3,
#          (('first_two', 'la'), 'en'): 3,
#          (('first_two', 'vä'), 'sv'): 3,
#          (('first_two', 'sm'), 'en'): 3,
#          (('first_two', 'up'), 'sv'): 3,
#          (('last_two', 'me'), 'fi'): 3,
#          (('last_three', 'dge'), 'en'): 3,
#          (('first_two', 'ut'), 'sv'): 3,
#          (('last_three', 'kes'), 'sv'): 3,
#          (('first', 'F'), 'de'): 3,
#          (('first_two', 'gl'), 'en'): 3,
#          (('last_three', 'ast'), 'fr'): 3,
#          (('last_three', 'nel'), 'fr'): 3,
#          (('last_three', 'sch'), 'de'): 3,
#          (('first_two', 'al'), 'fi'): 3,
#          (('first_two', 'na'), 'fr'): 3,
#          (('last_three', 'ver'), 'en'): 3,
#          (('last_three', 'rms'), 'en'): 3,
#          (('last_three', 'uch'), 'en'): 3,
#          (('last_three', 'lar'), 'en'): 3,
#          (('last_three', 'jon'), 'fr'): 3,
#          (('first_two', 'hé'), 'fr'): 3,
#          (('first_two', 'um'), 'de'): 3,
#          (('last_three', 'oan'), 'fi'): 2,
#          (('first_two', 'va'), 'en'): 2,
#          (('last_two', 'en'), 'de'): 2,
#          (('last_two', 'in'), 'fi'): 2,
#          (('last_three', 'jen'), 'fi'): 2,
#          (('first_two', 'gu'), 'fr'): 2,
#          (('first', 'g'), 'en'): 2,
#          (('last_two', 'ns'), 'fr'): 2,
#          (('first', 's'), 'sv'): 2,
#          (('last_two', 'en'), 'sv'): 2,
#          (('last_three', 'men'), 'de'): 2,
#          (('last', 't'), 'de'): 2,
#          (('last_two', 'ls'), 'en'): 2,
#          (('last_three', 'tes'), 'de'): 2,
#          (('first', 's'), 'en'): 2,
#          (('first', 'e'), 'fr'): 2,
#          (('last_three', 'tes'), 'fr'): 2,
#          (('last_three', 'het'), 'sv'): 2,
#          (('first', 'i'), 'en'): 2,
#          (('first_two', 'im'), 'en'): 2,
#          (('first_two', 'co'), 'fr'): 2,
#          (('first', 'c'), 'en'): 2,
#          (('last_three', 'ent'), 'sv'): 2,
#          (('last', 'a'), 'fi'): 2,
#          (('first', 'a'), 'fr'): 2,
#          (('last_two', 'ir'), 'fr'): 2,
#          (('last_three', 'oir'), 'fr'): 2,
#          (('last', 'r'), 'sv'): 2,
#          (('first', 'b'), 'en'): 2,
#          (('last_two', 'ed'), 'en'): 2,
#          (('last_three', 'sed'), 'en'): 2,
#          (('last_two', 'at'), 'sv'): 2,
#          (('first_two', 'St'), 'de'): 2,
#          (('last_two', 'on'), 'fr'): 2,
#          (('last_three', 'ösa'), 'sv'): 2,
#          (('first', 'o'), 'fr'): 2,
#          (('last_two', 'ng'), 'en'): 2,
#          (('last_three', 'ing'), 'en'): 2,
#          (('first_two', 'po'), 'sv'): 2,
#          (('first', 'y'), 'fi'): 2,
#          (('first_two', 'yh'), 'fi'): 2,
#          (('first_two', 'ur'), 'sv'): 2,
#          (('last_three', 'mla'), 'sv'): 2,
#          (('first_two', 'ma'), 'fi'): 2,
#          (('last_three', 'öld'), 'sv'): 2,
#          (('first', 'h'), 'fi'): 2,
#          (('first_two', 'hu'), 'fi'): 2,
#          (('last_two', 'ön'), 'fi'): 2,
#          (('last_three', 'tön'), 'fi'): 2,
#          (('last_three', 'tur'), 'sv'): 2,
#          (('first', 'W'), 'de'): 2,
#          (('last_two', 'em'), 'de'): 2,
#          (('first_two', 'ch'), 'en'): 2,
#          (('first_two', 'ed'), 'fi'): 2,
#          (('last', 'ä'), 'fi'): 2,
#          (('last_two', 'tä'), 'fi'): 2,
#          (('last_three', 'stä'), 'fi'): 2,
#          (('first', 'e'), 'sv'): 2,
#          (('last_two', 'he'), 'de'): 2,
#          (('first', 'n'), 'fi'): 2,
#          (('last_three', 'ani'), 'fi'): 2,
#          (('first', 'd'), 'en'): 2,
#          (('first_two', 'de'), 'en'): 2,
#          (('first_two', 'su'), 'fi'): 2,
#          (('last_two', 'nd'), 'fi'): 2,
#          (('first_two', 'ku'), 'fi'): 2,
#          (('first', 'C'), 'de'): 2,
#          (('first_two', 'Ca'), 'de'): 2,
#          (('last', 'o'), 'en'): 2,
#          (('first_two', 'ph'), 'en'): 2,
#          (('last_three', 'nes'), 'en'): 2,
#          (('first_two', 'Va'), 'de'): 2,
#          (('last_three', 'ure'), 'en'): 2,
#          (('last_two', 'cy'), 'de'): 2,
#          (('first_two', 'ef'), 'sv'): 2,
#          (('first', 'w'), 'fr'): 2,
#          (('first_two', 'wa'), 'fr'): 2,
#          (('last_three', 'ace'), 'fr'): 2,
#          (('last', 'é'), 'fr'): 2,
#          (('first_two', 're'), 'de'): 2,
#          (('last_three', 'lte'), 'de'): 2,
#          (('last_two', 'ro'), 'fr'): 2,
#          (('last_three', 'sen'), 'fi'): 2,
#          (('first', 'A'), 'de'): 2,
#          (('last_three', 'lla'), 'fi'): 2,
#          (('last', 'm'), 'en'): 2,
#          (('first_two', 'we'), 'de'): 2,
#          (('last_three', 'der'), 'sv'): 2,
#          (('last_two', 'ge'), 'de'): 2,
#          (('last_two', 'ge'), 'en'): 2,
#          (('first_two', 'oa'), 'sv'): 2,
#          (('last_three', 'lig'), 'sv'): 2,
#          (('last_two', 'ßt'), 'de'): 2,
#          (('last_three', 'aßt'), 'de'): 2,
#          (('first_two', 'fä'), 'sv'): 2,
#          (('first_two', 'di'), 'sv'): 2,
#          (('last_two', 'gn'), 'en'): 2,
#          (('last_three', 'ign'), 'en'): 2,
#          (('first', 'G'), 'de'): 2,
#          (('last_two', 'ne'), 'fr'): 2,
#          (('last_three', 'ane'), 'fr'): 2,
#          (('last_two', 'nt'), 'en'): 2,
#          (('first', 'N'), 'de'): 2,
#          (('first_two', 'os'), 'fr'): 2,
#          (('last_three', 'ant'), 'en'): 2,
#          (('last_three', 'tar'), 'sv'): 2,
#          (('last_two', 'hi'), 'en'): 2,
#          (('last_three', 'lhi'), 'en'): 2,
#          (('last_two', 'or'), 'sv'): 2,
#          (('last_three', 'det'), 'de'): 2,
#          (('first_two', 'dr'), 'en'): 2,
#          (('last_three', 'rag'), 'en'): 2,
#          (('last_three', 'lle'), 'fi'): 2,
#          (('first_two', 'sj'), 'sv'): 2,
#          (('last_three', 'iga'), 'sv'): 2,
#          (('first', 'm'), 'fr'): 2,
#          (('last_three', 'ile'), 'fr'): 2,
#          (('first_two', 'he'), 'fi'): 2,
#          (('first_two', 'is'), 'en'): 2,
#          (('last_three', 'bia'), 'en'): 2,
#          (('last_three', 'ade'), 'sv'): 2,
#          (('last_two', 'ke'), 'en'): 2,
#          (('last_three', 'oke'), 'en'): 2,
#          (('first_two', 'uc'), 'fr'): 2,
#          (('last_three', 'car'), 'fr'): 2,
#          (('first_two', 'sp'), 'en'): 2,
#          (('last_two', 'ys'), 'fi'): 2,
#          (('last_three', 'yys'), 'fi'): 2,
#          (('last_three', 'den'), 'de'): 2,
#          (('last_three', 'eur'), 'fr'): 2,
#          (('first_two', 'fo'), 'sv'): 2,
#          (('first_two', 'un'), 'en'): 2,
#          (('last_three', 'sta'), 'fi'): 2,
#          (('last_three', 'ino'), 'fr'): 2,
#          (('last_three', 'ire'), 'fr'): 2,
#          (('last_two', 'jo'), 'fi'): 2,
#          (('last_three', 'hjo'), 'fi'): 2,
#          (('last_two', 'ka'), 'sv'): 2,
#          (('last_three', 'ska'), 'sv'): 2,
#          (('last_three', 'zer'), 'fr'): 2,
#          (('last_three', 'ale'), 'de'): 2,
#          (('last_two', 'os'), 'fr'): 2,
#          (('last_three', 'ros'), 'fr'): 2,
#          (('first_two', 'tu'), 'fi'): 2,
#          (('first_two', 'fö'), 'sv'): 2,
#          (('last_two', 'rn'), 'sv'): 2,
#          (('last_three', 'orn'), 'sv'): 2,
#          (('first_two', 'ha'), 'sv'): 2,
#          (('last_two', 'gs'), 'sv'): 2,
#          (('last_three', 'ägs'), 'sv'): 2,
#          (('first_two', 'bo'), 'fr'): 2,
#          (('last_two', 'ly'), 'en'): 2,
#          (('last_two', 'ig'), 'de'): 2,
#          (('last_three', 'dig'), 'de'): 2,
#          (('last_two', 'ln'), 'sv'): 2,
#          (('last_three', 'eln'), 'sv'): 2,
#          (('first_two', 'kv'), 'sv'): 2,
#          (('first_two', 'vo'), 'fr'): 2,
#          (('first_two', 'ja'), 'sv'): 2,
#          (('last_three', 'den'), 'sv'): 2,
#          (('first', 'R'), 'de'): 2,
#          (('first_two', 'ab'), 'de'): 2,
#          (('first_two', 'ca'), 'fr'): 2,
#          (('last_two', 'na'), 'sv'): 2,
#          (('last_three', 'rna'), 'sv'): 2,
#          (('first', 'j'), 'en'): 2,
#          (('first_two', 'ja'), 'en'): 2,
#          (('last_three', 'eno'), 'en'): 2,
#          (('first_two', 'mc'), 'en'): 2,
#          (('last_three', 'nis'), 'en'): 2,
#          (('first_two', 'ri'), 'en'): 2,
#          (('last_two', 'sa'), 'fi'): 2,
#          (('first_two', 'mi'), 'sv'): 2,
#          (('last_three', 'nst'), 'sv'): 2,
#          (('first_two', 'ko'), 'fi'): 2,
#          (('last_two', 'us'), 'en'): 2,
#          (('last_three', 'ous'), 'en'): 2,
#          (('first_two', 'me'), 'fr'): 2,
#          (('last_three', 'gen'), 'sv'): 2,
#          (('last_three', 'ral'), 'en'): 2,
#          (('last_three', 'sse'), 'de'): 2,
#          (('last', 'k'), 'en'): 2,
#          (('last_two', 'rk'), 'en'): 2,
#          (('last_three', 'ork'), 'en'): 2,
#          (('last_two', 'és'), 'fr'): 2,
#          (('last_three', 'tés'), 'fr'): 2,
#          (('first_two', 'ar'), 'en'): 2,
#          (('last_three', 'ald'), 'en'): 2,
#          (('last_three', 'nat'), 'sv'): 2,
#          (('first_two', 'aq'), 'en'): 2,
#          (('last_two', 'fe'), 'en'): 2,
#          (('last_three', 'afe'), 'en'): 2,
#          (('last_three', 'gar'), 'fr'): 2,
#          (('first_two', 'dé'), 'fr'): 2,
#          (('first', 'y'), 'fr'): 2,
#          (('first_two', 'ya'), 'fr'): 2,
#          (('last_three', 'ate'), 'fr'): 2,
#          (('last_two', 'vs'), 'sv'): 2,
#          (('last_three', 'rvs'), 'sv'): 2,
#          (('last_two', 'pe'), 'fr'): 2,
#          (('last_three', 'ppe'), 'fr'): 2,
#          (('last_three', 'oit'), 'fr'): 2,
#          (('first_two', 'pu'), 'fi'): 2,
#          (('first_two', 'mu'), 'fr'): 2,
#          (('last_two', 'oa'), 'fr'): 2,
#          (('last_three', 'loa'), 'fr'): 2,
#          (('last_three', 'nge'), 'en'): 2,
#          (('last_three', 'lta'), 'sv'): 2,
#          (('first_two', 'ha'), 'en'): 2,
#          (('last_three', 'unt'), 'en'): 2,
#          (('last_two', 'im'), 'fr'): 2,
#          (('last_three', 'eim'), 'fr'): 2,
#          (('last_three', 'ues'), 'fr'): 2,
#          (('first_two', 'pu'), 'en'): 2,
#          (('last_three', 'ets'), 'en'): 2,
#          (('first_two', 'om'), 'fr'): 2,
#          (('last_three', 'éga'), 'fr'): 2,
#          (('last_two', 'kt'), 'sv'): 2,
#          (('last_three', 'ikt'), 'sv'): 2,
#          (('last_two', 'el'), 'fr'): 2,
#          (('last_three', 'zes'), 'en'): 2,
#          (('last_two', 'gt'), 'sv'): 2,
#          (('last', 'h'), 'de'): 2,
#          (('last_two', 'ch'), 'de'): 2,
#          (('last_three', 'ati'), 'sv'): 2,
#          (('first_two', 'sk'), 'en'): 2,
#          (('last_three', 'ssa'), 'sv'): 2,
#          (('last_three', 'ens'), 'sv'): 2,
#          (('last_three', 'rer'), 'fr'): 2,
#          (('first_two', 'ro'), 'fi'): 2,
#          (('last_three', 'ine'), 'en'): 2,
#          (('last_two', 'ät'), 'fi'): 2,
#          (('first_two', 'Ma'), 'de'): 2,
#          (('last_two', 'ht'), 'de'): 2,
#          (('last_two', 'pt'), 'en'): 2,
#          (('last_three', 'ept'), 'en'): 2,
#          (('first_two', 'ce'), 'sv'): 2,
#          (('last_three', 'asi'), 'fr'): 2,
#          (('last_two', 'de'), 'de'): 2,
#          (('last_three', 'nde'), 'de'): 2,
#          (('first_two', 'dy'), 'sv'): 2,
#          (('last_three', 'sme'), 'fr'): 2,
#          (('last_three', 'ces'), 'en'): 2,
#          (('last_three', 'rse'), 'sv'): 2,
#          (('last_three', 'ton'), 'fi'): 2,
#          (('last_three', 'ört'), 'sv'): 2,
#          (('last_three', 'ats'), 'sv'): 2,
#          (('last_three', 'ume'), 'fr'): 2,
#          (('first', 'v'), 'fi'): 1,
#          (('first_two', 'va'), 'fi'): 1,
#          (('last_two', 'an'), 'fi'): 1,
#          (('first_two', 'op'), 'de'): 1,
#          (('first', 'o'), 'fi'): 1,
#          (('first_two', 'op'), 'fi'): 1,
#          (('last_three', 'lin'), 'fi'): 1,
#          (('first_two', 'se'), 'fi'): 1,
#          (('last_three', 'rat'), 'fr'): 1,
#          (('first_two', 'Th'), 'de'): 1,
#          (('last_two', 'ra'), 'de'): 1,
#          (('last_three', 'yra'), 'de'): 1,
#          (('first_two', 'sp'), 'sv'): 1,
#          (('last', 'n'), 'sv'): 1,
#          (('first_two', 'bi'), 'sv'): 1,
#          (('last_three', 'len'), 'sv'): 1,
#          (('last_two', 'et'), 'sv'): 1,
#          (('last_three', 'set'), 'sv'): 1,
#          (('first_two', 'an'), 'de'): 1,
#          (('first', 'a'), 'sv'): 1,
#          (('first_two', 'an'), 'sv'): 1,
#          (('first_two', 'du'), 'de'): 1,
#          (('last_two', 'rt'), 'fr'): 1,
#          (('first_two', 'ta'), 'en'): 1,
#          (('last_three', 'ils'), 'en'): 1,
#          (('first', 't'), 'fr'): 1,
#          (('last', 's'), 'de'): 1,
#          (('last_two', 'es'), 'de'): 1,
#          (('last_two', 'et'), 'de'): 1,
#          (('last_two', 'ts'), 'en'): 1,
#          (('last_three', 'nts'), 'en'): 1,
#          (('first', 'c'), 'fr'): 1,
#          (('last_three', 'ini'), 'fr'): 1,
#          (('first', 'n'), 'fr'): 1,
#          (('last_two', 'nt'), 'fr'): 1,
#          (('first', 'j'), 'fi'): 1,
#          (('last_three', 'koa'), 'fi'): 1,
#          (('last', 'r'), 'fr'): 1,
#          (('first_two', 'ba'), 'en'): 1,
#          (('first_two', 'ra'), 'sv'): 1,
#          (('last_three', 'rat'), 'sv'): 1,
#          (('first_two', 'be'), 'sv'): 1,
#          (('last_two', 'ör'), 'sv'): 1,
#          (('last_three', 'rör'), 'sv'): 1,
#          (('last_two', 'ms'), 'de'): 1,
#          (('last_three', 'ums'), 'de'): 1,
#          (('last_two', 'ms'), 'en'): 1,
#          (('first', 'e'), 'en'): 1,
#          (('last_two', 'on'), 'en'): 1,
#          (('last', 'a'), 'sv'): 1,
#          (('last_two', 'sa'), 'sv'): 1,
#          (('last_three', 'maa'), 'fi'): 1,
#          (('last', 'x'), 'fr'): 1,
#          (('last_two', 'ux'), 'fr'): 1,
#          (('last_three', 'aux'), 'fr'): 1,
#          (('first_two', 'or'), 'en'): 1,
#          (('first', 'r'), 'en'): 1,
#          (('last', 'g'), 'en'): 1,
#          (('first_two', 'ga'), 'fr'): 1,
#          (('last_three', 'ars'), 'fr'): 1,
#          (('first', 'p'), 'sv'): 1,
#          (('last', 's'), 'sv'): 1,
#          (('last_two', 'is'), 'sv'): 1,
#          (('last_three', 'tis'), 'sv'): 1,
#          (('first', 'p'), 'en'): 1,
#          (('last_two', 'is'), 'en'): 1,
#          (('last', 'e'), 'fr'): 1,
#          (('first', 't'), 'fi'): 1,
#          (('last_two', 'si'), 'fi'): 1,
#          (('last_three', 'osi'), 'fi'): 1,
#          (('first_two', 'Ex'), 'de'): 1,
#          (('last_three', 'nce'), 'de'): 1,
#          (('last_two', 'ce'), 'fr'): 1,
#          (('first', 'u'), 'sv'): 1,
#          (('last_three', 'ken'), 'fi'): 1,
#          (('first_two', 'ma'), 'sv'): 1,
#          (('last_two', 'ld'), 'sv'): 1,
#          (('last_two', 'ld'), 'en'): 1,
#          (('last_three', 'née'), 'fr'): 1,
#          (('last_two', 'it'), 'fi'): 1,
#          (('last', 'l'), 'sv'): 1,
#          (('last_three', 'tal'), 'sv'): 1,
#          (('last', 'l'), 'fr'): 1,
#          (('first_two', 'li'), 'sv'): 1,
#          (('last_two', 'ur'), 'fr'): 1,
#          (('first_two', 'Wi'), 'de'): 1,
#          (('first_two', 'vo'), 'de'): 1,
#          (('last', 'm'), 'de'): 1,
#          (('last_three', 'tem'), 'de'): 1,
#          (('last_three', 'ged'), 'en'): 1,
#          (('last_two', 'ed'), 'fr'): 1,
#          (('last_two', 're'), 'sv'): 1,
#          (('first_two', 'Mi'), 'de'): 1,
#          (('last_three', 'öhe'), 'de'): 1,
#          (('first', 'ü'), 'de'): 1,
#          (('first_two', 'üb'), 'de'): 1,
#          (('last_two', 'mt'), 'de'): 1,
#          (('last_three', 'rmt'), 'de'): 1,
#          (('first_two', 'nu'), 'fi'): 1,
#          (('last_two', 'ni'), 'fi'): 1,
#          (('last_two', 'rt'), 'en'): 1,
#          (('first', 'o'), 'sv'): 1,
#          (('first_two', 'oe'), 'sv'): 1,
#          (('last_two', 'rd'), 'sv'): 1,
#          (('last_three', 'örd'), 'sv'): 1,
#          (('first_two', 'fr'), 'sv'): 1,
#          (('last_two', 'eg'), 'sv'): 1,
#          (('last_three', 'teg'), 'sv'): 1,
#          (('last_three', 'nen'), 'sv'): 1,
#          (('last_two', 'va'), 'fi'): 1,
#          (('last_three', 'eva'), 'fi'): 1,
#          (('first_two', 'ma'), 'en'): 1,
#          (('last_three', 'art'), 'en'): 1,
#          (('last_two', 'ip'), 'en'): 1,
#          (('last_three', 'hip'), 'en'): 1,
#          (('last_three', 'ear'), 'en'): 1,
#          (('last_two', 'ar'), 'sv'): 1,
#          (('first_two', 'sa'), 'fr'): 1,
#          (('last_two', 'ye'), 'fr'): 1,
#          (('last_three', 'aye'), 'fr'): 1,
#          (('last_two', 'ds'), 'sv'): 1,
#          (('last_three', 'ids'), 'sv'): 1,
#          (('last_three', 'ion'), 'sv'): 1,
#          (('first_two', 'pr'), 'en'): 1,
#          (('first', 'p'), 'fr'): 1,
#          (('first_two', 'pr'), 'fr'): 1,
#          (('first_two', 'uu'), 'fi'): 1,
#          (('last_two', 'ia'), 'fi'): 1,
#          (('last_three', 'sia'), 'fi'): 1,
#          (('last_three', 'ion'), 'de'): 1,
#          (('first_two', 'ef'), 'de'): 1,
#          (('last_two', 'té'), 'fr'): 1,
#          (('last_three', 'ité'), 'fr'): 1,
#          (('last_two', 'la'), 'fr'): 1,
#          (('last_three', 'lla'), 'fr'): 1,
#          (('last_two', 'nd'), 'fr'): 1,
#          (('first_two', 'sl'), 'sv'): 1,
#          (('last_three', 'ger'), 'sv'): 1,
#          (('first_two', 'sl'), 'fr'): 1,
#          (('last', 'o'), 'fr'): 1,
#          (('last_three', 'way'), 'en'): 1,
#          (('first_two', 'ge'), 'fi'): 1,
#          (('first_two', 'mu'), 'de'): 1,
#          (('first', 'O'), 'de'): 1,
#          (('first_two', 'Ob'), 'de'): 1,
#          (('last', 'u'), 'de'): 1,
#          (('last_two', 'au'), 'de'): 1,
#          (('last_three', 'gau'), 'de'): 1,
#          (('last_three', 'and'), 'sv'): 1,
#          (('first_two', 'Ag'), 'de'): 1,
#          (('last', 'v'), 'de'): 1,
#          (('last_two', 'iv'), 'de'): 1,
#          (('last_three', 'giv'), 'de'): 1,
#          (('first', 'w'), 'de'): 1,
#          (('last_two', 'er'), 'de'): 1,
#          (('last_three', 'der'), 'de'): 1,
#          (('last_three', 'tet'), 'sv'): 1,
#          (('first', 'd'), 'sv'): 1,
#          (('first_two', 'di'), 'en'): 1,
#          (('last_two', 'se'), 'de'): 1,
#          (('last_three', 'lée'), 'fr'): 1,
#          (('first_two', 'eg'), 'sv'): 1,
#          (('last_two', 'ap'), 'sv'): 1,
#          (('last_three', 'kap'), 'sv'): 1,
#          (('first_two', 'Gl'), 'de'): 1,
#          (('last', 'g'), 'de'): 1,
#          (('last_three', 'ung'), 'de'): 1,
#          (('first_two', 'be'), 'de'): 1,
#          (('first_two', 'Na'), 'de'): 1,
#          (('last_two', 'ni'), 'de'): 1,
#          (('last_three', 'ini'), 'de'): 1,
#          (('last_three', 'ant'), 'fr'): 1,
#          (('last_three', 'irs'), 'fr'): 1,
#          (('first_two', 'Si'), 'de'): 1,
#          (('last_three', 'üne'), 'de'): 1,
#          (('last_three', 'aat'), 'fi'): 1,
#          (('last_three', 'als'), 'en'): 1,
#          (('first_two', 'lu'), 'sv'): 1,
#          (('first_two', 'lu'), 'de'): 1,
#          (('last_three', 'ait'), 'fr'): 1,
#          (('first', 'u'), 'de'): 1,
#          (('first_two', 'un'), 'de'): 1,
#          (('last_two', 'ag'), 'en'): 1,
#          (('last_two', 'ga'), 'sv'): 1,
#          (('first_two', 'mi'), 'fr'): 1,
#          (('last_three', 'nde'), 'sv'): 1,
#          (('last_two', 'ia'), 'en'): 1,
#          (('first_two', 'sa'), 'fi'): 1,
#          (('last_three', 'tti'), 'fi'): 1,
#          (('last_two', 'ti'), 'sv'): 1,
#          (('first_two', 'gr'), 'en'): 1,
#          (('last_three', 'oro'), 'en'): 1,
#          (('first_two', 'Te'), 'de'): 1,
#          (('first', 'l'), 'fi'): 1,
#          (('first_two', 'le'), 'fi'): 1,
#          (('first_two', 'me'), 'de'): 1,
#          (('first_two', 'fl'), 'sv'): 1,
#          (('last_two', 'ta'), 'sv'): 1,
#          (('last_two', 'ta'), 'fr'): 1,
#          (('first_two', 'ka'), 'de'): 1,
#          (('last_three', 'hem'), 'de'): 1,
#          (('last_three', 'gas'), 'sv'): 1,
#          (('first_two', 'ob'), 'fi'): 1,
#          (('first_two', 're'), 'fr'): 1,
#          (('last_two', 'no'), 'fr'): 1,
#          (('last_two', 'no'), 'en'): 1,
#          (('first_two', 'as'), 'fr'): 1,
#          (('last_three', 'ige'), 'sv'): 1,
#          (('first_two', 'Em'), 'de'): 1,
#          (('last_two', 'ia'), 'de'): 1,
#          (('last_three', 'lia'), 'de'): 1,
#          (('first_two', 'to'), 'de'): 1,
#          (('last_three', 'jas'), 'sv'): 1,
#          (('first_two', 'Lo'), 'de'): 1,
#          (('last_three', 'tät'), 'de'): 1,
#          (('first_two', 'pl'), 'sv'): 1,
#          (('last_three', 'tly'), 'en'): 1,
#          (('first_two', 'Ga'), 'de'): 1,
#          (('last_three', 'ray'), 'de'): 1,
#          (('first_two', 'tr'), 'sv'): 1,
#          (('last_two', 'te'), 'fr'): 1,
#          (('last_three', 'ste'), 'fr'): 1,
#          (('last_three', 'eut'), 'de'): 1,
#          (('last_three', 'ent'), 'en'): 1,
#          (('last_two', 'st'), 'sv'): 1,
#          (('last_three', 'rst'), 'sv'): 1,
#          (('first', 'j'), 'sv'): 1,
#          (('first_two', 'Ru'), 'de'): 1,
#          (('last_two', 'ss'), 'de'): 1,
#          (('last_three', 'uss'), 'de'): 1,
#          (('last_three', 'nne'), 'fr'): 1,
#          (('first_two', 'ca'), 'en'): 1,
#          (('last_two', 'ne'), 'en'): 1,
#          (('last_three', 'een'), 'fi'): 1,
#          (('first_two', 'vi'), 'fi'): 1,
#          (('last_three', 'hig'), 'de'): 1,
#          (('first_two', 'ep'), 'fi'): 1,
#          (('last_three', 'tia'), 'fi'): 1,
#          (('first_two', 'er'), 'sv'): 1,
#          (('last_two', 'da'), 'sv'): 1,
#          (('last_three', 'uda'), 'sv'): 1,
#          (('first_two', 'öl'), 'fi'): 1,
#          (('last_two', 'ma'), 'fi'): 1,
#          (('last_three', 'ama'), 'fi'): 1,
#          (('first_two', 'fe'), 'en'): 1,
#          (('last_two', 'or'), 'en'): 1,
#          (('first', 'p'), 'fi'): 1,
#          (('first', 'l'), 'en'): 1,
#          (('last_two', 'ka'), 'en'): 1,
#          (('last_three', 'nka'), 'en'): 1,
#          (('first_two', 'Le'), 'de'): 1,
#          (('last_three', 'kon'), 'de'): 1,
#          (('first_two', 'pe'), 'fi'): 1,
#          (('last_two', 'st'), 'en'): 1,
#          (('first_two', 'tc'), 'fr'): 1,
#          (('last', 'u'), 'fr'): 1,
#          (('last_two', 'eu'), 'fr'): 1,
#          (('last_three', 'heu'), 'fr'): 1,
#          (('last_two', 'ot'), 'fi'): 1,
#          (('last_three', 'rot'), 'fi'): 1,
#          (('last_three', 'que'), 'fr'): 1,
#          (('last_two', 'er'), 'en'): 1,
#          (('last_three', 'ler'), 'en'): 1,
#          (('last_three', 'ler'), 'sv'): 1,
#          (('first_two', 'ob'), 'en'): 1,
#          (('first_two', 'Re'), 'de'): 1,
#          (('last_two', 'ue'), 'de'): 1,
#          (('last_three', 'eue'), 'de'): 1,
#          (('last_two', 'tt'), 'sv'): 1,
#          (('last_three', 'itt'), 'sv'): 1,
#          (('first_two', 'mo'), 'en'): 1,
#          (('last_two', 'al'), 'en'): 1,
#          (('first_two', 'ne'), 'en'): 1,
#          (('last_three', 'aan'), 'fi'): 1,
#          (('first_two', 'or'), 'sv'): 1,
#          (('first', 'K'), 'de'): 1,
#          (('first_two', 'Ku'), 'de'): 1,
#          (('last_three', 'tan'), 'de'): 1,
#          (('first_two', 'tr'), 'fr'): 1,
#          (('first_two', 'We'), 'de'): 1,
#          (('last_three', 'pot'), 'de'): 1,
#          (('last_three', 'fap'), 'fr'): 1,
#          (('first', 'P'), 'de'): 1,
#          (('first_two', 'Ph'), 'de'): 1,
#          (('last_two', 'ys'), 'de'): 1,
#          (('last_three', 'hys'), 'de'): 1,
#          (('first_two', 'jo'), 'fi'): 1,
#          (('last_three', 'vat'), 'fi'): 1,
#          (('last_three', 'rée'), 'fr'): 1,
#          (('first_two', 'ne'), 'sv'): 1,
#          (('first', 'r'), 'fi'): 1,
#          (('first_two', 'ra'), 'fi'): 1,
#          (('last_two', 'ut'), 'fi'): 1,
#          (('last_three', 'nut'), 'fi'): 1,
#          (('first', 'D'), 'de'): 1,
#          (('first_two', 'Di'), 'de'): 1,
#          (('last_three', 'ome'), 'de'): 1,
#          (('first_two', 'mo'), 'fr'): 1,
#          (('last_three', 'men'), 'fi'): 1,
#          (('first_two', 'Fa'), 'de'): 1,
#          (('last_three', 'per'), 'de'): 1,
#          (('first_two', 'fe'), 'fr'): 1,
#          (('last_two', 'hy'), 'en'): 1,
#          (('last_three', 'thy'), 'en'): 1,
#          (('last_two', 'ga'), 'fr'): 1,
#          (('first_two', 'do'), 'fr'): 1,
#          (('last_three', 'ier'), 'en'): 1,
#          (('last_three', 'ast'), 'sv'): 1,
#          (('first_two', 'tu'), 'en'): 1,
#          (('first_two', 'sy'), 'en'): 1,
#          (('first_two', 'mé'), 'fr'): 1,
#          (('last_three', 'ial'), 'fr'): 1,
#          (('last_two', 'io'), 'fr'): 1,
#          (('last_three', 'sio'), 'fr'): 1,
#          (('first_two', 'by'), 'sv'): 1,
#          (('last_three', 'ggt'), 'sv'): 1,
#          (('first_two', 'sy'), 'sv'): 1,
#          (('first_two', 'bl'), 'fr'): 1,
#          (('last_three', 'ème'), 'fr'): 1,
#          (('last_three', 'ksi'), 'fi'): 1,
#          (('last_two', 'si'), 'fr'): 1,
#          (('last_two', 'um'), 'en'): 1,
#          (('last_three', 'ium'), 'en'): 1,
#          (('first_two', 'Mo'), 'de'): 1,
#          (('last_two', 'ts'), 'de'): 1,
#          (('last_three', 'ats'), 'de'): 1,
#          (('last_three', 'vaa'), 'fi'): 1,
#          (('last', 'f'), 'fr'): 1,
#          (('last_two', 'if'), 'fr'): 1,
#          (('last_three', 'tif'), 'fr'): 1,
#          (('first_two', 'yk'), 'fi'): 1,
#          (('last_two', 'än'), 'fi'): 1,
#          (('last_three', 'ään'), 'fi'): 1,
#          (('first', 'B'), 'de'): 1,
#          (('first_two', 'Bu'), 'de'): 1,
#          (('last_two', 'ja'), 'fi'): 1,
#          (('last_three', 'oja'), 'fi'): 1,
#          (('first_two', 'ad'), 'fr'): 1,
#          (('first_two', 'ök'), 'sv'): 1,
#          (('last_three', 'tle'), 'en'): 1,
#          (('last_two', 'ry'), 'en'): 1,
#          (('last_three', 'ary'), 'en'): 1,
#          (('first_two', 'ia'), 'sv'): 1,
#          (('last_three', 'tas'), 'sv'): 1,
#          (('last_two', 'ie'), 'fr'): 1,
#          (('last_three', 'mie'), 'fr'): 1,
#          (('last_two', 'ri'), 'fi'): 1,
#          (('last_three', 'eri'), 'fi'): 1,
#          (('first_two', 'ba'), 'fr'): 1,
#          (('last_two', 'lé'), 'fr'): 1,
#          (('last_three', 'ulé'), 'fr'): 1,
#          (('first_two', 'tä'), 'sv'): 1,
#          (('last_three', 'ted'), 'en'): 1,
#          (('last_three', 'res'), 'en'): 1,
#          (('first_two', 'kä'), 'fi'): 1,
#          (('last_three', 'tät'), 'fi'): 1,
#          (('first', 'ä'), 'sv'): 1,
#          (('first_two', 'äm'), 'sv'): 1,
#          (('last_two', 'll'), 'sv'): 1,
#          (('last_three', 'åll'), 'sv'): 1,
#          (('first_two', 'du'), 'sv'): 1,
#          (('last_three', 'kan'), 'fi'): 1,
#          (('first_two', 'au'), 'de'): 1,
#          (('first_two', 'li'), 'fi'): 1,
#          (('first_two', 'in'), 'de'): 1,
#          (('last_three', 'eht'), 'de'): 1,
#          (('first', 'h'), 'fr'): 1,
#          (('last_three', 'ucy'), 'en'): 1,
#          (('first_two', 'mä'), 'sv'): 1,
#          (('last_three', 'les'), 'sv'): 1,
#          (('last_three', 'pia'), 'fi'): 1,
#          (('last_three', 'ers'), 'fr'): 1,
#          (('first_two', 'ré'), 'fr'): 1,
#          (('last_three', 'dit'), 'fr'): 1,
#          (('first_two', 'le'), 'en'): 1,
#          (('last_three', 'age'), 'en'): 1,
#          (('last_three', 'vin'), 'fi'): 1,
#          (('last_three', 'ren'), 'sv'): 1,
#          (('last_two', 'ca'), 'de'): 1,
#          (('last_three', 'uca'), 'de'): 1,
#          (('last_three', 'res'), 'fr'): 1,
#          (('first_two', 'To'), 'de'): 1,
#          (('last', 'l'), 'de'): 1,
#          (('last_two', 'el'), 'de'): 1,
#          (('last_three', 'kel'), 'de'): 1,
#          (('last_three', 'ien'), 'fi'): 1,
#          (('last_three', 'lly'), 'en'): 1,
#          (('first_two', 'fi'), 'en'): 1,
#          (('last_three', 'ded'), 'en'): 1,
#          (('first_two', 'No'), 'de'): 1,
#          (('last', 'z'), 'fr'): 1,
#          (('last_two', 'ez'), 'fr'): 1,
#          (('last_three', 'rez'), 'fr'): 1,
#          (('first_two', 'Fö'), 'de'): 1,
#          (('last_three', 'ang'), 'en'): 1,
#          (('last_two', 'id'), 'en'): 1,
#          (('last_three', 'aid'), 'en'): 1,
#          (('last_three', 'ich'), 'de'): 1,
#          (('first_two', 'hö'), 'de'): 1,
#          (('last_three', 'che'), 'de'): 1,
#          (('first_two', 'Lu'), 'de'): 1,
#          (('last_three', 'ern'), 'de'): 1,
#          (('first_two', 'ry'), 'fi'): 1,
#          (('last_three', 'ian'), 'fi'): 1,
#          (('first_two', 'Fe'), 'de'): 1,
#          (('first_two', 'oe'), 'fr'): 1,
#          (('last_three', 'ène'), 'fr'): 1,
#          (('last_three', 'igt'), 'sv'): 1,
#          (('first_two', 'ki'), 'fi'): 1,
#          (('last_three', 'vät'), 'fi'): 1,
#          (('first_two', 'do'), 'en'): 1,
#          (('last_three', 'bts'), 'en'): 1,
#          (('first_two', 'lä'), 'fi'): 1,
#          (('first_two', 'st'), 'fi'): 1,
#          (('first_two', 'Ad'), 'de'): 1,
#          (('last_three', 'ams'), 'de'): 1,
#          (('first_two', 'ai'), 'fr'): 1,
#          (('last', 'v'), 'sv'): 1,
#          (('last_two', 'av'), 'sv'): 1,
#          (('last_three', 'gav'), 'sv'): 1,
#          (('last_two', 'ad'), 'sv'): 1,
#          (('last_three', 'sad'), 'sv'): 1,
#          (('first_two', 'Er'), 'de'): 1,
#          (('last_three', 'hes'), 'de'): 1,
#          (('last_three', 'eed'), 'en'): 1,
#          (('last_three', 'lag'), 'sv'): 1,
#          (('last_two', 've'), 'en'): 1,
#          (('last_three', 'ive'), 'en'): 1,
#          (('first_two', 'au'), 'fr'): 1,
#          (('first', 'Z'), 'de'): 1,
#          (('first_two', 'Ze'), 'de'): 1,
#          (('last_three', 'cht'), 'de'): 1,
#          (('first_two', 'Vo'), 'de'): 1,
#          (('last_three', 'ist'), 'de'): 1,
#          (('last_three', 'eet'), 'fi'): 1,
#          (('last_three', 'nte'), 'fr'): 1,
#          (('last_three', 'taa'), 'fi'): 1,
#          (('last_three', 'ont'), 'fr'): 1,
#          (('last_three', 'tta'), 'fi'): 1,
#          (('first', 'v'), 'en'): 0,
#          (('last_two', 'an'), 'en'): 0,
#          (('last', 'n'), 'de'): 0,
#          (('first', 'm'), 'fi'): 0,
#          (('first', 'g'), 'fr'): 0,
#          (('last', 't'), 'fr'): 0,
#          (('last_two', 'at'), 'fr'): 0,
#          (('first', 's'), 'fr'): 0,
#          (('last', 's'), 'fr'): 0,
#          (('last_two', 'an'), 'sv'): 0,
#          (('first', 'v'), 'sv'): 0,
#          (('first_two', 'va'), 'sv'): 0,
#          (('last', 't'), 'sv'): 0,
#          (('last_two', 'et'), 'fi'): 0,
#          (('last_three', 'set'), 'fi'): 0,
#          (('last_two', 'rt'), 'de'): 0,
#          (('first', 'd'), 'fr'): 0,
#          (('first', 't'), 'en'): 0,
#          (('last', 's'), 'en'): 0,
#          (('last_two', 'es'), 'en'): 0,
#          (('first_two', 'ex'), 'fr'): 0,
#          (('last_two', 'es'), 'fr'): 0,
#          (('last', 'i'), 'fr'): 0,
#          (('last_two', 'ni'), 'fr'): 0,
#          (('first_two', 'co'), 'en'): 0,
#          (('last_three', 'ent'), 'fr'): 0,
#          (('first', 'n'), 'sv'): 0,
#          (('first_two', 'ja'), 'fi'): 0,
#          (('last_two', 'oa'), 'fi'): 0,
#          (('last', 'd'), 'en'): 0,
#          (('first_two', 'ba'), 'sv'): 0,
#          (('last', 'd'), 'sv'): 0,
#          (('first', 'r'), 'sv'): 0,
#          (('last', 'r'), 'en'): 0,
#          (('last_three', 'ion'), 'en'): 0,
#          (('last_three', 'ion'), 'fr'): 0,
#          (('last', 'a'), 'fr'): 0,
#          (('first_two', 'om'), 'fi'): 0,
#          (('first_two', 're'), 'en'): 0,
#          (('last', 'g'), 'sv'): 0,
#          (('last_three', 'ing'), 'sv'): 0,
#          (('first', 'g'), 'de'): 0,
#          (('first_two', 'ga'), 'de'): 0,
#          (('last_two', 'le'), 'fr'): 0,
#          (('last', 'e'), 'en'): 0,
#          (('last_three', 'ale'), 'en'): 0,
#          (('last', 'e'), 'de'): 0,
#          (('last_two', 'ce'), 'de'): 0,
#          (('last_two', 'la'), 'sv'): 0,
#          (('last_two', 'la'), 'fi'): 0,
#          (('first', 'm'), 'sv'): 0,
#          (('first', 'i'), 'sv'): 0,
#          (('first_two', 'in'), 'sv'): 0,
#          (('first_two', 'in'), 'en'): 0,
#          (('last_two', 'al'), 'sv'): 0,
#          (('last_two', 'ur'), 'sv'): 0,
#          (('last_three', 'gen'), 'de'): 0,
#          (('first', 'v'), 'de'): 0,
#          (('last', 'd'), 'fr'): 0,
#          (('first_two', 'el'), 'sv'): 0,
#          (('first_two', 'el'), 'de'): 0,
#          (('last_three', 'ert'), 'en'): 0,
#          (('first_two', 'de'), 'de'): 0,
#          (('first', 'f'), 'en'): 0,
#          (('first_two', 'fr'), 'en'): 0,
#          (('last', 'd'), 'fi'): 0,
#          (('first', 'm'), 'en'): 0,
#          (('last', 'p'), 'en'): 0,
#          (('last', 'p'), 'sv'): 0,
#          (('last_two', 'ar'), 'en'): 0,
#          (('first_two', 'de'), 'fr'): 0,
#          (('first_two', 'mi'), 'en'): 0,
#          (('first', 'i'), 'fi'): 0,
#          (('last_three', 'nen'), 'fi'): 0,
#          (('last_two', 'on'), 'de'): 0,
#          (('last_two', 're'), 'en'): 0,
#          (('last_two', 're'), 'fr'): 0,
#          (('last', 'y'), 'de'): 0,
#          (('first', 'f'), 'fr'): 0,
#          (('first_two', 'fl'), 'fr'): 0,
#          (('last_two', 'te'), 'de'): 0,
#          (('last_two', 'er'), 'sv'): 0,
#          (('last_two', 'er'), 'fr'): 0,
#          (('last_two', 'ay'), 'en'): 0,
#          (('last_two', 'ay'), 'de'): 0,
#          (('first_two', 'ge'), 'de'): 0,
#          (('last_two', 'ig'), 'sv'): 0,
#          (('first', 'l'), 'de'): 0,
#          (('first_two', 'la'), 'de'): 0,
#          (('last_two', 'et'), 'fr'): 0,
#          (('last_three', 'lls'), 'sv'): 0,
#          (('last_three', 'lls'), 'en'): 0,
#          (('last', 'p'), 'fr'): 0,
#          (('last_two', 'ap'), 'fr'): 0,
#          (('last_two', 'ng'), 'de'): 0,
#          (('last_two', 'nt'), 'de'): 0,
#          (('last', 'i'), 'de'): 0,
#          (('last_three', 'sen'), 'sv'): 0,
#          (('first', 'ö'), 'fi'): 0,
#          (('last_two', 'at'), 'fi'): 0,
#          (('last_three', 'det'), 'sv'): 0,
#          (('last', 'e'), 'fi'): 0,
#          (('last_two', 'le'), 'fi'): 0,
#          (('last_two', 'on'), 'fi'): 0,
#          (('last_three', 'son'), 'en'): 0,
#          (('first', 'c'), 'sv'): 0,
#          (('last_two', 'ti'), 'fi'): 0,
#          (('last_two', 'ro'), 'en'): 0,
#          (('last', 'd'), 'de'): 0,
#          (('last_two', 'nd'), 'de'): 0,
#          (('last_three', 'and'), 'de'): 0,
#          (('last_two', 'ar'), 'fr'): 0,
#          (('first', 'u'), 'en'): 0,
#          (('first_two', 'me'), 'en'): 0,
#          (('last_three', 'tta'), 'sv'): 0,
#          (('first_two', 'ka'), 'fi'): 0,
#          (('last_two', 'ta'), 'fi'): 0,
#          (('last_three', 'sta'), 'sv'): 0,
#          (('first_two', 'op'), 'fr'): 0,
#          (('last_two', 'ge'), 'sv'): 0,
#          (('first_two', 'ar'), 'sv'): 0,
#          (('first', 'a'), 'fi'): 0,
#          (('last_two', 'te'), 'fi'): 0,
#          (('last_two', 'ät'), 'de'): 0,
#          (('first_two', 'an'), 'fr'): 0,
#          (('last_two', 'rn'), 'de'): 0,
#          (('first_two', 'ma'), 'de'): 0,
#          (('first', 'b'), 'fr'): 0,
#          (('first_two', 'bo'), 'sv'): 0,
#          (('first_two', 'tr'), 'fi'): 0,
#          (('last_two', 'ut'), 'de'): 0,
#          (('first_two', 'os'), 'fi'): 0,
#          (('first_two', 'pe'), 'en'): 0,
#          (('first_two', 'gl'), 'sv'): 0,
#          (('first_two', 'la'), 'fi'): 0,
#          (('last_two', 'ot'), 'de'): 0,
#          (('last_two', 'ue'), 'fr'): 0,
#          (('last_three', 'ane'), 'en'): 0,
#          (('first_two', 'ro'), 'de'): 0,
#          (('first_two', 'in'), 'fr'): 0,
#          (('last_two', 'me'), 'fr'): 0,
#          (('last_two', 'an'), 'de'): 0,
#          (('last_two', 'st'), 'fr'): 0,
#          (('first_two', 'en'), 'fr'): 0,
#          (('last_two', 'me'), 'de'): 0,
#          (('first_two', 'mu'), 'fi'): 0,
#          (('last_three', 'ger'), 'en'): 0,
#          (('last', 'm'), 'fr'): 0,
#          (('first_two', 'we'), 'en'): 0,
#          (('last_two', 'ns'), 'sv'): 0,
#          (('last', 'h'), 'en'): 0,
#          (('last_two', 'ch'), 'en'): 0,
#          (('first_two', 'st'), 'en'): 0,
#          (('last_three', 'ger'), 'de'): 0,
#          (('last_three', 'age'), 'de'): 0,
#          (('first_two', 'al'), 'sv'): 0,
#          (('first_two', 'su'), 'en'): 0,
#          (('first_two', 'bo'), 'en'): 0,
#          (('first_two', 'br'), 'sv'): 0,
#          (('first', 'h'), 'de'): 0,
#          (('last_two', 'ts'), 'sv'): 0,
#          (('last_two', 'ag'), 'sv'): 0,
#          (('first_two', 'su'), 'fr'): 0,
#          (('last_three', 'oan'), 'en'): -1,
#          (('last_two', 'en'), 'fi'): -1,
#          (('first_two', 'mi'), 'fi'): -1,
#          (('last_two', 'in'), 'de'): -1,
#          (('last_three', 'lin'), 'de'): -1,
#          (('first', 's'), 'fi'): -1,
#          (('first_two', 'se'), 'de'): -1,
#          (('last_three', 'jen'), 'de'): -1,
#          (('first_two', 'gu'), 'en'): -1,
#          (('last', 't'), 'en'): -1,
#          (('last_two', 'at'), 'en'): -1,
#          (('last_three', 'rat'), 'en'): -1,
#          (('last', 'a'), 'de'): -1,
#          (('first', 'T'), 'en'): -1,
#          (('first_two', 'Th'), 'en'): -1,
#          (('last_two', 'ra'), 'en'): -1,
#          (('last_three', 'yra'), 'en'): -1,
#          (('last_two', 'ns'), 'fi'): -1,
#          (('last_three', 'ons'), 'fi'): -1,
#          (('last_three', 'gan'), 'fi'): -1,
#          (('first_two', 'bi'), 'fi'): -1,
#          (('last_three', 'len'), 'fi'): -1,
#          (('last', 't'), 'fi'): -1,
#          (('first', 'a'), 'de'): -1,
#          (('first', 'd'), 'de'): -1,
#          (('first_two', 'du'), 'fr'): -1,
#          (('last_three', 'ert'), 'fr'): -1,
#          (('first_two', 'ta'), 'fr'): -1,
#          (('last_two', 'ls'), 'fr'): -1,
#          (('last_three', 'ils'), 'fr'): -1,
#          (('first_two', 'av'), 'de'): -1,
#          (('last_three', 'het'), 'de'): -1,
#          (('first', 'i'), 'fr'): -1,
#          (('first_two', 'im'), 'fr'): -1,
#          (('last_three', 'nts'), 'fr'): -1,
#          (('last_two', 'ni'), 'en'): -1,
#          (('last_three', 'ini'), 'en'): -1,
#          (('first_two', 'né'), 'sv'): -1,
#          (('last_two', 'oa'), 'de'): -1,
#          (('last_three', 'koa'), 'de'): -1,
#          (('first_two', 'av'), 'fr'): -1,
#          (('last_three', 'sed'), 'sv'): -1,
#          (('first', 'r'), 'fr'): -1,
#          (('first_two', 'ra'), 'fr'): -1,
#          (('first_two', 'be'), 'en'): -1,
#          (('last_two', 'ör'), 'en'): -1,
#          (('last_three', 'rör'), 'en'): -1,
#          (('first', 'S'), 'en'): -1,
#          (('first_two', 'St'), 'en'): -1,
#          (('last_three', 'ums'), 'en'): -1,
#          (('first_two', 'sä'), 'fr'): -1,
#          (('last_three', 'ösa'), 'fr'): -1,
#          (('first_two', 'om'), 'de'): -1,
#          (('last_two', 'aa'), 'de'): -1,
#          (('last_three', 'maa'), 'de'): -1,
#          (('first_two', 'or'), 'fr'): -1,
#          (('first', 'o'), 'en'): -1,
#          (('last', 'x'), 'en'): -1,
#          (('last_two', 'ux'), 'en'): -1,
#          (('last_three', 'aux'), 'en'): -1,
#          (('last_two', 'ng'), 'sv'): -1,
#          (('last_two', 'rs'), 'de'): -1,
#          (('last_three', 'ars'), 'de'): -1,
#          (('first_two', 'po'), 'en'): -1,
#          (('last_three', 'tis'), 'en'): -1,
#          (('last_three', 'ale'), 'fr'): -1,
#          (('first_two', 'to'), 'fi'): -1,
#          (('first_two', 'to'), 'en'): -1,
#          (('last_two', 'si'), 'en'): -1,
#          (('last_three', 'osi'), 'en'): -1,
#          (('first', 'E'), 'fr'): -1,
#          (('first_two', 'Ex'), 'fr'): -1,
#          (('last_three', 'nce'), 'fr'): -1,
#          (('first', 'u'), 'fi'): -1,
#          (('last_three', 'ken'), 'sv'): -1,
#          (('last_three', 'öld'), 'en'): -1,
#          (('first_two', 'si'), 'sv'): -1,
#          (('last', 'e'), 'sv'): -1,
#          (('last_two', 'ée'), 'sv'): -1,
#          (('last_three', 'née'), 'sv'): -1,
#          (('first_two', 'hu'), 'sv'): -1,
#          (('last_two', 'it'), 'sv'): -1,
#          (('last_three', 'sit'), 'sv'): -1,
#          (('first_two', 'el'), 'en'): -1,
#          (('last_two', 'ön'), 'en'): -1,
#          (('last_three', 'tön'), 'en'): -1,
#          (('first_two', 'en'), 'en'): -1,
#          (('first_two', 'en'), 'fi'): -1,
#          (('last', 'c'), 'fi'): -1,
#          (('last_two', 'ic'), 'fi'): -1,
#          (('last_three', 'dic'), 'fi'): -1,
#          (('last_two', 'al'), 'fr'): -1,
#          (('last_three', 'tal'), 'fr'): -1,
#          (('first', 'l'), 'sv'): -1,
#          (('first', 'l'), 'fr'): -1,
#          (('first_two', 'li'), 'fr'): -1,
#          (('last_three', 'tur'), 'fr'): -1,
#          (('first', 'W'), 'fi'): -1,
#          (('first_two', 'Wi'), 'fi'): -1,
#          (('first_two', 'vo'), 'sv'): -1,
#          (('last_two', 'em'), 'sv'): -1,
#          (('last_three', 'tem'), 'sv'): -1,
#          (('last_three', 'ged'), 'fr'): -1,
#          (('first_two', 'ed'), 'en'): -1,
#          (('last', 'ä'), 'en'): -1,
#          (('last_two', 'tä'), 'en'): -1,
#          (('last_three', 'stä'), 'en'): -1,
#          (('last_three', 'ten'), 'de'): -1,
#          (('first', 't'), 'sv'): -1,
#          (('first', 't'), 'de'): -1,
#          (('first_two', 'ti'), 'de'): -1,
#          (('last_two', 're'), 'de'): -1,
#          (('last_three', 'are'), 'de'): -1,
#          (('first', 'M'), 'fr'): -1,
#          (('first_two', 'Mi'), 'fr'): -1,
#          (('last_two', 'he'), 'fr'): -1,
#          (('last_three', 'öhe'), 'fr'): -1,
#          (('first', 'ü'), 'fi'): -1,
#          (('first_two', 'üb'), 'fi'): -1,
#          (('last_two', 'mt'), 'fi'): -1,
#          (('last_three', 'rmt'), 'fi'): -1,
#          (('first_two', 'nu'), 'fr'): -1,
#          (('last_three', 'ani'), 'fr'): -1,
#          (('first_two', 'oe'), 'en'): -1,
#          (('last_two', 'rd'), 'en'): -1,
#          (('last_three', 'örd'), 'en'): -1,
#          (('last_two', 'eg'), 'en'): -1,
#          (('last_three', 'teg'), 'en'): -1,
#          (('first', 'r'), 'de'): -1,
#          (('first_two', 'ru'), 'de'): -1,
#          (('last_three', 'nen'), 'de'): -1,
#          (('last_two', 'nd'), 'sv'): -1,
#          (('last_three', 'und'), 'sv'): -1,
#          (('first_two', 'ku'), 'sv'): -1,
#          (('last_two', 'va'), 'sv'): -1,
#          (('last_three', 'eva'), 'sv'): -1,
#          (('last_two', 'rt'), 'fi'): -1,
#          (('last_three', 'art'), 'fi'): -1,
#          (('first', 'C'), 'sv'): -1,
#          (('first_two', 'Ca'), 'sv'): -1,
#          (('last_two', 'ip'), 'sv'): -1,
#          (('last_three', 'hip'), 'sv'): -1,
#          (('last_three', 'ear'), 'sv'): -1,
#          (('last', 'o'), 'fi'): -1,
#          (('last_two', 'to'), 'fi'): -1,
#          (('last_three', 'sto'), 'fi'): -1,
#          (('first_two', 'it'), 'sv'): -1,
#          (('first_two', 'sa'), 'de'): -1,
#          (('last_two', 'ye'), 'de'): -1,
#          (('last_three', 'aye'), 'de'): -1,
#          (('first', 'ö'), 'fr'): -1,
#          (('first_two', 'öv'), 'fr'): -1,
#          (('last_two', 'ds'), 'fr'): -1,
#          (('last_three', 'ids'), 'fr'): -1,
#          (('last_two', 'se'), 'fr'): -1,
#          (('first_two', 'uu'), 'sv'): -1,
#          (('last_three', 'sia'), 'sv'): -1,
#          (('first_two', 'ph'), 'sv'): -1,
#          (('last_two', 'es'), 'sv'): -1,
#          (('last_three', 'nes'), 'sv'): -1,
#          (('first_two', 'Va'), 'sv'): -1,
#          (('last_three', 'ure'), 'fr'): -1,
#          (('last', 'y'), 'sv'): -1,
#          (('last_two', 'cy'), 'sv'): -1,
#          (('last_three', 'ncy'), 'sv'): -1,
#          (('first', 'w'), 'en'): -1,
#          (('first_two', 'wa'), 'en'): -1,
#          (('last_two', 'ce'), 'en'): -1,
#          (('last_three', 'ace'), 'en'): -1,
#          (('first_two', 'fl'), 'en'): -1,
#          (('last_two', 'té'), 'en'): -1,
#          (('last_three', 'ité'), 'en'): -1,
#          (('first_two', 'di'), 'fr'): -1,
#          (('first_two', 'di'), 'fi'): -1,
#          (('last_three', 'ond'), 'fi'): -1,
#          (('last_two', 'te'), 'en'): -1,
#          (('last_three', 'lte'), 'en'): -1,
#          (('last_three', 'ger'), 'fr'): -1,
#          (('first', 'v'), 'fr'): -1,
#          (('first_two', 'va'), 'fr'): -1,
#          (('last', 'o'), 'de'): -1,
#          (('last_two', 'ro'), 'de'): -1,
#          (('last_three', 'ero'), 'de'): -1,
#          (('first_two', 'br'), 'de'): -1,
#          (('last_three', 'way'), 'de'): -1,
#          (('first', 'g'), 'fi'): -1,
#          (('first', 'O'), 'en'): -1,
#          (('first_two', 'Ob'), 'en'): -1,
#          (('last', 'u'), 'en'): -1,
#          (('last_two', 'au'), 'en'): -1,
#          (('last_three', 'gau'), 'en'): -1,
#          (('first_two', 'ef'), 'fr'): -1,
#          (('last_three', 'and'), 'fr'): -1,
#          (('first_two', 'Ag'), 'en'): -1,
#          (('last', 'v'), 'en'): -1,
#          (('last_two', 'iv'), 'en'): -1,
#          (('last_three', 'giv'), 'en'): -1,
#          (('first_two', 'fo'), 'de'): -1,
#          (('last_two', 'rm'), 'de'): -1,
#          (('last_three', 'orm'), 'de'): -1,
#          (('last', 'r'), 'de'): -1,
#          (('first_two', 'ec'), 'de'): -1,
#          (('first_two', 'oa'), 'fr'): -1,
#          (('last_two', 'ig'), 'fr'): -1,
#          (('last_three', 'lig'), 'fr'): -1,
#          (('first_two', 'la'), 'sv'): -1,
#          (('last_two', 'ßt'), 'sv'): -1,
#          (('last_three', 'aßt'), 'sv'): -1,
#          (('first_two', 'fä'), 'fr'): -1,
#          (('last_three', 'tet'), 'fr'): -1,
# ...
#          (('last_three', 'age'), 'fi'): -1,
#          (('last_three', 'het'), 'en'): -1,
#          (('first_two', 'hö'), 'en'): -1,
#          (('last_two', 'he'), 'en'): -1,
#          (('last_three', 'che'), 'en'): -1,
#          (('last_three', 'rse'), 'en'): -1,
#          (('first_two', 'ri'), 'sv'): -1,
#          (('last_three', 'ört'), 'de'): -1,
#          (('first_two', 'ha'), 'de'): -1,
#          (('last_two', 'gs'), 'de'): -1,
#          (('last_three', 'ägs'), 'de'): -1,
#          (('last_three', 'jon'), 'sv'): -1,
#          (('first', 'L'), 'fi'): -1,
#          (('first_two', 'Lu'), 'fi'): -1,
#          (('last_two', 'rn'), 'fi'): -1,
#          (('last_three', 'ern'), 'fi'): -1,
#          (('last_two', 'ms'), 'fr'): -1,
#          (('last_three', 'rms'), 'fr'): -1,
#          (('first_two', 'vä'), 'de'): -1,
#          (('first_two', 'ry'), 'sv'): -1,
#          (('last_three', 'ten'), 'fi'): -1,
#          (('last_three', 'ian'), 'de'): -1,
#          (('first_two', 'uc'), 'sv'): -1,
#          (('last_three', 'car'), 'sv'): -1,
#          (('first_two', 'ya'), 'de'): -1,
#          (('last_three', 'ate'), 'de'): -1,
#          (('first', 'F'), 'fi'): -1,
#          (('first_two', 'Fe'), 'fi'): -1,
#          (('first_two', 'it'), 'de'): -1,
#          (('first_two', 'in'), 'fi'): -1,
#          (('last_two', 'ld'), 'fi'): -1,
#          (('last_three', 'öld'), 'fi'): -1,
#          (('last_two', 'vs'), 'fi'): -1,
#          (('last_three', 'rvs'), 'fi'): -1,
#          (('first_two', 'oe'), 'de'): -1,
#          (('last_three', 'ène'), 'de'): -1,
#          (('last_three', 'are'), 'en'): -1,
#          (('last_three', 'ösa'), 'fi'): -1,
#          (('last_two', 'hi'), 'fr'): -1,
#          (('last_three', 'lhi'), 'fr'): -1,
#          (('first_two', 'kv'), 'fi'): -1,
#          (('last_two', 'gt'), 'fi'): -1,
#          (('last_three', 'igt'), 'fi'): -1,
#          (('first_two', 'be'), 'fr'): -1,
#          (('last_three', 'tar'), 'fr'): -1,
#          (('first_two', 'dy'), 'fr'): -1,
#          (('last_two', 'si'), 'sv'): -1,
#          (('last_three', 'asi'), 'sv'): -1,
#          (('first_two', 'ki'), 'de'): -1,
#          (('last_three', 'vät'), 'de'): -1,
#          (('last_three', 'bts'), 'sv'): -1,
#          (('first_two', 'sp'), 'fr'): -1,
#          (('last_three', 'son'), 'fr'): -1,
#          (('last_three', 'ero'), 'en'): -1,
#          (('first_two', 'lä'), 'sv'): -1,
#          (('last_three', 'ond'), 'en'): -1,
#          (('last_two', 'rn'), 'en'): -1,
#          (('last_three', 'orn'), 'en'): -1,
#          (('first_two', 'pl'), 'fi'): -1,
#          (('last_three', 'ume'), 'fi'): -1,
#          (('last_two', 'ni'), 'sv'): -1,
#          (('last_three', 'ani'), 'sv'): -1,
#          (('first_two', 'ce'), 'fr'): -1,
#          (('last_three', 'tes'), 'sv'): -1,
#          (('first', 'V'), 'en'): -1,
#          (('first_two', 'Va'), 'en'): -1,
#          (('first_two', 'ph'), 'fr'): -1,
#          (('last_three', 'nes'), 'fr'): -1,
#          (('first_two', 'Ad'), 'en'): -1,
#          (('last_three', 'ams'), 'en'): -1,
#          (('first_two', 'ga'), 'en'): -1,
#          (('last_two', 'ns'), 'en'): -1,
#          (('last_three', 'ons'), 'en'): -1,
#          (('first_two', 'ai'), 'sv'): -1,
#          (('last_three', 'ire'), 'sv'): -1,
#          (('last', 'v'), 'fr'): -1,
#          (('last_two', 'av'), 'fr'): -1,
#          (('last_three', 'gav'), 'fr'): -1,
#          (('last_three', 'sed'), 'fr'): -1,
#          (('last_two', 'ad'), 'en'): -1,
#          (('last_three', 'sad'), 'en'): -1,
#          (('last_two', 'ms'), 'sv'): -1,
#          (('last_three', 'rms'), 'sv'): -1,
#          (('first_two', 'ru'), 'fr'): -1,
#          (('last_two', 'me'), 'sv'): -1,
#          (('last_three', 'ume'), 'sv'): -1,
#          (('last_three', 'ées'), 'de'): -1,
#          (('last_three', 'vor'), 'fr'): -1,
#          (('first_two', 'na'), 'fi'): -1,
#          (('last_three', 'ale'), 'fi'): -1,
#          (('first_two', 'fä'), 'de'): -1,
#          (('last_three', 'nde'), 'en'): -1,
#          (('last_three', 'ane'), 'de'): -1,
#          (('last_two', 'rm'), 'sv'): -1,
#          (('last_three', 'orm'), 'sv'): -1,
#          (('first_two', 'Er'), 'en'): -1,
#          (('last_three', 'hes'), 'en'): -1,
#          (('last_three', 'ssa'), 'fi'): -1,
#          (('last_two', 'ti'), 'en'): -1,
#          (('last_three', 'ati'), 'en'): -1,
#          (('last_three', 'zes'), 'sv'): -1,
#          (('last_two', 'ed'), 'fi'): -1,
#          (('last_three', 'eed'), 'fi'): -1,
#          (('first_two', 'fö'), 'en'): -1,
#          (('last_three', 'lag'), 'en'): -1,
#          (('first_two', 'ut'), 'en'): -1,
#          (('last_three', 'kes'), 'en'): -1,
#          (('first_two', 'im'), 'de'): -1,
#          (('last_two', 've'), 'de'): -1,
#          (('last_three', 'ive'), 'de'): -1,
#          (('last_three', 'nst'), 'fr'): -1,
#          (('last_three', 'rse'), 'fr'): -1,
#          (('last_three', 'ald'), 'sv'): -1,
#          (('first_two', 'tu'), 'sv'): -1,
#          (('last_three', 'ver'), 'sv'): -1,
#          (('first_two', 'au'), 'en'): -1,
#          (('first', 'j'), 'fr'): -1,
#          (('first_two', 'ja'), 'fr'): -1,
#          (('last_three', 'eno'), 'fr'): -1,
#          (('last_three', 'dge'), 'fr'): -1,
#          (('first_two', 'ec'), 'en'): -1,
#          (('first_two', 'up'), 'fr'): -1,
#          (('last_three', 'ört'), 'fr'): -1,
#          (('last_three', 'ast'), 'de'): -1,
#          (('first', 'Z'), 'fr'): -1,
#          (('first_two', 'Ze'), 'fr'): -1,
#          (('last_two', 'ht'), 'fr'): -1,
#          (('last_three', 'cht'), 'fr'): -1,
#          (('first_two', 'Vo'), 'sv'): -1,
#          (('last_three', 'ist'), 'sv'): -1,
#          (('first_two', 'mu'), 'sv'): -1,
#          (('last_two', 'oa'), 'sv'): -1,
#          (('last_three', 'loa'), 'sv'): -1,
#          (('first_two', 'vo'), 'en'): -1,
#          (('last_three', 'ile'), 'en'): -1,
#          (('last_three', 'ine'), 'de'): -1,
#          (('first_two', 'dr'), 'sv'): -1,
#          (('last_three', 'rag'), 'sv'): -1,
#          (('last_three', 'sta'), 'fr'): -1,
#          (('last_three', 'und'), 'fr'): -1,
#          (('last_three', 'ver'), 'fr'): -1,
#          (('first_two', 'ca'), 'sv'): -1,
#          (('last_three', 'ean'), 'sv'): -1,
#          (('last', 'h'), 'fi'): -1,
#          (('last_two', 'ch'), 'fi'): -1,
#          (('last_three', 'uch'), 'fi'): -1,
#          (('first_two', 'pa'), 'sv'): -1,
#          (('first_two', 'ko'), 'sv'): -1,
#          (('last_three', 'eet'), 'sv'): -1,
#          (('last_three', 'nte'), 'fi'): -1,
#          (('first_two', 'ed'), 'fr'): -1,
#          (('last', 'ä'), 'fr'): -1,
#          (('last_two', 'tä'), 'fr'): -1,
#          (('last_three', 'stä'), 'fr'): -1,
#          (('last_two', 'ka'), 'fr'): -1,
#          (('last_three', 'ska'), 'fr'): -1,
#          (('last_two', 'ön'), 'fr'): -1,
#          (('last_three', 'tön'), 'fr'): -1,
#          (('last_three', 'ets'), 'sv'): -1,
#          (('first_two', 'me'), 'fi'): -1,
#          (('first_two', 'di'), 'de'): -1,
#          (('last_three', 'jon'), 'de'): -1,
#          (('last_three', 'ade'), 'fr'): -1,
#          (('first_two', 'em'), 'en'): -1,
#          (('last_three', 'ise'), 'en'): -1,
#          (('last_two', 'aa'), 'sv'): -1,
#          (('last_three', 'taa'), 'sv'): -1,
#          (('last_two', 'pe'), 'sv'): -1,
#          (('last_three', 'ppe'), 'sv'): -1,
#          (('last_two', 'ta'), 'de'): -1,
#          (('last_three', 'ota'), 'de'): -1,
#          (('last', 'c'), 'sv'): -1,
#          (('last_two', 'ic'), 'sv'): -1,
#          (('last_three', 'dic'), 'sv'): -1,
#          (('last_three', 'ont'), 'en'): -1,
#          (('last_two', 'st'), 'fi'): -1,
#          (('last_three', 'ast'), 'fi'): -1,
#          (('first_two', 'ab'), 'fr'): -1,
#          (('first_two', 'lu'), 'fi'): -1,
#          (('first_two', 'sm'), 'fr'): -1,
#          (('first_two', 'mo'), 'de'): -1,
#          (('first_two', 'de'), 'fi'): -1,
#          (('last_three', 'lta'), 'fi'): -1,
#          (('first_two', 'ba'), 'de'): -1,
#          (('first_two', 'ne'), 'fr'): -1,
#          (('last', 'k'), 'fr'): -1,
#          (('last_two', 'rk'), 'fr'): -1,
#          (('last_three', 'ork'), 'fr'): -1,
#          (('first_two', 'ka'), 'sv'): -1,
#          (('last', 'n'), 'en'): -2,
#          (('last_three', 'hen'), 'fi'): -2,
#          (('first', 'm'), 'de'): -2,
#          (('first_two', 'mi'), 'de'): -2,
#          (('last', 'a'), 'en'): -2,
#          (('last', 's'), 'fi'): -2,
#          (('first_two', 'sp'), 'fi'): -2,
#          (('first', 'b'), 'fi'): -2,
#          (('first_two', 'sc'), 'en'): -2,
#          (('first_two', 'ex'), 'de'): -2,
#          (('last_two', 'ts'), 'fr'): -2,
#          (('last', 'i'), 'en'): -2,
#          (('last_two', 'nt'), 'sv'): -2,
#          (('last_two', 'ir'), 'sv'): -2,
#          (('last_three', 'oir'), 'sv'): -2,
#          (('last_two', 'ed'), 'sv'): -2,
#          (('last_three', 'ies'), 'fr'): -2,
#          (('last', 'n'), 'fr'): -2,
#          (('last_two', 'sa'), 'fr'): -2,
#          (('first_two', 're'), 'sv'): -2,
#          (('first', 'y'), 'sv'): -2,
#          (('first_two', 'yh'), 'sv'): -2,
#          (('first_two', 'ur'), 'fi'): -2,
#          (('last_three', 'mla'), 'fi'): -2,
#          (('first', 'h'), 'sv'): -2,
#          (('first', 'e'), 'fi'): -2,
#          (('first_two', 'el'), 'fi'): -2,
#          (('last_three', 'gen'), 'fi'): -2,
#          (('last', 'm'), 'sv'): -2,
#          (('first_two', 'ch'), 'fr'): -2,
#          (('first_two', 'su'), 'sv'): -2,
#          (('first', 'k'), 'sv'): -2,
#          (('first_two', 'te'), 'sv'): -2,
#          (('last_two', 'se'), 'en'): -2,
#          (('last_three', 'ose'), 'fr'): -2,
#          (('last_two', 'ia'), 'sv'): -2,
#          (('first', 'V'), 'sv'): -2,
#          (('last', 'é'), 'en'): -2,
#          (('last_three', 'lla'), 'sv'): -2,
#          (('first', 'd'), 'fi'): -2,
#          (('first_two', 'va'), 'de'): -2,
#          (('last_three', 'sen'), 'de'): -2,
#          (('first_two', 'mu'), 'en'): -2,
#          (('first', 'A'), 'en'): -2,
#          (('first', 'f'), 'de'): -2,
#          (('first', 'w'), 'sv'): -2,
#          (('first_two', 'we'), 'sv'): -2,
#          (('last_three', 'art'), 'de'): -2,
#          (('last', 'g'), 'fr'): -2,
#          (('last_two', 'gn'), 'sv'): -2,
#          (('last_three', 'ign'), 'sv'): -2,
#          (('first', 'G'), 'en'): -2,
#          (('last_three', 'nnt'), 'en'): -2,
#          (('last_two', 'rs'), 'sv'): -2,
#          (('last_two', 'ne'), 'de'): -2,
#          (('first', 'k'), 'de'): -2,
#          (('last_two', 'it'), 'en'): -2,
#          (('first_two', 'un'), 'sv'): -2,
#          (('last_two', 'ga'), 'fi'): -2,
#          (('last_three', 'ion'), 'fi'): -2,
#          (('first_two', 'he'), 'en'): -2,
#          (('last_three', 'nde'), 'fr'): -2,
#          (('first_two', 'is'), 'fi'): -2,
#          (('last_three', 'bia'), 'fi'): -2,
#          (('last_two', 'de'), 'en'): -2,
#          (('last_two', 'en'), 'en'): -2,
#          (('last_two', 'le'), 'sv'): -2,
#          (('last_three', 'eur'), 'sv'): -2,
#          (('last_three', 'ble'), 'de'): -2,
#          (('last_two', 'as'), 'en'): -2,
#          (('first', 'a'), 'en'): -2,
#          (('first_two', 'st'), 'fr'): -2,
#          (('last_three', 'ota'), 'fi'): -2,
#          (('last_two', 'ka'), 'fi'): -2,
#          (('last', 'r'), 'fi'): -2,
#          (('last_two', 'er'), 'fi'): -2,
#          (('first', 'E'), 'en'): -2,
#          (('first_two', 'se'), 'sv'): -2,
#          (('last_three', 'dar'), 'fr'): -2,
#          (('first_two', 'ha'), 'fi'): -2,
#          (('last_two', 'or'), 'fr'): -2,
#          (('last_three', 'gon'), 'sv'): -2,
#          (('first_two', 'fe'), 'sv'): -2,
#          (('last_three', 'vor'), 'sv'): -2,
#          (('first_two', 'em'), 'sv'): -2,
#          (('last_three', 'ise'), 'sv'): -2,
#          (('first_two', 'la'), 'fr'): -2,
#          (('last_three', 'der'), 'fr'): -2,
#          (('first_two', 'sm'), 'sv'): -2,
#          (('last', 'l'), 'en'): -2,
#          (('first_two', 'up'), 'de'): -2,
#          (('first_two', 'dé'), 'en'): -2,
#          (('first_two', 'ac'), 'de'): -2,
#          (('last_three', 'dge'), 'de'): -2,
#          (('last_two', 'ys'), 'en'): -2,
#          (('last_three', 'est'), 'fr'): -2,
#          (('first_two', 'pu'), 'sv'): -2,
#          (('last_two', 'im'), 'en'): -2,
#          (('last_three', 'eim'), 'en'): -2,
#          (('last_three', 'ues'), 'sv'): -2,
#          (('last_two', 'et'), 'en'): -2,
#          (('first_two', 'av'), 'en'): -2,
#          (('first_two', 'do'), 'sv'): -2,
#          (('first_two', 'to'), 'sv'): -2,
#          (('last_two', 'el'), 'en'): -2,
#          (('last_three', 'nel'), 'en'): -2,
#          (('last_two', 'me'), 'en'): -2,
#          (('first_two', 'op'), 'en'): -2,
#          (('first_two', 'br'), 'fr'): -2,
#          (('first_two', 'ef'), 'en'): -2,
#          (('last_three', 'ncy'), 'en'): -2,
#          (('first', 'c'), 'fi'): -2,
#          (('first_two', 'ca'), 'fi'): -2,
#          (('last_three', 'ean'), 'fi'): -2,
#          (('first_two', 'pl'), 'en'): -2,
#          (('first', 'y'), 'de'): -2,
#          (('last_three', 'ens'), 'fr'): -2,
#          (('first', 'n'), 'de'): -2,
#          (('first_two', 'na'), 'de'): -2,
#          (('last_three', 'ons'), 'sv'): -2,
#          (('last_three', 'nnt'), 'sv'): -2,
#          (('first_two', 'me'), 'sv'): -2,
#          (('last_three', 'est'), 'sv'): -2,
#          (('last_three', 'rer'), 'en'): -2,
#          (('first_two', 'bo'), 'de'): -2,
#          (('first_two', 'tr'), 'en'): -2,
#          (('last_three', 'uch'), 'de'): -2,
#          (('first_two', 'an'), 'fi'): -2,
#          (('last_three', 'ler'), 'fr'): -2,
#          (('last_three', 'res'), 'sv'): -2,
#          (('first', 'M'), 'sv'): -2,
#          (('first_two', 'Ma'), 'sv'): -2,
#          (('last_three', 'gan'), 'en'): -2,
#          (('last_two', 'to'), 'fr'): -2,
#          (('last_three', 'sto'), 'fr'): -2,
#          (('last_three', 'ert'), 'sv'): -2,
#          (('last_three', 'tte'), 'fr'): -2,
#          (('last_three', 'ast'), 'en'): -2,
#          (('last_three', 'ant'), 'sv'): -2,
#          (('last_two', 'nd'), 'en'): -2,
#          (('last_three', 'det'), 'fr'): -2,
#          (('last_three', 'ose'), 'sv'): -2,
#          (('last_three', 'lar'), 'sv'): -2,
#          (('last_three', 'ces'), 'fr'): -2,
#          (('first_two', 've'), 'sv'): -2,
#          (('last_three', 'ton'), 'en'): -2,
#          (('first_two', 'gl'), 'fr'): -2,
#          (('last_three', 'sch'), 'en'): -2,
#          (('first_two', 'sä'), 'fi'): -2,
#          (('first_two', 'si'), 'en'): -2,
#          (('last_three', 'dar'), 'en'): -2,
#          (('first_two', 'né'), 'en'): -2,
#          (('last_three', 'nor'), 'en'): -2,
#          (('first_two', 'st'), 'de'): -2,
#          (('last_three', 'jet'), 'sv'): -2,
#          (('first_two', 'fu'), 'sv'): -2,
#          (('first', 'o'), 'de'): -3,
#          (('first', 's'), 'de'): -3,
#          (('last_three', 'men'), 'sv'): -3,
#          (('last_three', 'tes'), 'en'): -3,
#          (('first', 'e'), 'de'): -3,
#          (('first', 'j'), 'de'): -3,
#          (('first_two', 'ja'), 'de'): -3,
#          (('last_three', 'ées'), 'en'): -3,
#          (('last_two', 'on'), 'sv'): -3,
#          (('first', 'b'), 'de'): -3,
#          (('first_two', 'no'), 'fr'): -3,
#          (('last_two', 'de'), 'fr'): -3,
#          (('last_two', 'ge'), 'fr'): -3,
#          (('last_three', 'ele'), 'fr'): -3,
#          (('last_three', 'ier'), 'sv'): -3,
#          (('last_three', 'den'), 'fi'): -3,
#          (('last_three', 'ent'), 'de'): -3,
#          (('last_three', 'des'), 'fr'): -3,
#          (('last_three', 'ies'), 'sv'): -3,
#          (('last_three', 'ats'), 'en'): -3,
#          (('last_three', 'des'), 'en'): -3,
#          (('first_two', 'pe'), 'fr'): -3,
#          (('last_three', 'nsa'), 'sv'): -3,
#          (('last_three', 'gon'), 'fi'): -3,
#          (('first_two', 'hé'), 'sv'): -3,
#          (('first_two', 'um'), 'sv'): -3,
#          (('first_two', 'fo'), 'en'): -4,
#          (('last_three', 'ige'), 'en'): -4,
#          (('first', 'p'), 'de'): -4,
#          (('last_three', 'lle'), 'en'): -4,
#          (('last_three', 'red'), 'en'): -4,
#          (('last_three', 'mme'), 'fr'): -4,
#          (('first_two', 'ma'), 'fr'): -4,
#          (('last_three', 'lse'), 'en'): -4,
#          (('first_two', 'eq'), 'fr'): -4})

# %% [markdown]
# <p>Test these weights with test set.</p>
# <p>Create a dictionary. Assign scores (value) to each word (key). Before adding the scores into the dictionary, sort the scores from the highest to the lowest (so we can easily print how our word was classified by the perceptron).</p>

# %%
from operator import itemgetter

tested_scores = {}
for word, lang in test_set:
    features = {lang: score(get_features(word), lang) for lang in tags}
    features = sorted(features.items(), reverse=True, key=itemgetter(1))
    tested_scores[word] = features

# %% [markdown]
# <p>Print the results.</p>
# <p>Compare a predicted language with a correct language.</p>

# %%
i = 0
correct = 0
incorrect = 0

for word, stats in tested_scores.items():
    if stats[0][0] == test_set[i][1]:
        print(word, 'predicted correctly as:', stats[0][0])
        correct += 1
    else:
        print(word, 'predicted incorrectly as:', stats[0][0], 'desired language:', test_set[i][1])
        incorrect += 1
    i += 1
# Out:
# bladder predicted incorrectly as: sv desired language: en
# blindly predicted correctly as: en
# colourful predicted incorrectly as: fr desired language: en
# implemented predicted correctly as: en
# nondescript predicted incorrectly as: fi desired language: en
# reconsider predicted incorrectly as: de desired language: en
# slaves predicted incorrectly as: sv desired language: en
# strategic predicted correctly as: en
# utilising predicted correctly as: en
# weekly predicted correctly as: en
# avustettuna predicted incorrectly as: sv desired language: fi
# jalostettuja predicted correctly as: fi
# kansallista predicted correctly as: fi
# kansoillemme predicted correctly as: fi
# näen predicted correctly as: fi
# opeteltavaa predicted correctly as: fi
# soittaneen predicted incorrectly as: sv desired language: fi
# tiedosta predicted correctly as: fi
# tuijotin predicted correctly as: fi
# verojärjestelmän predicted correctly as: fi
# catastrophes predicted correctly as: fr
# manifester predicted incorrectly as: sv desired language: fr
# partiel predicted correctly as: fr
# posée predicted correctly as: fr
# rasées predicted correctly as: fr
# reproduction predicted incorrectly as: de desired language: fr
# sectes predicted correctly as: fr
# shiba predicted incorrectly as: sv desired language: fr
# stelmecke predicted incorrectly as: en desired language: fr
# wydad predicted correctly as: fr
# Abschied predicted correctly as: de
# Bushs predicted correctly as: de
# Enzymen predicted correctly as: de
# Gemeinen predicted incorrectly as: sv desired language: de
# Huang predicted incorrectly as: en desired language: de
# Immekeppel predicted incorrectly as: fr desired language: de
# Inhumanes predicted incorrectly as: en desired language: de
# Madame predicted correctly as: de
# territorialen predicted incorrectly as: fi desired language: de
# verdankt predicted correctly as: de
# fält predicted correctly as: sv
# förundersökningarna predicted correctly as: sv
# inflytande predicted incorrectly as: de desired language: sv
# innehåller predicted incorrectly as: en desired language: sv
# kapital predicted incorrectly as: fi desired language: sv
# kemisk predicted incorrectly as: fi desired language: sv
# kopp predicted incorrectly as: fi desired language: sv
# procentuella predicted incorrectly as: fi desired language: sv
# skyddsombudet predicted correctly as: sv
# upplagor predicted correctly as: sv

# %% [markdown]
# <p>How accurate the perceptron is?</p>

# %%
print('Correctly classified:', correct)
print('Incorrectly classified:', incorrect)
print('Accuracy:', correct/len(test_set))
# Out:
# Correctly classified: 28
# Incorrectly classified: 22
# Accuracy: 0.56

# %%
# I think 40% accuracy is a good result considering the fact we only look at last two letters and update weights.
# When I used last three letters and first two letters, I got accuracy around 57%. But getting even better accuracy
# is very difficult. Random shuffling before each epoch helps, but not as much as I thought.

# %%
# About the linearity: Simple perceptron is linear (like our case), but there are also multi-layer perceptrons. 
# MLPs have a hidden layer. Jurafsky and Martin say: '...taking a weighted sum of its inputs and then applying
# a non-linearity.' So I think we would have to change our score() function, so it would not return a simple
# sum of weights, but e.g. sigmoid, tanh, or ReLu. From these three, ReLu is the simplest one and most commonly 
# used, so I would use that one. I tried to implement it in my code to the score() function, but I got errors.
# It would be nice to see the solution for this, if you have it implemented :)

# %% [markdown]
# <p>Success! In general, one needs to update the weights several times for each item in the training data. Doing it too many times, however, can return in <em>overfitting</em>. The perceptron algorithm always leads to better classification of the <em>training</em> data, but the opposite can happen for data which is not in the training set. The basic reason for this is that the perceptron first learns very general rules (such that words ending with <em>-ed</em> tend to be verbs), but later during training starts finding more and more specific rules (such that words ending with <em>-ent</em> that are longer than 7 letters and begin with <em>emba-</em> tend to be nouns -- this happens to fit the noun <em>embarrassment</em>, but is not a general rule of English grammar).</p>
